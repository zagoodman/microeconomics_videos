// %% [markdown]
// <h1>Table of Contents<span class="tocSkip"></span></h1>
// <div class="toc"><ul class="toc-item"><li><span><a href="#Prep" data-toc-modified-id="Prep-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prep</a></span><ul class="toc-item"><li><span><a href="#Check-dependencies" data-toc-modified-id="Check-dependencies-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Check dependencies</a></span></li><li><span><a href="#Define-global-control-variable-list" data-toc-modified-id="Define-global-control-variable-list-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Define global control variable list</a></span></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Define functions</a></span></li></ul></li><li><span><a href="#Attrition" data-toc-modified-id="Attrition-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Attrition</a></span><ul class="toc-item"><li><span><a href="#Attrition-for-those-below-the-median" data-toc-modified-id="Attrition-for-those-below-the-median-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Attrition for those below the median</a></span></li><li><span><a href="#Attrition-at-the-cutoff" data-toc-modified-id="Attrition-at-the-cutoff-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Attrition at the cutoff</a></span></li></ul></li><li><span><a href="#Balance" data-toc-modified-id="Balance-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Balance</a></span></li><li><span><a href="#Base-models" data-toc-modified-id="Base-models-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Base models</a></span><ul class="toc-item"><li><span><a href="#ITT" data-toc-modified-id="ITT-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>ITT</a></span></li><li><span><a href="#LATE" data-toc-modified-id="LATE-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>LATE</a></span></li></ul></li><li><span><a href="#Post-Double-Selection-(control-var-selection)" data-toc-modified-id="Post-Double-Selection-(control-var-selection)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Post-Double-Selection (control var selection)</a></span><ul class="toc-item"><li><span><a href="#ITT" data-toc-modified-id="ITT-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ITT</a></span></li><li><span><a href="#LATE" data-toc-modified-id="LATE-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>LATE</a></span></li></ul></li><li><span><a href="#Estimation-of-treatment-effects" data-toc-modified-id="Estimation-of-treatment-effects-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Estimation of treatment effects</a></span><ul class="toc-item"><li><span><a href="#First-stage" data-toc-modified-id="First-stage-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>First stage</a></span><ul class="toc-item"><li><span><a href="#Plots" data-toc-modified-id="Plots-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Plots</a></span></li><li><span><a href="#Tables" data-toc-modified-id="Tables-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Tables</a></span></li></ul></li><li><span><a href="#Second-stage" data-toc-modified-id="Second-stage-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Second stage</a></span><ul class="toc-item"><li><span><a href="#Plots" data-toc-modified-id="Plots-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Scatter-plots" data-toc-modified-id="Scatter-plots-6.2.1.1"><span class="toc-item-num">6.2.1.1&nbsp;&nbsp;</span>Scatter plots</a></span></li><li><span><a href="#Quantile-Regression" data-toc-modified-id="Quantile-Regression-6.2.1.2"><span class="toc-item-num">6.2.1.2&nbsp;&nbsp;</span>Quantile Regression</a></span></li><li><span><a href="#Regression-discontinuity" data-toc-modified-id="Regression-discontinuity-6.2.1.3"><span class="toc-item-num">6.2.1.3&nbsp;&nbsp;</span>Regression discontinuity</a></span></li></ul></li><li><span><a href="#Tables" data-toc-modified-id="Tables-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Tables</a></span></li></ul></li><li><span><a href="#Heterogeneity" data-toc-modified-id="Heterogeneity-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Heterogeneity</a></span></li><li><span><a href="#Spillover-Effects" data-toc-modified-id="Spillover-Effects-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Spillover Effects</a></span><ul class="toc-item"><li><span><a href="#Concurrent-quarter" data-toc-modified-id="Concurrent-quarter-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Concurrent quarter</a></span></li><li><span><a href="#Following-quarter" data-toc-modified-id="Following-quarter-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Following quarter</a></span></li></ul></li><li><span><a href="#Time-series" data-toc-modified-id="Time-series-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Time series</a></span><ul class="toc-item"><li><span><a href="#Prepare-data" data-toc-modified-id="Prepare-data-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Prepare data</a></span></li><li><span><a href="#Binge-watching" data-toc-modified-id="Binge-watching-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Binge watching</a></span></li><li><span><a href="#First-stage" data-toc-modified-id="First-stage-6.5.3"><span class="toc-item-num">6.5.3&nbsp;&nbsp;</span>First stage</a></span></li></ul></li><li><span><a href="#Video-specific-differences" data-toc-modified-id="Video-specific-differences-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Video-specific differences</a></span></li></ul></li><li><span><a href="#Robustness-Checks" data-toc-modified-id="Robustness-Checks-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Robustness Checks</a></span><ul class="toc-item"><li><span><a href="#Randomization-inference" data-toc-modified-id="Randomization-inference-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Randomization inference</a></span></li></ul></li></ul></div>

// %% [markdown]
// This file takes cleaned data and performs all analysis found in Famulari & Goodman (2020). All code in this file is in Stata (version 16).
//
// The necessary file structure for this code to work is as follows:
// - base directory
//     - jupyter
//         - analyze_data.ipynb
//     - data
//         - generated
//             - dem_concurrent.csv
//             - dem_nextquarter.csv
//             - id-year_level_data.csv
//     - tex
//         - plots
//         - tables

// %% [markdown]
// ## Prep

// %%
* Set working directory to base directory
cd "C:\Users\Zack\Documents\GitHub\microeconomics_videos"

// %% [markdown]
// ### Check dependencies

// %%
* check that everything is up to date and installed

*ado update, update // run this if you need to update packages

version
which binsreg
which ftools
which grc1leg
which grqreg
which pdslasso
which rdplot
which ritest
which rlasso // ssc install lassopack
which unique

// %% [markdown]
// ### Define global control variable list

// %%
global ctrl_vars mathquizstd videos_mid1_u duration_mid1_u pset_pre ///
    transfer prev_cumgpa prev_cumgpa_unobs female ///
    asian latx white

// sum $ctrl_vars

// %% [markdown]
// ### Define functions

// %%
* Data prep functions

foreach v in clean_data get_idyearlevel merge_winter_gpa ///
    merge_dem clean_dem get_std_units {
    capture program drop `v'
}

* define data clean function common to all dfs
program clean_data
    capture drop arm
    gen arm = treated + toberandomized
    drop toberandomized
    drop if mi(mid1score) // did not start experiment
    label define arm 0 "Above median" 1 "Control" 2 "Treated"
    label values arm arm
    capture drop y2019
    gen y2019 = year == 2019
    capture drop bothpairs
    gen pairyear = year * 1000 + pair
    sort pair year
    foreach v in mid2score finalscore {
        gen bothpairs_`v' = !mi(`v')
        by pair year: ereplace bothpairs_`v' = sum(bothpairs_`v')
        replace bothpairs_`v' = bothpairs_`v' >= 2
    }
    rename (bothpairs_mid2 bothpairs_final) (bothpairs_mid2 bothpairs_final)
    replace mathquiz = 0 if mi(mathquiz)
    end

* define function that loads student-year level data
program get_idyearlevel
    import delimited ./data/generated/id-year_level_data.csv, clear varnames(1)
    clean_data
    end

* merge gpa/units/class data from subsequent quarter
program merge_winter_gpa
    preserve
    import delimited ./data/generated/dem_nextquarter.csv, clear varnames(1)
    local renamevars units_letter units_pnp units_w ///
        gpa_letter gpa_letter_sansecon gpa_letter_sans100a gpa_econ_sans100a ///
        nclass_letter nclass_np nclass_pnp nclass_p nclass_w
    keep id year `renamevars' 
    foreach v in `renamevars' {
        rename `v' winter_`v'
    }
    tempfile temp
    save `temp'
    restore
    merge 1:1 id year using `temp', nogen
    end

* merge demographic data
program merge_dem
    preserve
    import delimited ./data/generated/dem_concurrent.csv, clear varnames(1)
    tempfile temp
    save `temp'
    restore
    merge 1:1 id year using `temp', nogen
    end

* get demographic vars into binary form
program clean_dem
    capture drop male female othergen ///
        chinese latx oasian viet white othereth
    * gender
    gen male = gender == "m"
    gen female = gender == "f"
    gen othergen = gender == "u"
    * ethnicity
    gen chinese = ethnicity == "Chinese/Chinese-American"
    gen latx = ethnicity == "Chicanx/Latinx"
    gen oasian = ethnicity == "All Other Asian/Asian-American"
    gen viet = ethnicity == "Vietnamese"
    gen white = ethnicity == "White/Caucasian"
    gen othereth = !mi(ethnicity) & !(chinese | latx | oasian | viet | white)
    gen asian = chinese + oasian + viet
    * prev cumulative gpa
    gen prev_cumgpa_unobs = mi(prev_cumgpa)
    replace prev_cumgpa = 0 if mi(prev_cumgpa) // prev_cumgpa is interaction of obs * gpa
    * whether pass a course
    capture drop pass
    gen pass = inlist(substr(assigned_grade, 1, 1), "A", "B", "C", "P")
    replace pass = . if mi(finalscore)
    * whether take 100A for letter
    capture drop letter_option
    gen letter_option = inlist(substr(assigned_grade, 1, 1), "A", "B", "C", "D", "F")
    replace letter_option = . if mi(finalscore)
    * sum of attendance
    capture drop attendance
    gen attendance = attend1 + attend2 + attend3 + attend4 + attend5 + attend6 + attend7
    * nclass_np
    foreach p in "winter_" "" {
        capture drop `p'nclass_np
        gen `p'tot_class = `p'nclass_letter + `p'nclass_pnp + `p'nclass_w
        gen `p'nclass_np = `p'tot_class - `p'nclass_p - `p'nclass_w // where are incompletes counted?
        gen `p'pclass_letter = `p'nclass_letter / (`p'nclass_letter + `p'nclass_pnp)
        gen `p'pclass_pnp = `p'nclass_pnp / (`p'nclass_letter + `p'nclass_pnp)
    }
    end

* get score variables into standard deviation units
program get_std_units
    *** return std units for 100A vars
    local oldvars "mathquiz mid1score mid2score finalscore"
    foreach v in `oldvars' {
        capture drop `v'std
        gen `v'std = .
        forvalues y = 2018/2019 {
            qui sum `v' if year == `y' & arm == 1
            replace `v'std = (`v' - r(mean)) / r(sd) if year == `y'
        }
    }

    *** return std units for 100B vars if they exist
    capture confirm variable mid1_100b
    if !_rc {
        local oldvars "mid1_100b mid2_100b final_100b"
        foreach v in `oldvars' {
            capture drop `v'std
            gen `v'std = .
            forvalues y = 2018/2019 {
                qui sum `v' if year == `y' & arm == 1
                replace `v'std = (`v' - r(mean)) / r(sd) if year == `y'
            }
        }
    }
    end

// %%
* Label variables

capture program drop label_vars

* label vars

program label_vars
    capture label var mathquizstd "Math Quiz score"
    capture label var mid1scorestd "Midterm 1 score"
    capture label var mid2scorestd "Midterm 2 score"
    capture label var finalscorestd "Final exam score"
    capture label var treated "Treated"
    capture label var mid1_100bstd "100B Midterm 1 score"
    capture label var mid2_100bstd "100B Midterm 2 score"
    capture label var final_100bstd "100B Final score"
    capture label var duration_mid1 "Duration, videos before mid1"
    capture label var duration_mid2 "Duration, videos before mid2"
    capture label var duration_final "Duration, videos before final"
    capture label var duration_mid1_u "Duration, unique videos before mid1"
    capture label var duration_mid2_u "Duration, unique videos before mid2"
    capture label var duration_final_u "Duration, unique videos before final"
    capture label var videos_mid1 "Num. videos before mid1"
    capture label var videos_mid2 "Num. videos before mid2"
    capture label var videos_final "Num. videos before final"
    capture label var videos_mid1_u "Num. unique videos before mid1"
    capture label var videos_mid2_u "Num. unique videos before mid2"
    capture label var videos_final_u "Num. unique videos before final"
    capture label var pset_pre "PSET"
    capture label var transfer "Transfer Student"
    capture label var prev_cumgpa "Prev. GPA"
    capture label var male "Male"
    capture label var female "Female"
    capture label var othergen "Other gender/not spec."
    capture label var asian "Asian"
    capture label var chinese "Chinese"
    capture label var latx "Latinx"
    capture label var viet "Vietnamese"
    capture label var oasian "Other Asian"
    capture label var latx "Latinx"
    capture label var white "White"
    capture label var othereth "Other ethnicity/not spec."
    end

// %%
* Linear models

foreach v in reg_no_ctrls reg_all reg_pairs reg_pairs_fe reg_four { 
    capture program drop `v'
}

* all observations, no controls
program reg_no_ctrls
    args y
    reg `y' treated mid1scorestd i.year if arm > 0, robust
    end

* all observations, no controls
program reg_all
    args y
    reg `y' treated mid1scorestd i.year $ctrl_vars if arm > 0, robust
    end

* matching pairs only
program reg_pairs
    args y bothpairs
    reg `y' treated mid1scorestd i.year $ctrl_vars if arm > 0 & `bothpairs', robust
    end

* matching pairs with pairyear FEs
program reg_pairs_fe
    args y bothpairs
    areg `y' treated mid1scorestd if arm > 0 & `bothpairs', robust absorb(pairyear)
    end

* run all four regs
program reg_four
    args y name bothpairs
    reg_no_ctrls `y'
    eststo `name'1
    estadd local controls "{No}"
    estadd local pairfe "{No}"

    reg_all `y'
    eststo `name'2
    estadd local controls "{Yes}"
    estadd local pairfe "{No}"

    reg_pairs `y' `bothpairs'
    eststo `name'3
    estadd local controls "{Yes}"
    estadd local pairfe "{No}"

    reg_pairs_fe `y' `bothpairs'
    eststo `name'4
    estadd local controls "{No}"
    estadd local pairfe "{Yes}"
    end

// %%
* plotting and export functions

capture program drop export_img

program export_img
    args name
    graph export ".\tex\plots\\`name'.pdf", name(`name') replace
    end

// %% [markdown]
// ## Attrition
//
// In this section we examine attrition from the experiment

// %%
* get data

get_idyearlevel
get_std_units
merge_dem
clean_dem
label_vars

// %%
* examine attrition between experiment start and end
* (for those who did not opt of sharing their data)

di "Started experiment:"
tab treated arm // started experiment

di "Took midterm 2:"
tab treated arm if !mi(mid2score) // made it to second midterm

di "Took final (and completed experiment):"
tab treated arm if !mi(finalscore) & !mi(finalscore) // made it to end

// %% [markdown]
// ### Attrition for those below the median

// %%
* generate attrition coefplot

eststo clear
local filename = "attritecoefplot"
capture drop attrite
gen attrite = mi(finalscore)
logit attrite ibn.arm, nocons vce(robust) or
est store m1
reg attrite ibn.arm, nocons robust
est store m2
coefplot (m1, eform) m2, vert yline(0, lpattern("dash")) ///
    order(1* 2* 0*) drop(*year*) ///
    title("Attrition before Final by Treatment Arm") ///
    ytitle("Odds Ratio/Percent") ///
    legend(order(2 "Logit" 4 "OLS") pos(2) ring(0) col(1) region(lstyle(none))) ///
    name(`filename', replace)

export_img `filename'


* check midterm 2 attrition

eststo clear
local filename = "attritecoefplot_mid2"
capture drop attrite
gen attrite = mi(mid2score)
logit attrite ibn.arm, nocons vce(robust) or
est store m1
reg attrite ibn.arm, nocons robust
est store m2
coefplot (m1, eform) m2, vert yline(0, lpattern("dash")) ///
    order(1* 2* 0*) drop(*year*) ///
    title("Attrition before Midterm 2 by Treatment Arm") ///
    ytitle("Odds Ratio/Percent") ///
    legend(order(2 "Logit" 4 "OLS") pos(2) ring(0) col(1) region(lstyle(none))) ///
    name(`filename', replace)

export_img `filename'

// %%
/* Nonparametric attrition
   Note: confidence bands are tighter to the right of the cutoff 
   because there are twice as many observations per bin.
*/

local filename = "attritebinscatter"
qui sum mid1scorestd if arm > 0
local cutoff = r(max)
sort mid1scorestd
capture drop attrite
gen attrite = mi(finalscore)
binsreg attrite mid1scorestd, by(arm) cb(2, 2) nbins(5) ///
    yline(0, lpattern("dash") lcol("black")) ///
    xline(`cutoff', lpattern("dash") lcol("black")) ///
    legend(order(3 "Control" 5 "Treated" 1 "Above Median") ///
        pos(10) ring(0) region(lstyle(none)) col(3)) ///
    title("Probability of Attrition before" "Final vs Midterm 1 Score") ///
    ytitle("Probability") ///
    xtitle("Normalized Midterm 1 score") ///
    bycolors(green navy cranberry) ///
    name(`filename', replace)

export_img `filename'


* check midterm 2

local filename = "attritebinscatter_mid2"
qui sum mid1scorestd if arm > 0
local cutoff = r(max)
sort mid1scorestd
capture drop attrite
gen attrite = mi(mid2score)
binsreg attrite mid1scorestd, by(arm) cb(2, 2) nbins(5) ///
    yline(0, lpattern("dash") lcol("black")) ///
    xline(`cutoff', lpattern("dash") lcol("black")) ///
    legend(order(3 "Control" 5 "Treated" 1 "Above Median") ///
        pos(10) ring(0) region(lstyle(none)) col(3)) ///
    title("Probability of Attrition before" "Midterm 2 vs Midterm 1 Score") ///
    ytitle("Probability") ///
    xtitle("Normalized Midterm 1 score") ///
    bycolors(green navy cranberry) ///
    name(`filename', replace)

export_img `filename'

// %% [markdown]
// ### Attrition at the cutoff
// Use regression discontinuity to see if attrition different at the cutoff

// %%
* Estimate RDs

eststo clear

di "RD for treated vs above median (not including control below median):"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
capture drop attrite
gen attrite = mi(finalscore)
rdrobust attrite mid1scorestd if arm != 1, c(`cutoff') ///
    p(2) kernel(tri)
eststo m1

// check whole sample in case being in experiment itself affected attrition
di "RD for whole sample (including control below median):"
rdrobust attrite mid1scorestd, c(`cutoff') p(2) kernel(tri)
eststo m2

di "RD for midterm 2, treated vs above median (not including control):"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
capture drop attrite
gen attrite = mi(mid2score)
rdrobust attrite mid1scorestd if arm != 1, c(`cutoff') ///
    p(2) kernel(tri)
eststo m3

// check whole sample in case being in experiment itself affected attrition
di "RD for whole sample (including control below median):"
rdrobust attrite mid1scorestd, c(`cutoff') p(2) kernel(tri)
eststo m4

// TODO : generate rd attrition table

// %%
* plot RD

local filename = "attriterd"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot attrite mid1scorestd if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(5) ///
    graph_options(name(`filename', replace) ///
    title("Probablility of Attrition before Final") ///
    yline(0, lpattern("dash") lcol("black")) ///
    legend(off) xtitle("Normalized Midterm 1 score") ytitle("Probability"))

export_img `filename'


* midterm 2

local filename = "attriterd"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot attrite mid1scorestd if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(5) ///
    graph_options(name(`filename', replace) ///
    title("Probablility of Attrition before Final") ///
    yline(0, lpattern("dash") lcol("black")) ///
    legend(off) xtitle("Normalized Midterm 1 score") ytitle("Probability"))

export_img `filename'

// %% [markdown]
// ## Balance
// In this section we ensure the treatment and control arms are balanced on observable characteristics.

// %%
* get data and merge demographic vars

qui get_idyearlevel
qui get_std_units
qui merge_dem
qui clean_dem
qui label_vars

// %%
sum male female othergen if !mi(mid2scorestd)
tab othergen if !mi(finalscorestd)

// %%
** Generate balance tables

* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar arm str32 exam bothpairs mean stderr N

frames dir

* vars to check balance
local balance_vars mid1scorestd y2019 ///
    prev_cumgpa prev_cumgpa_unobs mathquizstd pset_pre ///
    videos_mid1 videos_mid1_u duration_mid1 duration_mid1_u ///
    asian latx white othereth female male transfer
replace prev_cumgpa = . if prev_cumgpa_unobs
order `balance_vars'
sum `balance_vars'


* Get balance table data
* Loop over exams
foreach exam in mid2 final {
    
    * loop through all variables and post info to `results'
    * first all obs
    capture restore
    preserve
    keep if !mi(`exam'scorestd)

    foreach v in `balance_vars' {
        forvalues i = 0/2 {
            qui sum `v' if arm == `i'
            frame post results ("`v'") (`i') ("`exam'") (0) (r(mean)) (r(sd) / sqrt(r(N))) (r(N))
        }
    }

    * second, matching pairs only
    keep if bothpairs_`exam'
    foreach v in `balance_vars' {
        forvalues i = 1/2 {
            qui sum `v' if arm == `i'
            frame post results ("`v'") (`i') ("`exam'") (1) (r(mean)) (r(sd) / sqrt(r(N))) (r(N))
        }
    }
    restore
}

frame results: li


* Export the results data for publication
frame results: export delimited "./data/generated/balance_table_data.csv"

// %% [markdown]
// ## Base models
//
// Here we use the repeated sampling approach of Neyman to calculate confidence intervals, and fit a linear model that has no additional controls beyond those used to assign treatment.

// %%
/* Outcomes of interest:

- First stage
videos_b4_mid2_relu
duration_b4_mid2_relu
videos_rel_u
duration_rel_u

- Second stage
midterm2 score
final exam score

- Tests of exclusion restriction/spillovers to other studying
letter_option (did treatment affect decision to take 100A for letter grade?)
attendance
piazza questions
piazza answers
piazza views
pset visits (post)

- Spillover outcomes, concurrent quarter
gpa in all gpa-affecting courses
gpa, excluding 100A
gpa, non-econ courses
gpa, only econ courses excluding 100A
units taken for letter grade
units taken p/np
units withdrawn
n classes passed
n classes not passed
n class withdrawn
n classes taken p/np
n classes taken letter

- Spillovers, following quarter
took100b
videos_rel_u_100b
duration_rel_u_100b
midterm1 100B
midterm2 100B
final exam 100B
winter gpa all, excluding 100b, excluding all econ, econ excluding 100b
winter units taken letter, p/np, w
winter n classes pass, not passed, w
winter n classes taken letter, p/np
*/

// %% [markdown]
// ### ITT

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

sum

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str32 model

frames dir

// %%
* define function to calculate difference in means and Neyman SEs

capture program drop neyman
program define neyman
    args y exam
    preserve

    * restrict sample
    keep if bothpairs_`exam' & arm > 0

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * reshape wide
    keep pairyear `y' treated
    reshape wide `y', i(pairyear) j(treated)

    * take difference in means
    gen diff = `y'1 - `y'0

    * get point estimate
    qui sum diff
    local meandiff = r(mean)
    
    * calc standard error estimate
    * SE_hat = [1/(J(J-1)) * sum(diff_j - diff_bar) ^ 2] ^ 0.5
    gen diff2 = (diff - `meandiff') ^ 2
    qui sum diff2
    local sumdiff2 = r(sum)
    local J = `N' / 2
    local se_hat = (1 / `J' / (`J' - 1) * `sumdiff2') ^ 0.5

    * post to frame
    frame post results ("`y'") (`meanctrl') (`meandiff') (`se_hat') (`N') ("Neyman")

    restore
    end

* test cases
// neyman mid2scorestd mid2
// neyman finalscorestd final
// frame results: li

// %%
* Write function to estimate linear model only controlling for treatment assignment method

capture program drop get_itt
program define get_itt
    args y exam
    preserve

    * restrict sample
    keep if !mi(`exam'scorestd)
    keep if !mi(`y') & arm > 0

    * mean control group
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * fit model
    reg `y' treated mid1scorestd y2019, robust
    
    * post to frame
    frame post results ("`y'") (`meanctrl') (_b[treated]) (_se[treated]) (e(N)) ("itt")

    restore
    end

* test cases
// get_itt mid2scorestd mid2
// get_itt finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars
// TODO: add 100b video vars

local mid2vars videos_mid2_u ///
    videos_mid2 duration_mid2_u duration_mid2 mid2scorestd

local finalvars videos_final_u videos_final duration_final_u duration_final /// 
    finalscorestd ///
    letter_option attendance pset_post ///
    piazza_questions piazza_answers piazza_views piazza_daysonline ///
    gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a ///
    units_letter units_pnp units_w ///
    nclass_p nclass_np nclass_w nclass_letter nclass_pnp pclass_letter pclass_pnp ///
    took100b ///
    winter_gpa_letter winter_gpa_letter_sans100a winter_gpa_letter_sansecon winter_gpa_econ_sans100a ///
    winter_units_letter winter_units_pnp winter_units_w ///
    winter_nclass_p winter_nclass_np winter_nclass_w ///
    winter_nclass_letter winter_nclass_pnp winter_pclass_letter winter_pclass_pnp

local finalvarsb videos_u_b duration_u_b final_100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui neyman `v' mid2
    qui get_itt `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui neyman `v' final
    qui get_itt `v' final
}


* Dependent vars observed at the end of 100B
capture drop bothpairs_finalb
rename final_100bstd finalbscorestd
gen bothpairs_finalb = !mi(finalbscorestd)
bys pair year: ereplace bothpairs_finalb = sum(bothpairs_finalb)
replace bothpairs_finalb = bothpairs_finalb >= 2
foreach v in `finalvarsb' {
    qui neyman `v' finalb
    qui get_itt `v' finalb
}
rename finalbscorestd final_100bstd


* Dependent vars observed in the middle of 100B
capture drop bothpairs_mid1b bothpairs_mid2b
forvalues i = 1/2 {
    di "`i'"
    rename mid`i'_100bstd mid`i'bscorestd
    gen bothpairs_mid`i'b = !mi(mid`i'bscorestd)
    bys pair year: ereplace bothpairs_mid`i'b = sum(bothpairs_mid`i'b)
    replace bothpairs_mid`i'b = bothpairs_mid`i'b >= 2
    qui neyman mid`i'bscorestd mid`i'b
    qui get_itt mid`i'bscorestd mid`i'b
    rename mid`i'bscorestd mid`i'_100bstd
}


* see results
frame results: li

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/itt_coeffs.csv"

// %% [markdown]
// ### LATE

// %%
* We'll use ivregress for the base model and a custom function for the Neyman model

* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str32 model

frames dir

// %%
* define function for ivregress

capture program drop est_late
program define est_late
    args y exam

    capture restore
    preserve

    * restrict sample
    qui keep if !mi(`y') & arm > 0

    * adjust units of videos_
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local ctrlmean = r(mean)

    * estimate iv, twice
    qui ivregress 2sls `y' mid1scorestd y2019 (videos_`exam'_u = treated), vce(robust)
    local late_v = _b[videos_`exam'_u]
    local se_v = _se[videos_`exam'_u]
    qui ivregress 2sls `y' mid1scorestd y2019 (duration_`exam'_u = treated), vce(robust)
    local late_d = _b[duration_`exam'_u]
    local se_d = _se[duration_`exam'_u]

    * post to frame, twice
    frame post results ("`y'") (`ctrlmean') (`late_v') (`se_v') (`N') ("late_v")
    frame post results ("`y'") (`ctrlmean') (`late_d') (`se_d') (`N') ("late_d")

    restore
    end

* test cases
// est_late mid2scorestd mid2
// est_late finalscorestd final
// frame results: li

// %%
* define function to calculate difference in means and Neyman SEs


capture program drop neyman_late
program define neyman_late
    args y exam
    preserve

    * restrict sample
    qui keep if bothpairs_`exam' & arm > 0

    * adjust units of videos_
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local ctrlmean = r(mean)

    * reshape wide
    qui keep pairyear `y' treated videos_`exam'_u duration_`exam'_u
    qui reshape wide `y' videos_`exam'_u duration_`exam'_u, i(pairyear) j(treated)

    * take difference in means for itt and first stages
    gen itt = `y'1 - `y'0
    gen fs_v = videos_`exam'_u1 - videos_`exam'_u0
    gen fs_d = duration_`exam'_u1 - duration_`exam'_u0

    * get point estimate
    foreach v in itt fs_v fs_d {
        qui sum `v'
        local meandiff_`v' = r(mean)
    }
    local late_v = `meandiff_itt' / `meandiff_fs_v'
    local late_d = `meandiff_itt' / `meandiff_fs_d'
    
    * calc standard error estimates
    * SE_hat = [1/(J(J-1)) * sum(diff_j - diff_bar) ^ 2] ^ 0.5
    local J = `N' / 2
    foreach v in itt fs_v fs_d {
        capture drop diff2
        gen diff2 = (`v' - `meandiff_`v'') ^ 2
        qui sum diff2
        local se_hat_`v' = (1 / `J' / (`J' - 1) * r(sum)) ^ 0.5
    }

    * SE for LATE approx b1/b2 sqrt( V(b1)/b1^2 + V(b2)/b2^2 - 2 * cov(b1, b2) / (b1 * b2) )
    * do this calc twice for each meandiff_fs

    foreach x in "v" "d" {
        qui correlate itt fs_`x', covariance
        local cov_`x' = 0 // r(cov_12) is wrong
        local se_`x' = (`meandiff_itt' / `meandiff_fs_`x'') * ///
            sqrt((`se_hat_itt' ^ 2) / (`meandiff_itt' ^ 2) + (`se_hat_fs_`x'' ^ 2) / (`meandiff_fs_`x'' ^ 2) - ///
            2 * `cov_`x'' / (`meandiff_itt' * `meandiff_fs_`x''))
    }

    * post to frame, twice
    frame post results ("`y'") (`ctrlmean') (`late_v') (`se_v') (`N') ("N_late_v")
    frame post results ("`y'") (`ctrlmean') (`late_d') (`se_d') (`N') ("N_late_d")

    restore
    end

* test cases
// neyman_late mid2scorestd mid2
// neyman_late finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars for which we estimate LATEs
// TODO: add 100b video vars

local mid2vars mid2scorestd

local finalvars finalscorestd 


* 100B outcomes
local finalvarsb final_100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui est_late `v' mid2
    qui neyman_late `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui est_late `v' final
    qui neyman_late `v' final
}

* TODO: 100B LATEs

* see results
frame results: li

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/lates_coeffs.csv"

// %%
* Bootstrap standard errors

* Not using this becuase dist variance may not be finite
* TODO: look into altenative options, perhaps parametric bootstrap, using
* percentiles, etc.

capture program drop neyman_boot
program define neyman_boot 
    args y exam iters
    capture frame change default
    capture restore
    preserve

    * restrict sample
    keep if bothpairs_`exam' & arm > 0

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    local J = `N' / 2

    * reshape wide
    qui keep pairyear `y' treated videos_`exam'_u duration_`exam'_u
    qui reshape wide `y' videos_`exam'_u duration_`exam'_u, i(pairyear) j(treated)

    * take difference in means for itt and first stages
    gen itt = `y'1 - `y'0
    gen fs_v = videos_`exam'_u1 - videos_`exam'_u0
    gen fs_d = duration_`exam'_u1 - duration_`exam'_u0

    * get point estimate
    foreach v in itt fs_v fs_d {
        qui sum `v'
        local meandiff_`v' = r(mean)
    }
    local late_v = `meandiff_itt' / `meandiff_fs_v'
    local late_d = `meandiff_itt' / `meandiff_fs_d'

    * now resample `iters' times and store "LATE" estimates each round
    * store in frame `sim'. Each draw in draws
    capture frame drop sim
    frame create sim iter late_v late_d
    keep itt fs_v fs_d
    forvalue i = 1/`iters' {
        capture frame drop copyf
        frame copy default copyf
        frame change copyf
        bsample
        foreach v in itt fs_v fs_d {
            qui sum `v'
            local meandiff_`v' = r(mean)
        }
        local late_v_s = `meandiff_itt' / `meandiff_fs_v'
        local late_d_s = `meandiff_itt' / `meandiff_fs_d'
        frame post sim (`i') (`late_v_s') (`late_d_s')
        frame change default
    }
    frame sim: sum
    frame change sim
    histogram late_d, bin(50)
    frame change default
    
    frame sim: qui sum late_v
    local se_v = r(sd)
    frame sim: qui sum late_d
    local se_d = r(sd)

    * post to frame, twice
    frame post results ("`y'") (`late_v') (`se_v') (`N') ("N_boot_v")
    frame post results ("`y'") (`late_d') (`se_d') (`N') ("N_boot_d")

    frame change default
    restore
    end

* test cases
// neyman_boot mid2scorestd mid2 10000
// neyman_late finalscorestd final
// frame results: li

* Distribution (perhaps) does not have finite variance, std err does not converge

// ivregress 2sls mid2scorestd mid1scorestd y2019 (duration_mid2_u = treated) if arm > 0, vce(bootstrap, rep(10000)) nodots

// %% [markdown]
// ## Post-Double-Selection (control var selection)
// Here we use Belloni, Chernozhukov, and Hansen (2014)'s post-double-selection procedure to choose control variables in a principled manner. The method uses the lasso (least absolute shrinkage and selection operator) to predict, separately, outcomes of interest and treatment indicators. Then, one takes the union of the important covariates and includes them as controls in her specification of interest.
//
// Because `pdslasso` and `ivlasso`both produce coefficient estimates, we store these here as well.

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
* non linear controls?

/*
* add squares of nonbinary controls
capture drop mathquizstd2 pset_pre2 videos_b4_mid1_rel2
gen mathquizstd2 = mathquizstd * mathquizstd
gen pset_pre2 = pset_pre * pset_pre
gen videos_b4_mid1_rel2 = videos_b4_mid1_rel * videos_b4_mid1_rel
*/

// %% [markdown]
// ### ITT
//
// Here we use `pdslasso` to get control vars

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str99 ctrls str32 model

frames dir

// %%
* Model without Fixed Effects

capture program drop pds_itt
program pds_itt, eclass
    args y
    // display 
    di "`=char(10)'`=char(13)'" ///
        "****************" "`=char(10)'`=char(13)'" "PDS for `y'..." ///
        "`=char(10)'`=char(13)'" "****************" "`=char(10)'`=char(13)'"
    // run PDS
    pdslasso `y' treated (y2019 mid1scorestd $ctrl_vars) if arm > 0, ///
        partial(y2019 mid1scorestd) robust noisily
    end


* Fixed Effect models

capture program drop pds_itt_fe
program pds_itt_fe, eclass
    args y bothpairs

    di "`=char(10)'`=char(13)'" ///
        "****************" "`=char(10)'`=char(13)'" "PDS for `y' with FEs..." ///
        "`=char(10)'`=char(13)'" "****************" "`=char(10)'`=char(13)'"

    
    pdslasso `y' treated (mid1scorestd $ctrl_vars) if arm > 0 & `bothpairs', ///
        partial(mid1scorestd) fe robust noisily
    end

// %%
* define function to get coefficient and ctrls for each outcome

capture program drop get_pds
program define get_pds
    args y exam

    * no fixed effects
    preserve
    keep if !mi(`exam'scorestd)
    qui sum `y' if arm == 1
    local meany = r(mean)
    qui pds_itt `y'
    restore
    frame post results ("`y'") (`meany') (_b[treated]) (_se[treated]) (e(N)) ("`e(xselected)'") ("noFEs")

    * fixed effects
    preserve
    xtset pairyear
    keep if bothpairs_`exam'
    qui sum `y' if arm == 1
    local meany = r(mean)
    qui pds_itt_fe `y' bothpairs_`exam'
    restore
    frame post results ("`y'") (`meany') (_b[treated]) (_se[treated]) (e(N)) ("`e(xselected)'") ("FEs")
    end

* test cases
// get_pds mid2scorestd mid2
// get_pds finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars
// TODO: add duration_rel_u for three times: before mid2, at final, and at 100b final

local mid2vars videos_mid2_u ///
    videos_mid2 duration_mid2_u duration_mid2 mid2scorestd

local finalvars videos_final_u videos_final duration_final_u duration_final /// 
    finalscorestd ///
    letter_option attendance pset_post ///
    piazza_questions piazza_answers piazza_views piazza_daysonline ///
    gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a ///
    units_letter units_pnp units_w ///
    nclass_p nclass_np nclass_w nclass_letter nclass_pnp pclass_letter pclass_pnp ///
    took100b ///
    winter_gpa_letter winter_gpa_letter_sans100a winter_gpa_letter_sansecon winter_gpa_econ_sans100a ///
    winter_units_letter winter_units_pnp winter_units_w ///
    winter_nclass_p winter_nclass_np winter_nclass_w ///
    winter_nclass_letter winter_nclass_pnp winter_pclass_letter winter_pclass_pnp

local finalvarsb videos_u_b duration_u_b final_100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui get_pds `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui get_pds `v' final
}


* Dependent vars observed at the end of 100B
capture drop bothpairs_finalb
rename final_100bstd finalbscorestd
gen bothpairs_finalb = !mi(finalbscorestd)
bys pair year: ereplace bothpairs_finalb = sum(bothpairs_finalb)
replace bothpairs_finalb = bothpairs_finalb >= 2
foreach v in `finalvarsb' {
    qui get_pds `v' finalb
}
rename finalbscorestd final_100bstd


* Dependent vars observed in the middle of 100B
capture drop bothpairs_mid1b bothpairs_mid2b
forvalues i = 1/2 {
    di "`i'"
    rename mid`i'_100bstd mid`i'bscorestd
    gen bothpairs_mid`i'b = !mi(mid`i'bscorestd)
    bys pair year: ereplace bothpairs_mid`i'b = sum(bothpairs_mid`i'b)
    replace bothpairs_mid`i'b = bothpairs_mid`i'b >= 2
    qui get_pds mid`i'bscorestd mid`i'b
    rename mid`i'bscorestd mid`i'_100bstd
}


* see results
frame results: li

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/pds_coeffs.csv"

// %%
sum prev_cumgpa if prev_cumgpa_unobs

// %% [markdown]
// ### LATE
//
// Here we use `ivlasso` to get control vars

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str99 ctrls str32 model

frames dir

// %%
* Model without Fixed Effects

capture program drop pds_iv
program pds_iv
    args y exam

    ** no Fixed Effects

    * restrict sample
    preserve
    keep if !mi(`y') & arm > 0

    * adjust units of videos_
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * control mean
    qui sum `y' if arm == 1
    local meany = r(mean)

    * estimate IV using PDS, video counts
    ivlasso `y' (y2019 mid1scorestd $ctrl_vars) (videos_`exam'_u=treated), ///
        partial(y2019 mid1scorestd treated) robust noisily
    frame post results ("`y'") (`meany') (_b[videos_`exam'_u]) (_se[videos_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IV_v")

    * estimate IV using PDS, video duration
    ivlasso `y' (y2019 mid1scorestd $ctrl_vars) (duration_`exam'_u=treated), ///
        partial(y2019 mid1scorestd treated) robust noisily
    frame post results ("`y'") (`meany') (_b[duration_`exam'_u]) (_se[duration_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IV_d")


    ** Fixed Effects

    * further restrict sample and xtset
    keep if bothpairs_`exam'
    xtset pairyear

    * get control mean
    qui sum `y' if arm == 1
    local meany = r(mean)

    * estimate IV using PDS with FEs, video counts
    ivlasso `y' (y2019 mid1scorestd $ctrl_vars) (videos_`exam'_u=treated), ///
        partial(y2019 mid1scorestd treated) robust noisily
    frame post results ("`y'") (`meany') (_b[videos_`exam'_u]) (_se[videos_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IVFE_v")

    * estimate IV using PDS with FEs, video duration
    ivlasso `y' (mid1scorestd $ctrl_vars) (duration_`exam'_u=treated), ///
        partial(mid1scorestd treated) fe robust noisily
    frame post results ("`y'") (`meany') (_b[duration_`exam'_u]) (_se[duration_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IVFE_d")

    restore
    end

* test cases
// qui pds_iv mid2scorestd mid2
// qui pds_iv finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars for which we estimate LATEs
// TODO: add 100b video vars

local mid2vars mid2scorestd

local finalvars finalscorestd 

* 100B outcomes
local finalvarsb final_100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui pds_iv `v' mid2
}

* Dependent vars observed after final
foreach v in `finalvars' {
    qui pds_iv `v' final
}

* TODO: 100B LATEs

* see results
frame results: li

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/pds_iv_coeffs.csv"

// %%
* TODO: remove redundancies from section 6

// %% [markdown]
// ## Estimation of treatment effects
//
// Here we estimate:
// 1. the effect of treatment on videos watched (first stage)
// 2. the effect of treatment on exam scores (ITT)
// 3. the effect of videos watched on exam scores (LATE)

// %% [markdown]
// ### First stage
// Here we estimate the effect of treatment (ITT) on videos watched.

// %%
* get data
get_idyearlevel
get_std_units
merge_dem
clean_dem
label_vars

* gen year-specific pair identifier
gen pairyear = year * 1000 + pair
bys pairyear: gen N = _N
tab N
drop N

// %% [markdown]
// #### Plots

// %%
* histogram of unique videos watched

preserve
keep if !mi(finalscore) // only include experiment completers

local w = 2
local filename = "histrelu"
twoway (hist relevant_u if arm == 1, ///
        width(`w') color(navy%50) freq) ///	
    (hist relevant_u if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Unique relevant videos watched during experiment") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Videos watched") ///
    name(`filename', replace)

export_img `filename'

restore

// %%
* coeff plot of relevant videos watched

preserve
keep if !mi(finalscore) // only include experiment completers

local filename = "relevantcombocoefplot"
eststo clear
reg relevant_u ibn.arm i.year, nocons robust
eststo m1
reg relevant ibn.arm i.year, nocons robust
eststo m2
coefplot (m1, offset(0)) (m2, offset(0)), vert yline(0, lpattern("dash")) ///
    title("Relevant videos watched vs treatment arm") ///
    ytitle("Relevant videos watched") ///
    drop(2019.year) order(1* 2* 0*) ///
    legend(order(4 "All relevant videos" 2 "Unique relevant videos") ///
        cols(1) pos(10) ring(0) region(lcolor(none))) ///
    name(`filename', replace)

export_img `filename'

restore

// %%
* binscatter unique relevant videos watched vs mid1 score

preserve
keep if !mi(finalscore) // only include experiment completers

qui sum mid1scorestd if arm != 0
local xline = r(max)
local filename = "relevantubinscatter"
binsreg relevant_u mid1scorestd, by(arm) cb(2, 2) nbins(5) ///
    yline(0, lpattern("dash") lcol("black")) ///
    xline(`xline', lpattern("dash") lcol("black")) ///
    legend(order(3 "Control" 5 "Treated" 1 "Above Median") col(3)) ///
    title("Unique relevant videos watched vs Midterm 1 score") ///
    ytitle("Unique relevant videos watched") ///
    xtitle("Midterm 1 score (std. deviations)") ///
    bycolors(green navy cranberry) ///
    name(`filename', replace)

export_img `filename'

restore

// %% [markdown]
// #### Tables

// %%
sum mid1scorestd year $ctrl_vars if arm > 0

// %%
* Did students know their treatment status?

// todo: merge 2018 data
label var q10start "I have been randomized into the 'Video Watching' group where part of my grade is based on watching 40 videos."

tab q10start treated if arm > 0

// %%
* ITT on all relevant videos watched before final

preserve
keep if !mi(finalscore) // keep experiment completers

eststo clear
reg_four relevant_u "rel_u" bothpairs_final
reg_four relevant "rel" bothpairs_final

local notetext "\bottomrule \multicolumn{9}{@{}p{1\textwidth}} {\textit{Notes}: 'Videos watched' includes all videos watched before the final exam relevant to the course. Test score variables are normalized by the control mean and standard deviation. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively.} \end{tabular} \end{table}"

esttab rel_u1 rel_u2 rel_u3 rel_u4 rel1 rel2 rel3 rel4 using ./tex/tables/firststage_allrel.tex, ///
    cell(b(star f(%9.2f)) se(par)) /// 
    alignment(S) ///
    stats(N controls pairfe, label("N" "Controls" "Pair Fixed Effects") fmt(0) layout("\multicolumn{1}{c}{@}")) ///
    drop(2018.year $ctrl_vars) ///
    coeflabels(_cons "Intercept" 2019.year "Year = 2019" ) ///
    title("Effect of Being Assigned Treatment (ITT) on Relevant Videos Watched") ///
    mtitles("All Observations" "All Observations" "Matching Pairs" "Matching Pairs" ///
            "All Observations" "All Observations" "Matching Pairs" "Matching Pairs") ///
    star(* .1 ** .05 *** .01) booktabs label replace ///
    nonote ///
    postfoot("`notetext'") ///
    collabel(none) nonum ///
    mgroups("Unique Videos" "Total Videos", pattern(1 0 0 0 1 0 0 0) ///
        prefix(\multicolumn{@span}{c}{) ///
        suffix(}) span erepeat(\cmidrule(lr){@span}))

restore

// %%
sum mid2score if arm > 0

// %%
* ITT on all relevant videos watched before midterm 2

preserve
keep if !mi(mid2score) // keep those who did not attrite before mid2

eststo clear
reg_four videos_b4_mid2_relu "rel_u" bothpairs_mid2
reg_four videos_b4_mid2_rel "rel" bothpairs_mid2

local notetext "\bottomrule \multicolumn{9}{@{}p{1\textwidth}} {\textit{Notes}: 'Videos watched' includes all videos watched before the second midterm relevant to the course. Test score variables are normalized by the control mean and standard deviation. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively.} \end{tabular} \end{table}"

esttab rel_u1 rel_u2 rel_u3 rel_u4 rel1 rel2 rel3 rel4 using ./tex/tables/firststage_b4mid2rel.tex, ///
    cell(b(star f(%9.2f)) se(par)) /// 
    alignment(S) ///
    stats(N controls pairfe, label("N" "Controls" "Pair Fixed Effects") fmt(0) layout("\multicolumn{1}{c}{@}")) ///
    drop(2018.year $ctrl_vars) ///
    coeflabels(_cons "Intercept" 2019.year "Year = 2019" ) ///
    title("Effect of Being Assigned Treatment (ITT) on Relevant Videos Watched before Midterm 2") ///
    mtitles("All Observations" "All Observations" "Matching Pairs" "Matching Pairs" ///
            "All Observations" "All Observations" "Matching Pairs" "Matching Pairs") ///
    star(* .1 ** .05 *** .01) booktabs label replace ///
    nonote ///
    postfoot("`notetext'") ///
    collabel(none) nonum ///
    mgroups("Unique Videos" "Total Videos", pattern(1 0 0 0 1 0 0 0) ///
        prefix(\multicolumn{@span}{c}{) ///
        suffix(}) span erepeat(\cmidrule(lr){@span}))

restore

// %%
* ITT on all duration of videos watched

capture restore
preserve
keep if !mi(mid2score) // keep those who did not attrite before mid2

replace duration_u = duration_u / 3600 // hours
replace duration_rel = duration_rel / 3600 // hours

eststo clear
reg_four duration_u "dur_u" bothpairs_final
reg_four duration_rel "dur_rel" bothpairs_mid2

local notetext "\bottomrule \multicolumn{9}{@{}p{1\textwidth}} {\textit{Notes}: 'Videos watched' includes all videos watched before the second midterm relevant to the course. Test score variables are normalized by the control mean and standard deviation. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively.} \end{tabular} \end{table}"

esttab dur_u* dur_rel* using ./tex/tables/firststage_duration.tex, ///
    cell(b(star f(%9.2f)) se(par)) /// 
    alignment(S) ///
    stats(N controls pairfe, label("N" "Controls" "Pair Fixed Effects") fmt(0) layout("\multicolumn{1}{c}{@}")) ///
    drop(2018.year $ctrl_vars) ///
    coeflabels(_cons "Intercept" 2019.year "Year = 2019" ) ///
    title("Effect of Being Assigned Treatment (ITT) on Duration of Videos Wathced") ///
    mtitles("All Observations" "All Observations" "Matching Pairs" "Matching Pairs" ///
            "All Observations" "All Observations" "Matching Pairs" "Matching Pairs") ///
    star(* .1 ** .05 *** .01) booktabs label replace ///
    nonote ///
    postfoot("`notetext'") ///
    collabel(none) nonum ///
    mgroups("Unique Videos" "Total Videos", pattern(1 0 0 0 1 0 0 0) ///
        prefix(\multicolumn{@span}{c}{) ///
        suffix(}) span erepeat(\cmidrule(lr){@span}))

restore

// %% [markdown]
// ### Second stage
// Here we estimate the effect of treatment (ITT) and videos (LATE) on exam scores.

// %% [markdown]
// #### Plots

// %% [markdown]
// ##### Scatter plots

// %%
*** scatter final exam vs mid1

preserve
keep if bothpairs_final

* linear fit
local filename = "finalscatterlin"
twoway (scatter finalscorestd mid1scorestd if arm == 1, msize(vsmall) mcol(navy%60) mlc(%0)) ///
    (scatter finalscorestd mid1scorestd if arm == 2, msize(vsmall) mcol(cranberry%60) mlc(%0)) ///
    (scatter finalscorestd mid1scorestd if arm == 0, msize(vsmall) mcol(green%60) mlc(%0)) ///
    (lfit finalscorestd mid1scorestd if arm == 1, msize(vsmall) lcol(navy)) ///
    (lfit finalscorestd mid1scorestd if arm == 2, msize(vsmall) lcol(cranberry)) ///
    (lfit finalscorestd mid1scorestd if arm == 0, msize(vsmall) lcol(green)), ///
    legend(order(1 "Control" 2 "Treated" 3 "Above Median") col(3)) ///
    title("Final vs Midterm 1 Scores") ///
    ytitle("Final exam score (std. dev.)") ///
    xtitle("Midterm 1 score (std. dev.)") ///
    name(`filename', replace)
export_img `filename'

* lowess 
local filename = "finalscatterlowess"
twoway (scatter finalscorestd mid1scorestd if arm == 1, msize(vsmall) mcol(navy%60) mlc(%0)) ///
    (scatter finalscorestd mid1scorestd if arm == 2, msize(vsmall) mcol(cranberry%60) mlc(%0)) ///
    (scatter finalscorestd mid1scorestd if arm == 0, msize(vsmall) mcol(green%60) mlc(%0)) ///
    (lowess finalscorestd mid1scorestd if arm == 1, bw(0.8) msize(vsmall) lcol(navy)) ///
    (lowess finalscorestd mid1scorestd if arm == 2, bw(0.8) msize(vsmall) lcol(cranberry)) ///
    (lowess finalscorestd mid1scorestd if arm == 0, bw(0.8) msize(vsmall) lcol(green)), ///
    legend(order(1 "Control" 2 "Treated" 3 "Above Median") col(3)) ///
    title("Final vs Midterm 1 Scores, lowess") ///
    ytitle("Final exam score (std. dev.)") ///
    xtitle("Midterm 1 score (std. dev.)") ///
    name(`filename', replace)
export_img `filename'

restore

// %%
*** scatter mid2 vs mid1

preserve
keep if bothpairs_mid2

* linear fit
local filename = "mid2scatterlin"
twoway (scatter mid2scorestd mid1scorestd if arm == 1, msize(vsmall) mcol(navy%60) mlc(%0)) ///
    (scatter mid2scorestd mid1scorestd if arm == 2, msize(vsmall) mcol(cranberry%60) mlc(%0)) ///
    (scatter mid2scorestd mid1scorestd if arm == 0, msize(vsmall) mcol(green%60) mlc(%0)) ///
    (lfit mid2scorestd mid1scorestd if arm == 1, msize(vsmall) lcol(navy)) ///
    (lfit mid2scorestd mid1scorestd if arm == 2, msize(vsmall) lcol(cranberry)) ///
    (lfit mid2scorestd mid1scorestd if arm == 0, msize(vsmall) lcol(green)), ///
    legend(order(1 "Control" 2 "Treated" 3 "Above Median") col(3)) ///
    title("Midterm 2 vs Midterm 1 Scores") ///
    ytitle("Midterm 2 score (std. dev.)") ///
    xtitle("Midterm 1 score (std. dev.)") ///
    name(`filename', replace)
export_img `filename'

* lowess 
local filename = "mid2scatterlowess"
twoway (scatter mid2scorestd mid1scorestd if arm == 1, msize(vsmall) mcol(navy%60) mlc(%0)) ///
    (scatter mid2scorestd mid1scorestd if arm == 2, msize(vsmall) mcol(cranberry%60) mlc(%0)) ///
    (scatter mid2scorestd mid1scorestd if arm == 0, msize(vsmall) mcol(green%60) mlc(%0)) ///
    (lowess mid2scorestd mid1scorestd if arm == 1, bw(0.8) msize(vsmall) lcol(navy)) ///
    (lowess mid2scorestd mid1scorestd if arm == 2, bw(0.8) msize(vsmall) lcol(cranberry)) ///
    (lowess mid2scorestd mid1scorestd if arm == 0, bw(0.8) msize(vsmall) lcol(green)), ///
    legend(order(1 "Control" 2 "Treated" 3 "Above Median") col(3)) ///
    title("Midterm 2 vs Midterm 1 Scores, lowess") ///
    ytitle("Midterm 2 score (std. dev.)") ///
    xtitle("Midterm 1 score (std. dev.)") ///
    name(`filename', replace)
export_img `filename'

restore

// %% [markdown]
// ##### Quantile Regression

// %%
* final 

local filename = "finalquantreg"
tempfile temp
sqreg finalscorestd treated mid1scorestd if arm > 0, ///
    quantile(.05 .25 .5 .75 .95) reps(100) 
grqreg treated, ci ols olsci seed(1887) save(`temp') 
preserve
use `temp', clear
tw (rarea treated_cihi treated_cilo qtile, col(gs13)) ///
    (line treated qtile) (line ols_treated qtile if qtile <= 0.06 | qtile >= 0.94, ///
        lpattern("dash")), ///
    title("Quantile effects of being assigned" "treatment on final exam scores") ///
    legend(col(1) ring(0) order(2 "QITE estimates" 3 "OLS estimate")) ///
    ytitle("Final exam std. deviations") ///
    xtitle("Quantile") ///
    name(`filename', replace)
export_img `filename'
restore

* midterm 2

local filename = "mid2quantreg"
tempfile temp2
sqreg mid2scorestd treated mid1scorestd if arm > 0, ///
    quantile(.05 .25 .5 .75 .95) reps(100) 
grqreg treated, ci ols olsci seed(1887) save(`temp2') 
preserve
use `temp2', clear
tw (rarea treated_cihi treated_cilo qtile, col(gs13)) ///
    (line treated qtile) (line ols_treated qtile if qtile <= 0.06 | qtile >= 0.94, ///
        lpattern("dash")), ///
    title("Quantile effects of being assigned" "treatment on midterm 2 scores") ///
    legend(col(1) ring(0) order(2 "QTE estimates" 3 "OLS estimate")) ///
    ytitle("Midterm 2 std. deviations") ///
    xtitle("Quantile") ///
    name(`filename', replace)
export_img `filename'
restore

// %% [markdown]
// ##### Regression discontinuity

// %%
preserve
keep if bothpairs_final

* final
local filename = "rdplotfinal"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot finalscorestd mid1scorestd i.year if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(10) ///
    graph_options(name(`filename', replace) ///
    title("Effect of Treatement (ITT) at the cutoff on Final exam scores") ///
    legend(off) xtitle("Normalized Midterm 1 score") ///
    ytitle("Normalized Final exam score"))
export_img `filename'

restore

preserve
keep if bothpairs_mid2

* midterm 2
local filename = "rdplotmid2"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot mid2scorestd mid1scorestd i.year if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(10) ///
    graph_options(name(`filename', replace) ///
    title("Effect of Treatement (ITT) at the cutoff on Midterm 2 scores") ///
    legend(off) xtitle("Normalized Midterm 1 score") ///
    ytitle("Normalized Midterm 2 score"))
export_img `filename'

restore

// %% [markdown]
// #### Tables

// %%
* ITT - effect of treatment on final and mid2 scores

eststo clear
reg_four finalscorestd "final" bothpairs_final
reg_four mid2scorestd "mid2" bothpairs_mid2

local notetext "\bottomrule \multicolumn{9}{@{}p{1\textwidth}} {\textit{Notes}: Test score variables are in standard deviation-units. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively.} \end{tabular} \end{table}"

esttab final1 final2 final3 final4 mid21 mid22 mid23 mid24 using ./tex/tables/itt_table.tex, ///
    cell(b(star f(%9.2f)) se(par)) /// 
    alignment(S) ///
    stats(N,  fmt(0) layout("\multicolumn{1}{c}{@}")) ///
    drop(2018.year $ctrl_vars) ///
    coeflabels(_cons "Intercept" 2019.year "Year = 2019" ) ///
    title("Effect of Being Assigned Treatment (ITT) on Test Scores") ///
    mtitles("All Observations" "All Observations" "Matching Pairs" "Matching Pairs" ///
            "All Observations" "All Observations" "Matching Pairs" "Matching Pairs") ///
    star(* .1 ** .05 *** .01) booktabs label replace ///
    nonote ///
    postfoot("`notetext'") ///
    collabel(none) nonum ///
    mgroups("Final" "Midterm 2", pattern(1 0 0 0 1 0 0 0) ///
        prefix(\multicolumn{@span}{c}{) ///
        suffix(}) span erepeat(\cmidrule(lr){@span}))

// %%
* LATE - effect of videos on final and mid2 scores

/*
Models:
1. No controls or fixed effects
2. Controls and no fixed effects
3. Controls and only keep matching pairs
4. Control and pairyear fixed effects
*/

* -- Final Exam -- *

eststo clear

ivreg2 finalscorestd mid1scorestd i.year (relevant_u = treated) ///
    if arm > 0, robust
estadd local controls "{No}"
estadd local pairfe "{No}"
eststo m1

ivreg2 finalscorestd mid1scorestd i.year $ctrl_vars (relevant_u = treated) ///
    if arm > 0, robust
estadd local controls "{Yes}"
estadd local pairfe "{No}"
eststo m2

ivreg2 finalscorestd mid1scorestd i.year $ctrl_vars (relevant_u = treated) ///
    if arm > 0 & bothpairs_final, robust
estadd local controls "{Yes}"
estadd local pairfe "{No}"
eststo m3

ivreghdfe finalscorestd (relevant_u = treated) ///
    if arm > 0 & bothpairs_final, robust absorb(pairyear)
estadd local controls "{No}"
estadd local pairfe "{Yes}"
eststo m4

* -- Midterm 2 -- *

ivreg2 mid2scorestd mid1scorestd i.year (videos_b4_mid2_relu = treated) ///
    if arm > 0, robust
estadd local controls "{No}"
estadd local pairfe "{No}"
eststo m5

ivreg2 mid2scorestd mid1scorestd i.year $ctrl_vars (videos_b4_mid2_relu = treated) ///
    if arm > 0, robust
estadd local controls "{Yes}"
estadd local pairfe "{No}"
eststo m6

ivreg2 mid2scorestd mid1scorestd i.year $ctrl_vars (videos_b4_mid2_relu = treated) ///
    if arm > 0 & bothpairs_mid2, robust
estadd local controls "{Yes}"
estadd local pairfe "{No}"
eststo m7

ivreghdfe mid2scorestd (videos_b4_mid2_relu = treated) ///
    if arm > 0 & bothpairs_mid2, robust absorb(pairyear)
estadd local controls "{No}"
estadd local pairfe "{Yes}"
eststo m8

local notetext "\bottomrule \multicolumn{9}{@{}p{1\textwidth}} {\textit{Notes}: 'Unique relevant video' variables are instrumented using exogenously assigned treatment. The first coefficient in each column is the local average treatment effect on exam score of each video induced to be watched by treatment. Test score variables are in standard deviation-units. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively.} \end{tabular} \end{table}"

esttab m* using ./tex/tables/late_table.tex, ///
    order(relu_since_mid1 relu_bt_mid1_mid2) ///
    cell(b(star f(%9.3f)) se(par)) /// 
    alignment(S) ///
    stats(N,  fmt(0) layout("\multicolumn{1}{c}{@}")) ///
    drop(2018.year $ctrl_vars) ///
    coeflabels(_cons "Intercept" 2019.year "Year = 2019" ) ///
    title("Effect of Watching Videos (LATE) on Test Scores for those induced by treatment") ///
    mtitles("All Observations" "Matching Pairs" "Matching Pairs" ///
        "All Observations" "Matching Pairs" "Matching Pairs") ///
    star(* .1 ** .05 *** .01) booktabs label replace ///
    nonote ///
    postfoot("`notetext'") ///
    collabel(none) nonum ///
    mgroups("Final" "Midterm 2", pattern(1 0 0 0 1 0 0 0) ///
        prefix(\multicolumn{@span}{c}{) ///
        suffix(}) span erepeat(\cmidrule(lr){@span}))

// %% [markdown]
// ### Heterogeneity
// In this section we see if treatment effects were greater for certain demographic groups.

// %%
* define freshman var

capture drop freshman
gen freshman = apptype == "First-Time First Year"
label var freshman "Freshman"

// %%
* Heterogeneous first stage (ITT)

/* 
Strategy:

First, intialize the latex table for one interaction term.

Then, loop over all but one remaining independent variable, 
 fitting each of the four models:
1. relevant unique, no controls
2. relevant unique, with controls
3. relevant all, no controls
4. relevant all, with controls
 and append to the existing latex table.

Finally, estimate the last interaction term and add the 
 end of the table content to the latex table.
*/


* keep only those below the median and those who took final

preserve
keep if arm > 0
keep if !mi(finalscore)


* Define estimation function
capture program drop interaction_est
program define interaction_est
    args v

    * clear stored models
    eststo clear
    
    * estimate models and store
    reg relevant_u c.treated##c.`v' mid1scorestd i.year, robust
    estadd local controls "{No}"
    eststo m1
    reg relevant_u c.treated##c.`v' mid1scorestd i.year $ctrl_vars, robust
    estadd local controls "{Yes}"
    eststo m2
    reg relevant c.treated##c.`v' mid1scorestd i.year, robust
    estadd local controls "{No}"
    eststo m3
    reg relevant c.treated##c.`v' mid1scorestd i.year $ctrl_vars, robust
    estadd local controls "{Yes}"
    eststo m4

    end


** Step 1: initialize table

interaction_est mid1scorestd

local notetext "\begin{table}[htbp] \centering \begin{threeparttable} \def\sym#1{\ifmmode^{#1}\else\(^{#1}\)\fi} \caption{Interaction effect coefficients: first stage} \begin{tabular}{l*{4}{c}} \toprule "

esttab m* using ./tex/tables/interaction_first.tex, replace ///
    keep(*treated#*) ///
    cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
    star gaps noline fragment ///
    label ///  
    collabels(none) ///   
    style(tex) ///
    noobs ///
    prehead(`notetext') ///
    posthead("\midrule") ///
    title("Interaction effect coefficients")


** Step 2: loop over all but one remaining indep. var

local indepvars mathquizstd pset_pre ///
    freshman transfer male female asian latx white

foreach v of varlist `indepvars' {
    interaction_est `v'
    
    * append to tex file
    esttab using ./tex/tables/interaction_first.tex, ///
        append ///
        keep(*treated#*) ///
        cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
        f label nomtitle nonumber collabels(none) /// 
        star gaps noline ///
        noobs 
}


** Step 3: Add remaining indep. var

local notetext "\bottomrule \end{tabular} \begin{tablenotes} \item \textit{Notes}: Each coefficient is the estimated $\beta_3$ from equation (X). Test score (outcome) variables are in standard deviation units. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively. \end{tablenotes} \end{threeparttable} \end{table}"

interaction_est othereth

esttab using ./tex/tables/interaction_first.tex, ///
    append ///
    keep(*treated#*) ///
    cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
    f label nomtitle nonumber collabels(none) /// 
    star gaps noline ///
    prefoot("\midrule") /// 
    postfoot(`notetext') ///
    substitute(\_ _)


restore

// %%
* Heterogeneous second stage (ITT)

/* 
Strategy:

First, intialize the latex table for one interaction term.

Then, loop over all but one remaining independent variable, 
 fitting each of the four models:
1. final, no controls
2. final, with controls
3. mid2, no controls
4. mid2, with controls
 and append to the existing latex table.

Finally, estimate the last interaction term and add the 
 end of the table content to the latex table.
*/


* keep only those below the median

preserve
keep if arm > 0


* Define estimation function
capture program drop interaction_est
program define interaction_est
    args v

    * clear stored models
    eststo clear
    
    * estimate models and store
    reg finalscorestd c.treated##c.`v' mid1scorestd i.year, robust
    estadd local controls "{No}"
    eststo m1
    reg finalscorestd c.treated##c.`v' mid1scorestd i.year $ctrl_vars, robust
    estadd local controls "{Yes}"
    eststo m2
    reg mid2scorestd c.treated##c.`v' mid1scorestd i.year, robust
    estadd local controls "{No}"
    eststo m3
    reg mid2scorestd c.treated##c.`v' mid1scorestd i.year $ctrl_vars, robust
    estadd local controls "{Yes}"
    eststo m4

    end


** Step 1: initialize table

interaction_est mid1scorestd

local notetext "\begin{table}[htbp] \centering \begin{threeparttable} \def\sym#1{\ifmmode^{#1}\else\(^{#1}\)\fi} \caption{Interaction effect coefficients: second stage} \begin{tabular}{l*{4}{c}} \toprule "

esttab m* using ./tex/tables/interaction_second.tex, replace ///
    keep(*treated#*) ///
    cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
    star gaps noline fragment ///
    label ///  
    collabels(none) ///   
    style(tex) ///
    noobs ///
    prehead(`notetext') ///
    posthead("\midrule") ///
    title("Interaction effect coefficients")


** Step 2: loop over all but one remaining indep. var

local indepvars mathquizstd pset_pre ///
    freshman transfer male female asian latx white

foreach v of varlist `indepvars' {
    interaction_est `v'
    
    * append to tex file
    esttab using ./tex/tables/interaction_second.tex, ///
        append ///
        keep(*treated#*) ///
        cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
        f label nomtitle nonumber collabels(none) /// 
        star gaps noline ///
        noobs 
}


** Step 3: Add remaining indep. var

local notetext "\bottomrule \end{tabular} \begin{tablenotes} \item \textit{Notes}: Each coefficient is the estimated $\beta_3$ from equation (X). Test score (outcome) variables are in standard deviation units. Standard errors are robust to heteroskedasticity. ***, **, and * indicate significance at the 1, 5, and 10 percent critical levels, respectively. \end{tablenotes} \end{threeparttable} \end{table}"

interaction_est othereth

esttab using ./tex/tables/interaction_second.tex, ///
    append ///
    keep(*treated#*) ///
    cells(b(fmt(%9.3f) star) se(fmt(3) par)) ///
    f label nomtitle nonumber collabels(none) /// 
    star gaps noline ///
    prefoot("\midrule") /// 
    postfoot(`notetext') ///
    substitute(\_ _)


restore

// %% [markdown]
// ### Spillover Effects
// In this section we investigate if treatment caused spillovers within the quarter (e.g. impacted grades in the concurrent quarter) or the next quarter (e.g. impacted grades in the second intermediate microeconomics course in the sequence).

// %% [markdown]
// #### Concurrent quarter

// %%
tab assigned_grade

// %%
sum

// %%
* effect of treatment on spillover vars

capture drop attendance
gen attendance = attend1 + attend2 + attend3 + attend4 + attend5 + attend6 + attend7

local vars gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a ///
    nclass_p nclass_np nclass_w nclass_letter nclass_pnp ///
    units_letter units_pnp units_w ///
    piazza_daysonline piazza_views piazza_questions ///
    piazza_answers piazza_contributions pset_post attendance

label var gpa_letter "Term GPA across all courses that count towards GPA"
label var gpa_letter_sans100a "Term GPA for courses that count towards GPA excluding 100A"
label var gpa_letter_sansecon "Term GPA for courses that count towards GPA excluding all econ courses"
label var gpa_econ_sans100a "Term GPA for econ courses that count excluding 100a"
label var nclass_p "Number of classes passed"
label var nclass_np "Number of classes not passed"
label var nclass_w "Number of classes withdrawn"
label var nclass_letter "Number of class taken for a lettergrade"
label var nclass_pnp "Number of class taken for P/NP"
label var units_letter "Number of units taken for a letter"
label var units_pnp "Number of units taken for P/NP"
label var units_w "Number of units withdrawn"
label var piazza_daysonline "Piazza days online"
label var piazza_views "Piazza views"
label var piazza_questions "Piazza questions asked"
label var piazza_answers "Piazza answers"
label var piazza_contributions "Piazza contributions"
label var pset_post "PSET visits during experiment (after midterm 1)"
label var attendance "Attendance across seven attendance quizzes"

preserve
keep if arm > 0
keep if !mi(finalscore)

eststo clear

foreach v of varlist `vars' {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
    eststo m`v'
}

restore

// %%
* effect of treatment on pass rates and classes taken 




foreach v in  ///
     {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %%
* effect of treatment on use of Piazza, PSET, and attendance quizzes



local varlist 
sum `varlist'

foreach v of varlist `varlist' {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %%
* effect of treatment on reported time use

label var q2end "How many exams did you have LAST WEEK?"
label var q3end "How many TOTAL hours did you spend studying for Econ 100A LAST WEEK?"
label var q4end "How many hours LAST WEEK did you spend reading the textbook for 100A?"
label var q5end "How many hours LAST WEEK did you spend watching the micro videos?"
label var q6end "How many hours LAST WEEK did you spend working through old 100A exams?"
label var q7end "I plan to attend [TA's] final exam review tonight."
label var q8end "Last week I attended class (the Tuesday before Thanksgiving)."
label var q9end "How many hours LAST WEEK did you spend with friends? "
label var q10end "I have been randomized into the 'Videos Required' group where part of my grade is based on watching 40 videos."

local varlist q2end-q10end
sum `varlist'
tab year if !mi(q2end)

foreach v of varlist `varlist' {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd, robust
}

tab q10end treated

// %% [markdown]
// #### Following quarter

// %%
* effect of treatment on taking next micro course

forvalues x = 0/2 {
    di "Arm = `x'"
    sum took100b if arm == `x'
}

reg took100b treated mid1scorestd i.year, robust
logit took100b treated mid1scorestd i.year, robust or

// %%
* effect of treatment on videos watched in next micro course

foreach v in videos_b videos_u_b duration_all_b duration_rel_b duration_u_b {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %%
* effect of treatment on exam scores in next micro course

foreach v in mid1_100bstd mid2_100bstd final_100bstd {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %%
* effect of treatment on passing next micro course

tab lettergrade_100b
capture drop gp_100b
gen gp_100b = 4 if substr(lettergrade_100b, 1, 1) == "A"
replace gp_100b = 3 if substr(lettergrade_100b, 1, 1) == "B"
replace gp_100b = 2 if substr(lettergrade_100b, 1, 1) == "C"
replace gp_100b = 1 if substr(lettergrade_100b, 1, 1) == "D"
replace gp_100b = 0 if substr(lettergrade_100b, 1, 1) == "F"
replace gp_100b = gp_100b - 0.333 if substr(lettergrade_100b, 2, 1) == "-"
replace gp_100b = gp_100b + 0.333 if substr(lettergrade_100b, 2, 1) == "+"

tab gp_100b

capture drop pass_100b
gen pass_100b = gp_100b >= 1.66

sum gp_100b if arm == 1
reg gp_100b treated mid1scorestd i.year, robust

sum pass_100b if arm == 1
reg pass_100b treated mid1scorestd i.year, robust
logit pass_100b treated mid1scorestd i.year, robust or

// %%
* merge subsequent quarter gpa and class data

capture restore
drop units_letter-nclass_w
preserve
import delimited ./data/generated/dem_nextquarter.csv, clear varnames(1)
tempfile temp
save `temp'
restore
merge 1:1 id year using `temp', nogen // keep(1 3)

// %%
* effect of treatment on GPA in subsequent quarter

foreach v in gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %%
* effect of treatment on pass rates and classes taken 

foreach v in nclass_p nclass_np nclass_w nclass_letter nclass_pnp ///
    units_letter units_pnp units_w {
    di "Effect of treatment on `v'"
    reg `v' treated mid1scorestd i.year, robust
}

// %% [markdown]
// ### Time series
//
// Here we plot the first stage as a function of time to see when students are watching videos.

// %% [markdown]
// #### Prepare data

// %%
* get data

// TODO : generate duration var

import delimited ./data/raw/DeID_video-level_data.csv, clear varnames(1)
rename deid id
drop if length_mins == "NA"
drop if mi(id)

label var incentivized "1 if video was included in grade incentive"
label var pre_mid1 "1 if video relevant to material taught before mid1"
label var mid1_to_mid2 "1 if video relevant to material taught b/t mid1 and mid2"
label var post_mid2 "1 if video relevant to material taught after mid2"
label var relevant_100a "1 if video relevant to course"
label var syllabus_week "Which week of quarter the video is most relevant per syllabus"
replace syllabus_week = "" if syllabus_week == "NA"

* generate week of year variable
gen weekoy = week(date(firstview, "MDYhm")) - 39 - 4
* experiment begins during weekoy == 0

* clean numeric variables
destring visitid length_mins-syllabus_week, replace

* keep only first unique videocode entry (to get unique count)
sort id year videocode firstview
by id year videocode: replace videocode = "" if _n > 1
encode videocode, gen(videocode_encoded)

* collapse to student-week level
keep id year weekoy visitid videocode_encoded ///
    length_mins pre_mid1 mid1_to_mid2 post_mid2 relevant_100a
collapse (count) visitid videocode_encoded ///
    (sum) length_mins pre_mid1 mid1_to_mid2 post_mid2 relevant_100a, ///
    by (id year weekoy)

// %%
*** balance panel

* get treatment arm
preserve
get_idyearlevel
keep id year arm
tempfile temp
save `temp'
restore
merge n:1 id year using `temp', keep(2 3) nogen

* generate id-year specific identifier
unique id
bysort id year: gen idyear = 1 if _n == 1
replace idyear = sum(idyear)

di "Check: next two counts should be the same"
unique idyear
unique id year

* fill with missings for id-weekoys with no obs
replace weekoy = 0 if mi(weekoy)
sum

drop id year
tsset idyear weekoy
unique idyear weekoy
unique idyear
unique weekoy
local x = 789 * 12
di "Should have `x' observations after balancing."
tsfill, full
tab weekoy

* add zeros where applicable
foreach v of varlist visitid-relevant_100a {
    replace `v' = 0 if mi(`v')
}

* add nonzeros where applicable
bys idyear: ereplace arm = min(arm)

* rename vars
rename visitid videos_watched
rename videocode_encoded unique_videos_watched

sum

// %% [markdown]
// #### Binge watching

// %%
* Histogram of most videos watched in any week

preserve
local filename = "histweek"
local w = 2
bys idyear: egen max_videos_week = max(videos_watched)
keep if weekoy == 1
twoway (hist max_videos_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_videos_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week by each student") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Most videos watched in one week") ///
    name(`filename', replace)
restore

preserve
local filename = "histweek_u"
local w = 2
bys idyear: egen unique_videos_week = max(unique_videos_watched) 
keep if weekoy == 1
twoway (hist unique_videos_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist unique_videos_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most unique videos watched in one week by each student") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Most unique videos watched in one week") ///
    name(`filename', replace)
restore

* Histogram of most videos watched in any week before mid2
preserve
local filename = "histweekmid2"
keep if inrange(weekoy, 0, 3)
capture drop max_relevant_u_week
bys idyear: egen max_relevant_u_week = max(videos_watched)
keep if weekoy == 3
local w = 2
twoway (hist max_relevant_u_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_relevant_u_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week" "before Midterm 2") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Most videos watched in one week") ///
    name(`filename', replace)
restore

preserve
local filename = "histweekfinal"
keep if weekoy >= 4
capture drop max_relevant_u_week
bys idyear: egen max_relevant_u_week = max(videos_watched)
keep if weekoy == 4
local w = 2
twoway (hist max_relevant_u_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_relevant_u_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week" "between Midterm 2 and Final") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Most videos watched in one week") ///
    name(`filename', replace)
restore

// %% [markdown]
// #### First stage

// %%
* collapse to arm-weekoy level taking means

drop idyear
collapse videos_watched-relevant_100a, by(weekoy arm)

sum

// %%
* define plot function

capture program drop plot_ts
program plot_ts
    args filename y title xtitle ytitle
    twoway (line `y' weekoy if arm == 0, lcol(green)) ///
        (line `y' weekoy if arm == 1, lcol(navy)) ///
        (line `y' weekoy if arm == 2, lcol(cranberry) ///
            xline(-1, lpattern(dash) lcolor(black)) ///
            xline(3, lpattern(dash) lcolor(black)) ///
            xline(6, lpattern(dash) lcolor(black))), ///
        legend(order(2 "Control" 3 "Treated" 1 "Above cutoff" ) col(3)) ///
        title(`title') ///
        xtitle(`xtitle') ///
        ytitle(`ytitle') ///
        xscale(range(-4 7)) ///
        xlabel(-4(1)7) ///
        xsize(2.5) ///
        ysize(2) ///
        name(`filename', replace)
    // export_img `filename'
    end

// %%
* Mean videos, all
plot_ts tsall videos_watched ///
    "Videos watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Mean videos, unique
plot_ts tsunique unique_videos_watched ///
    "Unique videos watched per week" ///
    "Weeks since experiment began" ///
    "Unique videos"

* Mean duration
plot_ts tsduration length_mins ///
    "Time spent watching per week" ///
    "Weeks since experiment began" ///
    "Minutes"

* Videos before midterm 1
plot_ts tspremid1 pre_mid1 ///
    "Videos relevant to first midterm watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Videos between mid1 and mid2
plot_ts tsmid1mid2 mid1_to_mid2 ///
    "Videos relevant to second midterm watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Videos post midterm 2
plot_ts tspostmid2 post_mid2 ///
    "Videos relevant to final exam watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

// %%
* combine plots

grc1leg tsall tspremid1 tsunique tsmid1mid2 tsduration tspostmid2, ///
    rows(3) altshrink ysize(8) xsize(5.5) name(tscombo, replace)

export_img tscombo

// %% [markdown]
// ### Video-specific differences

// %%
* Start with raw video data, collapse to arm-video level

* import and clean
import delimited ./data/raw/DeID_video-level_data.csv, clear varnames(1)
rename deid id
drop if length_mins == "NA"
drop if mi(id)
drop if syllabus_week == "NA"
destring visitid length_mins-syllabus_week, replace
gen video_duration_secs = 60 * minutes + seconds
keep id year videocode video_duration_secs incentivized-syllabus_week
gen views = 1

* collapse to student-video level
collapse (sum) views, by(id year videocode video_duration_secs incentivized-syllabus_week)

* merge arm
preserve
get_idyearlevel
// keep if complete experiment
keep if !mi(finalscore)
keep id year arm
tempfile temp
save `temp'
restore
// merge and drop videos watched by those not in sample
merge n:1 id year using `temp', nogen keep(2 3) 

* balance panel
bysort id year: gen idyear = 1 if _n == 1
replace idyear = sum(idyear)
drop id year
encode videocode, generate(vcode)
replace vcode = 1 if mi(vcode)
tsset idyear vcode
unique idyear vcode
unique idyear
unique vcode
local x = 789 * 73
di "Should have `x' observations after balancing."
tsfill, full
count
//tab vcode

* replace missings
drop videocode
bys idyear: ereplace arm = min(arm)
replace views = 0 if mi(views)
foreach v of varlist incentivized-video_duration_secs {
    bys vcode: ereplace `v' = min(`v')
}

sum

* collapse to arm-video level
drop idyear
gen conditional_views = views if views > 0
gen unique_views = views > 0
collapse (mean) unique_views views conditional_views, ///
    by(arm vcode incentivized-video_duration_secs)

label var unique_views "Perc. arm that saw video at least once"
label var views "Avg. views for that video by that arm"
label var conditional_views "Avg. views conditional on seeing the video at least once"

sum

// %%
*** Plot % of each arm viewing each video

* trim and reshape data for plotting
preserve
keep if arm > 0
gen incent = incentivized > 0
label define incent 0 "Not incentivized" 1 "Incentivized"
label values incent incent
replace syllabus_week = syllabus_week + 1
reshape wide views unique_views conditional_views, i(vcode incentivized - video_duration_secs) j(arm)
order vcode video_duration_secs incent incentivized - syllabus_week unique_views* views* conditional_views*

* ordered by incentives

capture drop ordering
sort unique_views1
bys incent: gen ordering = _n
local filename = "bar_uviews"
graph bar unique_views1 unique_views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) col(1) pos(10)) ///
    title("Fraction of arm viewing each video") ///
    ytitle("Fraction of arm") ///
    name(`filename', replace)
export_img `filename'


* ordered by syllabus_week

capture drop ordering
sort syllabus_week unique_views1
bys incent: gen ordering = _n
local filename = "bar_uviews_week"
graph bar unique_views1 unique_views2, ///
    over(ordering, sort(1) lab(nolab)) over(syllabus_week) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) col(1) pos(10)) ///
    title("Fraction of arm viewing each video") ///
    ytitle("Fraction of arm") ///
    b1title("Week of quarter") ///
    name(`filename', replace)
export_img `filename'


* Total views per person

capture drop ordering
sort unique_views1
bys incent: gen ordering = _n
local filename = "bar_views"
graph bar views1 views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) col(1) pos(10)) ///
    title("Views per person per video") ///
    ytitle("Views") ///
    name(`filename', replace)
export_img `filename'


* Conditional views per person

capture drop ordering
sort conditional_views1
bys incent: gen ordering = _n
local filename = "bar_cviews"
graph bar conditional_views1 conditional_views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) col(1) pos(10)) ///
    title("Views per person who watched at least once") ///
    ytitle("Views") ///
    name(`filename', replace)
export_img `filename'

restore

// %% [markdown]
// ## Robustness Checks

// %% [markdown]
// ### Randomization inference
//
// Randomly assign placebo treatment and estimate placebo treatment effects. Where the true treatment effect falls into the distribution of placebo treatments provides a nonparametric p-value.

// %%
* get data

get_idyearlevel
get_std_units
merge_dem
clean_dem
gen pairyear = year * 1000 + pair

// %%
* random number generated from random.org

ritest treated _b[treated], reps(5000) seed(84784) strata(year mid1scorestd): ///
    reg finalscorestd treated mid1scorestd i.year if arm > 0, robust

// %%
* repeat fixing pair assignments as strata

ritest treated _b[treated], reps(5000) seed(84784) strata(pairyear): ///
    reg finalscorestd treated mid1scorestd i.year if arm > 0, robust

// %%
* Randomization inference for midterm 2 as outcome

ritest treated _b[treated], reps(1000) seed(84784) strata(year mid1scorestd): ///
    reg mid2scorestd treated mid1scorestd i.year if arm > 0, robust

ritest treated _b[treated], reps(1000) seed(84784) strata(pairyear): ///
    reg mid2scorestd treated mid1scorestd i.year if arm > 0, robust
