// %% [markdown]
// <h1>Table of Contents<span class="tocSkip"></span></h1>
// <div class="toc"><ul class="toc-item"><li><span><a href="#Prep" data-toc-modified-id="Prep-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prep</a></span><ul class="toc-item"><li><span><a href="#Check-dependencies" data-toc-modified-id="Check-dependencies-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Check dependencies</a></span></li><li><span><a href="#Define-global-control-variable-list" data-toc-modified-id="Define-global-control-variable-list-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Define global control variable list</a></span></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Define functions</a></span></li><li><span><a href="#Label-variables" data-toc-modified-id="Label-variables-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Label variables</a></span></li></ul></li><li><span><a href="#Plotting-schemes-and-functions" data-toc-modified-id="Plotting-schemes-and-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plotting schemes and functions</a></span></li><li><span><a href="#Attrition" data-toc-modified-id="Attrition-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Attrition</a></span><ul class="toc-item"><li><span><a href="#Attrition-for-those-below-the-median" data-toc-modified-id="Attrition-for-those-below-the-median-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Attrition for those below the median</a></span></li><li><span><a href="#Attrition-at-the-cutoff" data-toc-modified-id="Attrition-at-the-cutoff-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Attrition at the cutoff</a></span></li></ul></li><li><span><a href="#Balance" data-toc-modified-id="Balance-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Balance</a></span></li><li><span><a href="#Instrument-checks" data-toc-modified-id="Instrument-checks-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Instrument checks</a></span><ul class="toc-item"><li><span><a href="#Did-students-know-their-treatment-statuses?" data-toc-modified-id="Did-students-know-their-treatment-statuses?-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Did students know their treatment statuses?</a></span></li><li><span><a href="#Relevancy" data-toc-modified-id="Relevancy-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Relevancy</a></span></li></ul></li><li><span><a href="#Base-models" data-toc-modified-id="Base-models-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Base models</a></span><ul class="toc-item"><li><span><a href="#Checks" data-toc-modified-id="Checks-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Checks</a></span></li><li><span><a href="#ITT" data-toc-modified-id="ITT-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ITT</a></span></li><li><span><a href="#LATE" data-toc-modified-id="LATE-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>LATE</a></span></li></ul></li><li><span><a href="#Post-Double-Selection-(control-var-selection)" data-toc-modified-id="Post-Double-Selection-(control-var-selection)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Post-Double-Selection (control var selection)</a></span><ul class="toc-item"><li><span><a href="#ITT" data-toc-modified-id="ITT-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>ITT</a></span></li><li><span><a href="#LATE" data-toc-modified-id="LATE-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>LATE</a></span></li></ul></li><li><span><a href="#Heterogeneous-treatment-effects" data-toc-modified-id="Heterogeneous-treatment-effects-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Heterogeneous treatment effects</a></span></li><li><span><a href="#Local-linear-trends-by-treatment-arm" data-toc-modified-id="Local-linear-trends-by-treatment-arm-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Local linear trends by treatment arm</a></span></li><li><span><a href="#Student-level-plots" data-toc-modified-id="Student-level-plots-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Student-level plots</a></span><ul class="toc-item"><li><span><a href="#Quantile-Regression" data-toc-modified-id="Quantile-Regression-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Quantile Regression</a></span></li></ul></li><li><span><a href="#Time-series-plots" data-toc-modified-id="Time-series-plots-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Time series plots</a></span></li><li><span><a href="#Binge-watching" data-toc-modified-id="Binge-watching-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Binge watching</a></span><ul class="toc-item"><li><span><a href="#Regression-discontinuity" data-toc-modified-id="Regression-discontinuity-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Regression discontinuity</a></span></li></ul></li><li><span><a href="#Video-level-plots" data-toc-modified-id="Video-level-plots-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Video-level plots</a></span></li><li><span><a href="#Robustness-Checks" data-toc-modified-id="Robustness-Checks-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Robustness Checks</a></span><ul class="toc-item"><li><span><a href="#Randomization-inference" data-toc-modified-id="Randomization-inference-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Randomization inference</a></span></li></ul></li></ul></div>

// %% [markdown]
// This file takes cleaned data and performs all analysis found in Famulari & Goodman (2020). All code in this file is in Stata (version 16).
//
// The necessary file structure for this code to work is as follows:
//
// - base directory
//   - jupyter
//     - analyze_data.ipynb
//   - data
//     - generated
//       - student_demographics_fall.csv
//       - student_demographics_winter.csv
//       - student_analysis_sample.csv
//   - tex
//     - plots
//     - tables

// %% [markdown]
// ## Prep

// %%
* Set working directory to base directory
* cd "C:\Users\Zack\Documents\GitHub\microeconomics_videos"
cd "/Users/zack/github/microeconomics_videos"
// Out:
// /Users/zack/github/microeconomics_videos

// %%
* set more off to show all output
set more off

// %% [markdown]
// ### Check dependencies

// %%
* check that everything is up to date and installed
* run 'ssc install {package_name}' for any missing packages

*ado update, update // run this if you need to update packages

version
which avar
which binsreg // net install binsreg, from(https://raw.githubusercontent.com/nppackages/binsreg/master/stata)
which binscatter2 // net install binscatter2, from("https://raw.githubusercontent.com/mdroste/stata-binscatter2/master/")
which ereplace
which estout
which ftools
which grqreg
which gtools
which ivreg2
which lpdensity // net install lpdensity, from(https://raw.githubusercontent.com/nppackages/lpdensity/master/stata)
which mhtreg
// which moremata // not checkable but necessary
which pdslasso
which ranktest
which rddensity // net install rddensity, from(https://raw.githubusercontent.com/rdpackages/rddensity/master/stata)
which rdrobust
which ritest
which rlasso // ssc install lassopack
which unique
which weakiv
which weakivtest
// Out:
// version 17.0
//
// /Users/zack/Library/Application Support/Stata/ado/plus/a/avar.ado
// *! avar 1.0.07  28July2015
// *! authors cfb/mes
// *! shell based on ranktest by fk/mes
// *! see end of file for version comments
//
// /Users/zack/Library/Application Support/Stata/ado/plus/b/binsreg.ado
// *! version 1.5 19-OCT-2024
//
// /Users/zack/Library/Application Support/Stata/ado/plus/b/binscatter2.ado
// *! binscatter2, v0.91 (19jan2023), Michael Droste, mdroste@fas.harvard.edu
//
// /Users/zack/Library/Application Support/Stata/ado/plus/e/ereplace.ado
// *! Chris Larkin, version 1.0.3
// *! Chris Larkin, version 1.0.2
// *! Nick Cox, version 1.0.1
//
// /Users/zack/Library/Application Support/Stata/ado/plus/e/estout.ado
// *! version 3.31  26apr2022  Ben Jann
//
// /Users/zack/Library/Application Support/Stata/ado/plus/f/ftools.ado
// *! version 2.50.0 09jan2026
//
// /Users/zack/Library/Application Support/Stata/ado/plus/g/grqreg.ado
// *! version 2.1  (17 March 2011) Joao Pedro Azevedo
// *! version 2.0  (10 March 2010) Joao Pedro Azevedo
//
// /Users/zack/Library/Application Support/Stata/ado/plus/g/gtools.ado
// *! version 1.10.1 05Dec2022 Mauricio Caceres Bravo, mauricio.caceres.bravo@gmail
// > .com
// *! Program for managing the gtools package installation
//
// /Users/zack/Library/Application Support/Stata/ado/plus/i/ivreg2.ado
// *! ivreg2 4.1.12  14aug2024
// *! authors cfb & mes
// *! see end of file for version comments
//
// /Users/zack/Library/Application Support/Stata/ado/plus/l/lpdensity.ado
// *!version 2.5 2024-10-06
//
// /Users/zack/Library/Application Support/Stata/ado/plus/m/mhtreg.ado
//
// /Users/zack/Library/Application Support/Stata/ado/plus/p/pdslasso.ado
// *! pdslasso 1.0.03 04sept2018
// *! pdslasso package 1.3 29july2020
// *! authors aa/cbh/ms
//
// /Users/zack/Library/Application Support/Stata/ado/plus/r/ranktest.ado
// *! ranktest 2.0.04  21sept2020
// *! authors mes & fw; KP stat based on code by fk
// *! see end of file for version comments
//
// /Users/zack/Library/Application Support/Stata/ado/plus/r/rddensity.ado
// *!version 2.5 2024-10-06
//
// /Users/zack/Library/Application Support/Stata/ado/plus/r/rdrobust.ado
// *!version 10.0.0  2025-06-30
//
// /Users/zack/Library/Application Support/Stata/ado/plus/r/ritest.ado
// *! version 1.1.7 feb2020.
//
// /Users/zack/Library/Application Support/Stata/ado/plus/r/rlasso.ado
// *! rlasso 1.0.11 29jul2020
// *! lassopack package 1.4.3
// *! authors aa/cbh/ms
//
// /Users/zack/Library/Application Support/Stata/ado/plus/u/unique.ado
// *! version 1.2.4  Jun 17, 2020 @ 17:28:41
// *! MH and TB
//
// /Users/zack/Library/Application Support/Stata/ado/plus/w/weakiv.ado
// *! weakiv 2.4.07 1Oct2015
// *! authors Finlay-Magnusson-Schaffer
//
// /Users/zack/Library/Application Support/Stata/ado/plus/w/weakivtest.ado

// %% [markdown]
// ### Define global control variable list

// %%
global ctrl_vars mathquizstd mathquiz_unobs videos_mid1_u duration_mid1_u pset_pre ///
    transfer prev_cumgpa prev_cumgpa_unobs female ///
    asian latx white

// sum $ctrl_vars

// %% [markdown]
// ### Define functions

// %%
* Data prep functions

foreach v in clean_data get_idyearlevel merge_winter_gpa ///
    merge_dem clean_dem get_std_units {
    capture program drop `v'
}

* define data clean function common to all dfs
program clean_data
    capture drop arm
    gen arm = treated + toberandomized
    drop toberandomized
    drop if mi(mid1score) // did not start experiment
    label define arm 0 "Above median" 1 "Control" 2 "Treated"
    label values arm arm
    capture drop y2019
    gen y2019 = year == 2019
    capture drop bothpairs
    gen pairyear = year * 1000 + pair
    sort pair year
    foreach v in assigned_grade mid2score finalscore {
        gen bothpairs_`v' = !mi(`v')
        by pair year: ereplace bothpairs_`v' = sum(bothpairs_`v')
        replace bothpairs_`v' = bothpairs_`v' >= 2
    }
    rename (bothpairs_mid2 bothpairs_final) (bothpairs_mid2 bothpairs_final)
    gen mathquiz_unobs = mi(mathquiz)
    replace mathquiz = 0 if mi(mathquiz)
    end

* define function that loads student-year level data
program get_idyearlevel
    import delimited ./data/generated/student_analysis_sample.csv, clear varnames(1)
    clean_data
    end

* merge gpa/units/class data from subsequent quarter
program merge_winter_gpa
    preserve
    import delimited ./data/generated/student_demographics_winter.csv, clear varnames(1)
    local renamevars units_letter units_pnp units_w ///
        gpa_letter gpa_letter_sansecon gpa_letter_sans100a gpa_econ_sans100a ///
        nclass_letter nclass_np nclass_pnp nclass_p nclass_w
    keep id year `renamevars' 
    foreach v in `renamevars' {
        rename `v' winter_`v'
    }
    tempfile temp
    save `temp'
    restore
    merge 1:1 id year using `temp', nogen
    end

* merge demographic data
program merge_dem
    preserve
    import delimited ./data/generated/student_demographics_fall.csv, clear varnames(1)
    tempfile temp
    save `temp'
    restore
    merge 1:1 id year using `temp', nogen
    end

* get demographic vars into binary form
program clean_dem
    capture drop male female othergen ///
        chinese latx oasian viet white othereth 
    * gender
    gen male = gender == "m"
    gen female = gender == "f"
    gen othergen = gender == "u"
    * ethnicity
    gen chinese = ethnicity == "Chinese/Chinese-American"
    gen latx = ethnicity == "Chicanx/Latinx"
    gen oasian = ethnicity == "All Other Asian/Asian-American"
    gen viet = ethnicity == "Vietnamese"
    gen white = ethnicity == "White/Caucasian"
    gen othereth = !mi(ethnicity) & !(chinese | latx | oasian | viet | white)
    gen asian = chinese + oasian + viet
    * prev cumulative gpa
    gen prev_cumgpa_unobs = mi(prev_cumgpa)
    replace prev_cumgpa = 0 if mi(prev_cumgpa) // prev_cumgpa is interaction of obs * gpa
    * whether pass 100A
    capture drop pass
    gen pass = inlist(substr(assigned_grade, 1, 1), "A", "B", "C", "P")
    replace pass = . if mi(finalscore)
    * whether pass 100B
    capture drop pass100b
    gen pass100b = inlist(substr(lettergrade_100b, 1, 1), "A", "B", "C") if !mi(lettergrade_100b)
    * whether take 100A for letter
    capture drop letter_option
    gen letter_option = inlist(substr(assigned_grade, 1, 1), "A", "B", "C", "D", "F")
    replace letter_option = . if mi(finalscore)
    * sum of attendance
    capture drop attendance
    gen attendance = attend1 + attend2 + attend3 + attend4 + attend5 + attend6 + attend7
    * nclass_np
    foreach p in "winter_" "" {
        capture drop `p'nclass_np
        gen `p'tot_class = `p'nclass_letter + `p'nclass_pnp + `p'nclass_w
        gen `p'nclass_np = `p'tot_class - `p'nclass_p - `p'nclass_w // where are incompletes counted?
        gen `p'pclass_letter = `p'nclass_letter / (`p'nclass_letter + `p'nclass_pnp)
        gen `p'pclass_pnp = `p'nclass_pnp / (`p'nclass_letter + `p'nclass_pnp)
    }
    end

* get score variables into standard deviation units
* normalize by the median score in each year
program get_std_units
    *** return std units for 100A vars
    capture drop mid1scorestd
    gen mid1scorestd = .
    forvalues y = 2018/2019 {
        qui sum mid1score if year == `y' & arm >= 1
        local maxscore = r(max)
        qui sum mid1score if year == `y' & arm == 1
        replace mid1scorestd = (mid1score - `maxscore') / r(sd) if year == `y'
    }
    
    local oldvars "mathquiz mid2score finalscore"
    foreach v in `oldvars' {
        capture drop `v'std
        gen `v'std = .
        forvalues y = 2018/2019 {
            qui sum `v' if year == `y' & arm == 1
            replace `v'std = (`v' - r(mean)) / r(sd) if year == `y'
        }
    }

    *** return std units for 100B vars if they exist
    capture confirm variable mid1_100b
    if !_rc {
        local oldvars "mid1_100b mid2_100b final_100b"
        foreach v in `oldvars' {
            capture drop `v'std
            gen `v'std = .
            forvalues y = 2018/2019 {
            qui sum `v' if year == `y' & arm == 1
            replace `v'std = (`v' - r(mean)) / r(sd) if year == `y'
            }
        }
    }
    end

// %% [markdown]
// ### Label variables

// %%
* Label variables

capture program drop label_vars

* label vars

program label_vars
    capture label var mathquizstd "Math Quiz score"
    capture label var mid1scorestd "Midterm 1 score"
    capture label var mid2scorestd "Midterm 2 score"
    capture label var finalscorestd "Final exam score"
    capture label var treated "Treated"
    capture label var mid1_100bstd "100B Midterm 1 score"
    capture label var mid2_100bstd "100B Midterm 2 score"
    capture label var final_100bstd "100B Final score"
    capture label var duration_mid1 "Duration, videos before mid1"
    capture label var duration_mid2 "Duration, videos before mid2"
    capture label var duration_final "Duration, videos before final"
    capture label var duration_mid1_u "Duration, unique videos before mid1"
    capture label var duration_mid2_u "Duration, unique videos before mid2"
    capture label var duration_final_u "Duration, unique videos before final"
    capture label var videos_mid1 "Num. videos before mid1"
    capture label var videos_mid2 "Num. videos before mid2"
    capture label var videos_final "Num. videos before final"
    capture label var videos_mid1_u "Num. unique videos before mid1"
    capture label var videos_mid2_u "Num. unique videos before mid2"
    capture label var videos_final_u "Num. unique videos before final"
    capture label var pset_pre "PSET"
    capture label var transfer "Transfer Student"
    capture label var prev_cumgpa "Prev. GPA"
    capture label var male "Male"
    capture label var female "Female"
    capture label var othergen "Other gender/not spec."
    capture label var asian "Asian"
    capture label var chinese "Chinese"
    capture label var latx "Latinx"
    capture label var viet "Vietnamese"
    capture label var oasian "Other Asian"
    capture label var latx "Latinx"
    capture label var white "White"
    capture label var othereth "Other ethnicity/not spec."
    end

// %% [markdown]
// ## Plotting schemes and functions

// %%
* set scheme to one with white background

set scheme s1color


* plotting and export functions

capture program drop export_img

program export_img
    args name
    graph export "./tex/plots/`name'.pdf", name(`name') replace
    end

// %% [markdown]
// ## Attrition
//
// In this section we examine attrition from the experiment

// %%
* get data

qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
* examine attrition between experiment start and end
* (for those who did not opt of sharing their data)

* Before anonymization:
// T, C, I: 425, 218, 218

di "Consented to data sharing:"
tab treated arm

di "In experiment & saw treatment assignment:"
tab treated arm if !mi(assigned_grade)

di "Took midterm 2:"
tab treated arm if !mi(mid2score) & !mi(assigned_grade)

di "Took final (and completed experiment):"
tab treated arm if !mi(finalscore) & !mi(assigned_grade)

di "Took Micro B:"
tab treated arm if took100b & !mi(assigned_grade)
// Out:
// Consented to data sharing:
//
//
//            |               arm
//    Treated | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       420        215          0 |       635
//          1 |         0          0        215 |       215
// -----------+---------------------------------+----------
//      Total |       420        215        215 |       850
//
// In experiment & saw treatment assignment:
//
//
//            |               arm
//    Treated | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       418        196          0 |       614
//          1 |         0          0        206 |       206
// -----------+---------------------------------+----------
//      Total |       418        196        206 |       820
//
// Took midterm 2:
//
//
//            |               arm
//    Treated | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       417        193          0 |       610
//          1 |         0          0        202 |       202
// -----------+---------------------------------+----------
//      Total |       417        193        202 |       812
//
// Took final (and completed experiment):
//
//
//            |               arm
//    Treated | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       415        184          0 |       599
//          1 |         0          0        190 |       190
// -----------+---------------------------------+----------
//      Total |       415        184        190 |       789
//
// Took Micro B:
//
//
//            |               arm
//    Treated | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       284        114          0 |       398
//          1 |         0          0        100 |       100
// -----------+---------------------------------+----------
//      Total |       284        114        100 |       498

// %% [markdown]
// ### Attrition for those below the median

// %%
tab assigned_grade arm if mi(mid2score), mi
tab assigned_grade arm if mi(finalscore) & !mi(mid2score), mi
// Out:
// assigned_g |               arm
//       rade | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//            |         2         19          9 |        30
//          C |         0          0          1 |         1
//          F |         1          3          3 |         7
// -----------+---------------------------------+----------
//      Total |         3         22         13 |        38
//
//
// assigned_g |               arm
//       rade | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          B |         0          1          0 |         1
//          C |         1          0          0 |         1
//          D |         0          3          0 |         3
//          F |         1          4         12 |        17
//         NP |         0          0          1 |         1
//          W |         0          1          0 |         1
// -----------+---------------------------------+----------
//      Total |         2          9         13 |        24

// %%
capture restore
preserve

* keep only those who observed their treatment statuses (i.e. received a grade including W)
keep if !mi(assigned_grade) & arm > 0

foreach v in mid2score finalscore {
    capture drop miss
    qui gen miss = mi(`v')
    di "`v'"
    tab miss arm, col
    ttest miss, by(arm) unequal
}

capture drop miss
qui gen miss = took100b == 0
di "took100b"
tab miss arm, col
ttest miss, by(arm) unequal

* what if we condition on mid1 scores and year?
reg took100b treated mid1scorestd y2019 if arm > 0

restore
// Out:
// (448 observations deleted)
//
// mid2score
//
// +-------------------+
// | Key               |
// |-------------------|
// |     frequency     |
// | column percentage |
// +-------------------+
//
//            |          arm
//       miss |   Control    Treated |     Total
// -----------+----------------------+----------
//          0 |       193        202 |       395
//            |     98.47      98.06 |     98.26
// -----------+----------------------+----------
//          1 |         3          4 |         7
//            |      1.53       1.94 |      1.74
// -----------+----------------------+----------
//      Total |       196        206 |       402
//            |    100.00     100.00 |    100.00
//
// Two-sample t test with unequal variances
// ------------------------------------------------------------------------------
//    Group |     Obs        Mean    Std. err.   Std. dev.   [95% conf. interval]
// ---------+--------------------------------------------------------------------
//  Control |     196    .0153061    .0087916    .1230818   -.0020326    .0326449
//  Treated |     206    .0194175    .0096374    .1383232    .0004163    .0384187
// ---------+--------------------------------------------------------------------
// Combined |     402    .0174129     .006532    .1309671    .0045716    .0302543
// ---------+--------------------------------------------------------------------
//     diff |           -.0041114     .013045                -.029757    .0215343
// ------------------------------------------------------------------------------
//     diff = mean(Control) - mean(Treated)                          t =  -0.3152
// H0: diff = 0                     Satterthwaite's degrees of freedom =  398.232
//
//     Ha: diff < 0                 Ha: diff != 0                 Ha: diff > 0
//  Pr(T < t) = 0.3764         Pr(|T| > |t|) = 0.7528          Pr(T > t) = 0.6236
// finalscore
//
// +-------------------+
// | Key               |
// |-------------------|
// |     frequency     |
// | column percentage |
// +-------------------+
//
//            |          arm
//       miss |   Control    Treated |     Total
// -----------+----------------------+----------
//          0 |       184        190 |       374
//            |     93.88      92.23 |     93.03
// -----------+----------------------+----------
//          1 |        12         16 |        28
//            |      6.12       7.77 |      6.97
// -----------+----------------------+----------
//      Total |       196        206 |       402
//            |    100.00     100.00 |    100.00
//
// Two-sample t test with unequal variances
// ------------------------------------------------------------------------------
//    Group |     Obs        Mean    Std. err.   Std. dev.   [95% conf. interval]
// ---------+--------------------------------------------------------------------
//  Control |     196    .0612245    .0171683    .2403556    .0273652    .0950838
//  Treated |     206    .0776699    .0186936    .2683034    .0408136    .1145262
// ---------+--------------------------------------------------------------------
// Combined |     402    .0696517    .0127121    .2548764    .0446611    .0946424
// ---------+--------------------------------------------------------------------
//     diff |           -.0164454    .0253811               -.0663429    .0334521
// ------------------------------------------------------------------------------
//     diff = mean(Control) - mean(Treated)                          t =  -0.6479
// H0: diff = 0                     Satterthwaite's degrees of freedom =  398.568
//
//     Ha: diff < 0                 Ha: diff != 0                 Ha: diff > 0
//  Pr(T < t) = 0.2587         Pr(|T| > |t|) = 0.5174          Pr(T > t) = 0.7413
//
//
//
// took100b
//
//
// +-------------------+
// | Key               |
// |-------------------|
// |     frequency     |
// | column percentage |
// +-------------------+
//
//            |          arm
//       miss |   Control    Treated |     Total
// -----------+----------------------+----------
//          0 |       114        100 |       214
//            |     58.16      48.54 |     53.23
// -----------+----------------------+----------
//          1 |        82        106 |       188
//            |     41.84      51.46 |     46.77
// -----------+----------------------+----------
//      Total |       196        206 |       402
//            |    100.00     100.00 |    100.00
//
//
// Two-sample t test with unequal variances
// ------------------------------------------------------------------------------
//    Group |     Obs        Mean    Std. err.   Std. dev.   [95% conf. interval]
// ---------+--------------------------------------------------------------------
//  Control |     196    .4183673    .0353253    .4945543    .3486986    .4880361
//  Treated |     206    .5145631    .0349067    .5010054    .4457409    .5833853
// ---------+--------------------------------------------------------------------
// Combined |     402    .4676617    .0249165    .4995749    .4186783     .516645
// ---------+--------------------------------------------------------------------
//     diff |           -.0961958    .0496624               -.1938281    .0014366
// ------------------------------------------------------------------------------
//     diff = mean(Control) - mean(Treated)                          t =  -1.9370
// H0: diff = 0                     Satterthwaite's degrees of freedom =  399.455
//
//     Ha: diff < 0                 Ha: diff != 0                 Ha: diff > 0
//  Pr(T < t) = 0.0267         Pr(|T| > |t|) = 0.0535          Pr(T > t) = 0.9733
//
//
//       Source |       SS           df       MS      Number of obs   =       402
// -------------+----------------------------------   F(3, 398)       =     13.71
//        Model |  9.37061891         3  3.12353964   Prob > F        =    0.0000
//     Residual |  90.7089831       398  .227912018   R-squared       =    0.0936
// -------------+----------------------------------   Adj R-squared   =    0.0868
//        Total |  100.079602       401  .249575067   Root MSE        =     .4774
//
// ------------------------------------------------------------------------------
//     took100b | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      treated |  -.0885763   .0476524    -1.86   0.064    -.1822582    .0051056
// mid1scorestd |   .1278918   .0254226     5.03   0.000     .0779125    .1778712
//        y2019 |   .1703565   .0476488     3.58   0.000     .0766817    .2640312
//        _cons |   .6396788   .0502081    12.74   0.000     .5409726     .738385
// ------------------------------------------------------------------------------

// %% [markdown]
// ## Balance
//
// In this section we ensure the treatment and control arms are balanced on observable characteristics.

// %%
* get data and merge demographic vars

qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
** Generate balance tables

* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar arm str32 exam bothpairs mean stderr N

frames dir

* vars to check balance
local balance_vars mid1scorestd y2019 ///
    prev_cumgpa prev_cumgpa_unobs mathquizstd pset_pre ///
    videos_mid1 videos_mid1_u duration_mid1 duration_mid1_u ///
    asian latx white othereth female male transfer
replace prev_cumgpa = . if prev_cumgpa_unobs
order `balance_vars'
sum `balance_vars'


* Get balance table data
* Loop over exams for those seeing treatment assignment
foreach exam in mid2 final {
    
    * loop through all variables and post info to `results'
    
    capture restore
    preserve
    
    * first, anyone who saw their treatment status
    keep if !mi(assigned_grade)
    foreach v in `balance_vars' {
        forvalues i = 0/2 {
            qui sum `v' if arm == `i'
            frame post results ("`v'") (`i') ("`exam'") (-1) (r(mean)) (r(sd) / sqrt(r(N))) (r(N))
        }
    }
    
    * second, anyone who completed the `exam'
    keep if !mi(`exam'score)

    foreach v in `balance_vars' {
        forvalues i = 0/2 {
            qui sum `v' if arm == `i'
            frame post results ("`v'") (`i') ("`exam'") (0) (r(mean)) (r(sd) / sqrt(r(N))) (r(N))
        }
    }

    * third, matching pairs only
    keep if bothpairs_`exam'
    foreach v in `balance_vars' {
        forvalues i = 1/2 {
            qui sum `v' if arm == `i'
            frame post results ("`v'") (`i') ("`exam'") (1) (r(mean)) (r(sd) / sqrt(r(N))) (r(N))
        }
    }
    restore
}

frame results: li depvar arm bothpairs mean stderr N


* Export the results data for publication
frame results: export delimited "./data/generated/balance_table_data.csv", replace
// Out:
// * default  850 x 136
// * results  0 x 7
//
// Note: Frames marked with * contain unsaved data.
//
//
// (252 real changes made, 252 to missing)
//
//
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
// mid1scorestd |        850   -.1986668    1.292519  -4.384486   2.095526
//        y2019 |        850    .4905882    .5002057          0          1
//  prev_cumgpa |        598    3.208813     .610118          0          4
// prev_cumgp~s |        850    .2964706    .4569699          0          1
//  mathquizstd |        850     .306071    .9740099  -2.362005   1.768687
// -------------+---------------------------------------------------------
//     pset_pre |        850    .2529412    .8298166          0         10
//  videos_mid1 |        850    13.61176    13.63152          0        105
// videos_m~1_u |        850    9.941176    8.605273          0         40
// duration_m~1 |        850    2.557915    2.565142          0    19.7325
// duration~1_u |        850    1.780169    1.515467          0   6.584722
// -------------+---------------------------------------------------------
//        asian |        850    .6870588    .4639636          0          1
//         latx |        850    .1047059    .3063543          0          1
//        white |        850    .1341176    .3409793          0          1
//     othereth |        850    .0741176    .2621165          0          1
//       female |        850         .38    .4856722          0          1
// -------------+---------------------------------------------------------
//         male |        850    .6094118    .4881695          0          1
//     transfer |        850    .3729412    .4838714          0          1
//
// (30 observations deleted)
// (8 observations deleted)
// (33 observations deleted)
// (30 observations deleted)
// (31 observations deleted)
// (42 observations deleted)
//
//
//      +-----------------------------------------------------------------+
//      |            depvar   arm   bothpa~s        mean     stderr     N |
//      |-----------------------------------------------------------------|
//   1. |      mid1scorestd     0         -1    .8373252    .024661   418 |
//   2. |      mid1scorestd     1         -1   -1.126683   .0655659   196 |
//   3. |      mid1scorestd     2         -1   -1.166532   .0668381   206 |
//   4. |             y2019     0         -1    .4904306   .0244806   418 |
//   5. |             y2019     1         -1     .505102   .0358039   196 |
//      |-----------------------------------------------------------------|
//   6. |             y2019     2         -1    .4902913   .0349149   206 |
//   7. |       prev_cumgpa     0         -1    3.445016   .0287579   321 |
//   8. |       prev_cumgpa     1         -1    2.930569    .045059   123 |
//   9. |       prev_cumgpa     2         -1    2.940652   .0570439   138 |
//  10. | prev_cumgpa_unobs     0         -1    .2320574   .0206726   418 |
//      |-----------------------------------------------------------------|
//  11. | prev_cumgpa_unobs     1         -1     .372449   .0346211   196 |
//  12. | prev_cumgpa_unobs     2         -1    .3300971   .0328435   206 |
//  13. |       mathquizstd     0         -1    .5894628   .0436182   418 |
//  14. |       mathquizstd     1         -1    .0159523   .0706312   196 |
//  15. |       mathquizstd     2         -1    .0928443   .0652509   206 |
//      |-----------------------------------------------------------------|
//  16. |          pset_pre     0         -1    .2679426   .0423072   418 |
//  17. |          pset_pre     1         -1     .255102   .0576999   196 |
//  18. |          pset_pre     2         -1     .223301   .0554251   206 |
//  19. |       videos_mid1     0         -1    13.19617   .6796828   418 |
//  20. |       videos_mid1     1         -1    13.32143   .8747991   196 |
//      |-----------------------------------------------------------------|
//  21. |       videos_mid1     2         -1    13.70388   .9153225   206 |
//  22. |     videos_mid1_u     0         -1    9.722488   .4306574   418 |
//  23. |     videos_mid1_u     1         -1    9.668367   .5723309   196 |
//  24. |     videos_mid1_u     2         -1    10.15534   .6016992   206 |
//  25. |     duration_mid1     0         -1    2.470361   .1268212   418 |
//      |-----------------------------------------------------------------|
//  26. |     duration_mid1     1         -1    2.522313   .1676827   196 |
//  27. |     duration_mid1     2         -1    2.576042   .1728432   206 |
//  28. |   duration_mid1_u     0         -1      1.7251   .0751331   418 |
//  29. |   duration_mid1_u     1         -1    1.751501   .1025451   196 |
//  30. |   duration_mid1_u     2         -1    1.833727   .1063646   206 |
//      |-----------------------------------------------------------------|
//  31. |             asian     0         -1    .7009569   .0224205   418 |
//  32. |             asian     1         -1    .6938776   .0330044   196 |
//  33. |             asian     2         -1    .6699029   .0328435   206 |
//  34. |              latx     0         -1    .0598086   .0116124   418 |
//  35. |              latx     1         -1    .1326531   .0242906   196 |
//      |-----------------------------------------------------------------|
//  36. |              latx     2         -1    .1553398   .0252991   206 |
//  37. |             white     0         -1    .1507177   .0175202   418 |
//  38. |             white     1         -1    .1173469    .023047   196 |
//  39. |             white     2         -1    .1213592   .0228068   206 |
//  40. |          othereth     0         -1    .0885167   .0139097   418 |
//      |-----------------------------------------------------------------|
//  41. |          othereth     1         -1    .0561224    .016482   196 |
//  42. |          othereth     2         -1    .0533981   .0157025   206 |
//  43. |            female     0         -1    .3923445   .0239108   418 |
//  44. |            female     1         -1    .3367347   .0338431   196 |
//  45. |            female     2         -1    .3932039   .0341156   206 |
//      |-----------------------------------------------------------------|
//  46. |              male     0         -1    .5933014    .024055   418 |
//  47. |              male     1         -1    .6581632   .0339671   196 |
//  48. |              male     2         -1    .5970874   .0342569   206 |
//  49. |          transfer     0         -1    .2727273   .0218095   418 |
//  50. |          transfer     1         -1    .4846939    .035789   196 |
//      |-----------------------------------------------------------------|
//  51. |          transfer     2         -1    .4466019   .0347218   206 |
//  52. |      mid1scorestd     0          0    .8383668   .0246982   417 |
//  53. |      mid1scorestd     1          0   -1.093833   .0633601   193 |
//  54. |      mid1scorestd     2          0   -1.172395   .0678008   202 |
//  55. |             y2019     0          0    .4916067   .0245111   417 |
//      |-----------------------------------------------------------------|
//  56. |             y2019     1          0    .5129533   .0360723   193 |
//  57. |             y2019     2          0          .5   .0352673   202 |
//  58. |       prev_cumgpa     0          0    3.445016   .0287579   321 |
//  59. |       prev_cumgpa     1          0    2.944426   .0432282   122 |
//  60. |       prev_cumgpa     2          0    2.947556   .0577718   135 |
//      |-----------------------------------------------------------------|
//  61. | prev_cumgpa_unobs     0          0    .2302158   .0206398   417 |
//  62. | prev_cumgpa_unobs     1          0    .3678756   .0348018   193 |
//  63. | prev_cumgpa_unobs     2          0    .3316832   .0332089   202 |
//  64. |       mathquizstd     0          0    .5923803    .043625   417 |
//  65. |       mathquizstd     1          0    .0368635   .0701806   193 |
//      |-----------------------------------------------------------------|
//  66. |       mathquizstd     2          0    .1060785   .0652618   202 |
//  67. |          pset_pre     0          0    .2685851   .0424039   417 |
//  68. |          pset_pre     1          0    .2590674   .0585534   193 |
//  69. |          pset_pre     2          0    .2227723   .0563611   202 |
//  70. |       videos_mid1     0          0    13.22782   .6805758   417 |
//      |-----------------------------------------------------------------|
//  71. |       videos_mid1     1          0    13.36788    .886062   193 |
//  72. |       videos_mid1     2          0    13.77723   .9311686   202 |
//  73. |     videos_mid1_u     0          0    9.745804   .4310583   417 |
//  74. |     videos_mid1_u     1          0    9.689119   .5796209   193 |
//  75. |     videos_mid1_u     2          0    10.18812   .6112674   202 |
//      |-----------------------------------------------------------------|
//  76. |     duration_mid1     0          0    2.476285   .1269869   417 |
//  77. |     duration_mid1     1          0    2.527226   .1698314   193 |
//  78. |     duration_mid1     2          0    2.587547   .1758057   202 |
//  79. |   duration_mid1_u     0          0    1.729237   .0751992   417 |
//  80. |   duration_mid1_u     1          0    1.751517   .1038364   193 |
//      |-----------------------------------------------------------------|
//  81. |   duration_mid1_u     2          0    1.837742   .1079811   202 |
//  82. |             asian     0          0    .7002398   .0224628   417 |
//  83. |             asian     1          0    .6943005   .0332484   193 |
//  84. |             asian     2          0    .6683168   .0332089   202 |
//  85. |              latx     0          0     .059952   .0116394   417 |
//      |-----------------------------------------------------------------|
//  86. |              latx     1          0     .134715   .0246398   193 |
//  87. |              latx     2          0    .1584158   .0257543   202 |
//  88. |             white     0          0    .1510791   .0175586   417 |
//  89. |             white     1          0    .1139896   .0229351   193 |
//  90. |             white     2          0    .1237624   .0232278   202 |
//      |-----------------------------------------------------------------|
//  91. |          othereth     0          0     .088729   .0139415   417 |
//  92. |          othereth     1          0    .0569948   .0167311   193 |
//  93. |          othereth     2          0     .049505   .0153003   202 |
//  94. |            female     0          0    .3932854   .0239497   417 |
//  95. |            female     1          0    .3419689   .0342347   193 |
//      |-----------------------------------------------------------------|
//  96. |            female     2          0    .3910891   .0344205   202 |
//  97. |              male     0          0    .5923262    .024093   417 |
//  98. |              male     1          0    .6528497    .034357   193 |
//  99. |              male     2          0    .6039604   .0344965   202 |
// 100. |          transfer     0          0    .2709832   .0217918   417 |
//      |-----------------------------------------------------------------|
// 101. |          transfer     1          0    .4766839   .0360451   193 |
// 102. |          transfer     2          0    .4554456    .035127   202 |
// 103. |      mid1scorestd     1          1   -1.070108   .0645987   181 |
// 104. |      mid1scorestd     2          1   -1.077882   .0655088   181 |
// 105. |             y2019     1          1    .5138122   .0372536   181 |
//      |-----------------------------------------------------------------|
// 106. |             y2019     2          1    .5138122   .0372536   181 |
// 107. |       prev_cumgpa     1          1    2.942261   .0447679   115 |
// 108. |       prev_cumgpa     2          1    2.992033   .0556937   123 |
// 109. | prev_cumgpa_unobs     1          1    .3646409   .0358762   181 |
// 110. | prev_cumgpa_unobs     2          1     .320442   .0347818   181 |
//      |-----------------------------------------------------------------|
// 111. |       mathquizstd     1          1    .0539368   .0708915   181 |
// 112. |       mathquizstd     2          1    .1372366   .0675624   181 |
// 113. |          pset_pre     1          1    .2762431   .0622348   181 |
// 114. |          pset_pre     2          1    .2320442   .0607539   181 |
// 115. |       videos_mid1     1          1    13.66298   .9289433   181 |
//      |-----------------------------------------------------------------|
// 116. |       videos_mid1     2          1    13.72928   .9855577   181 |
// 117. |     videos_mid1_u     1          1    9.845304   .6060284   181 |
// 118. |     videos_mid1_u     2          1    10.11602   .6441064   181 |
// 119. |     duration_mid1     1          1    2.601177   .1780951   181 |
// 120. |     duration_mid1     2          1    2.583887   .1850829   181 |
//      |-----------------------------------------------------------------|
// 121. |   duration_mid1_u     1          1    1.789544   .1084148   181 |
// 122. |   duration_mid1_u     2          1    1.833313   .1137591   181 |
// 123. |             asian     1          1    .7127072   .0337273   181 |
// 124. |             asian     2          1    .6519337   .0355056   181 |
// 125. |              latx     1          1    .1325967   .0252779   181 |
//      |-----------------------------------------------------------------|
// 126. |              latx     2          1    .1657459   .0277162   181 |
// 127. |             white     1          1    .1049724   .0228465   181 |
// 128. |             white     2          1    .1381215   .0257168   181 |
// 129. |          othereth     1          1    .0497238   .0162021   181 |
// 130. |          othereth     2          1    .0441989   .0153198   181 |
//      |-----------------------------------------------------------------|
// 131. |            female     1          1    .3425414   .0353716   181 |
// 132. |            female     2          1    .3922652   .0363924   181 |
// 133. |              male     1          1    .6519337   .0355056   181 |
// 134. |              male     2          1    .6022099   .0364808   181 |
// 135. |          transfer     1          1    .4696133   .0371989   181 |
//      |-----------------------------------------------------------------|
// 136. |          transfer     2          1    .4364641   .0369657   181 |
// 137. |      mid1scorestd     0         -1    .8373252    .024661   418 |
// 138. |      mid1scorestd     1         -1   -1.126683   .0655659   196 |
// 139. |      mid1scorestd     2         -1   -1.166532   .0668381   206 |
// 140. |             y2019     0         -1    .4904306   .0244806   418 |
//      |-----------------------------------------------------------------|
// 141. |             y2019     1         -1     .505102   .0358039   196 |
// 142. |             y2019     2         -1    .4902913   .0349149   206 |
// 143. |       prev_cumgpa     0         -1    3.445016   .0287579   321 |
// 144. |       prev_cumgpa     1         -1    2.930569    .045059   123 |
// 145. |       prev_cumgpa     2         -1    2.940652   .0570439   138 |
//      |-----------------------------------------------------------------|
// 146. | prev_cumgpa_unobs     0         -1    .2320574   .0206726   418 |
// 147. | prev_cumgpa_unobs     1         -1     .372449   .0346211   196 |
// 148. | prev_cumgpa_unobs     2         -1    .3300971   .0328435   206 |
// 149. |       mathquizstd     0         -1    .5894628   .0436182   418 |
// 150. |       mathquizstd     1         -1    .0159523   .0706312   196 |
//      |-----------------------------------------------------------------|
// 151. |       mathquizstd     2         -1    .0928443   .0652509   206 |
// 152. |          pset_pre     0         -1    .2679426   .0423072   418 |
// 153. |          pset_pre     1         -1     .255102   .0576999   196 |
// 154. |          pset_pre     2         -1     .223301   .0554251   206 |
// 155. |       videos_mid1     0         -1    13.19617   .6796828   418 |
//      |-----------------------------------------------------------------|
// 156. |       videos_mid1     1         -1    13.32143   .8747991   196 |
// 157. |       videos_mid1     2         -1    13.70388   .9153225   206 |
// 158. |     videos_mid1_u     0         -1    9.722488   .4306574   418 |
// 159. |     videos_mid1_u     1         -1    9.668367   .5723309   196 |
// 160. |     videos_mid1_u     2         -1    10.15534   .6016992   206 |
//      |-----------------------------------------------------------------|
// 161. |     duration_mid1     0         -1    2.470361   .1268212   418 |
// 162. |     duration_mid1     1         -1    2.522313   .1676827   196 |
// 163. |     duration_mid1     2         -1    2.576042   .1728432   206 |
// 164. |   duration_mid1_u     0         -1      1.7251   .0751331   418 |
// 165. |   duration_mid1_u     1         -1    1.751501   .1025451   196 |
//      |-----------------------------------------------------------------|
// 166. |   duration_mid1_u     2         -1    1.833727   .1063646   206 |
// 167. |             asian     0         -1    .7009569   .0224205   418 |
// 168. |             asian     1         -1    .6938776   .0330044   196 |
// 169. |             asian     2         -1    .6699029   .0328435   206 |
// 170. |              latx     0         -1    .0598086   .0116124   418 |
//      |-----------------------------------------------------------------|
// 171. |              latx     1         -1    .1326531   .0242906   196 |
// 172. |              latx     2         -1    .1553398   .0252991   206 |
// 173. |             white     0         -1    .1507177   .0175202   418 |
// 174. |             white     1         -1    .1173469    .023047   196 |
// 175. |             white     2         -1    .1213592   .0228068   206 |
//      |-----------------------------------------------------------------|
// 176. |          othereth     0         -1    .0885167   .0139097   418 |
// 177. |          othereth     1         -1    .0561224    .016482   196 |
// 178. |          othereth     2         -1    .0533981   .0157025   206 |
// 179. |            female     0         -1    .3923445   .0239108   418 |
// 180. |            female     1         -1    .3367347   .0338431   196 |
//      |-----------------------------------------------------------------|
// 181. |            female     2         -1    .3932039   .0341156   206 |
// 182. |              male     0         -1    .5933014    .024055   418 |
// 183. |              male     1         -1    .6581632   .0339671   196 |
// 184. |              male     2         -1    .5970874   .0342569   206 |
// 185. |          transfer     0         -1    .2727273   .0218095   418 |
//      |-----------------------------------------------------------------|
// 186. |          transfer     1         -1    .4846939    .035789   196 |
// 187. |          transfer     2         -1    .4466019   .0347218   206 |
// 188. |      mid1scorestd     0          0    .8398661    .024776   415 |
// 189. |      mid1scorestd     1          0   -1.055942   .0605222   184 |
// 190. |      mid1scorestd     2          0   -1.152775    .068672   190 |
//      |-----------------------------------------------------------------|
// 191. |             y2019     0          0    .4891566   .0245679   415 |
// 192. |             y2019     1          0    .5163044   .0369414   184 |
// 193. |             y2019     2          0          .5   .0363696   190 |
// 194. |       prev_cumgpa     0          0    3.445141   .0289279   319 |
// 195. |       prev_cumgpa     1          0    2.946017   .0440831   118 |
//      |-----------------------------------------------------------------|
// 196. |       prev_cumgpa     2          0    2.958819   .0600882   127 |
// 197. | prev_cumgpa_unobs     0          0    .2313253   .0207244   415 |
// 198. | prev_cumgpa_unobs     1          0    .3586957   .0354544   184 |
// 199. | prev_cumgpa_unobs     2          0    .3315789   .0342442   190 |
// 200. |       mathquizstd     0          0    .5992457   .0433594   415 |
//      |-----------------------------------------------------------------|
// 201. |       mathquizstd     1          0     .071137   .0681639   184 |
// 202. |       mathquizstd     2          0    .1515437   .0655006   190 |
// 203. |          pset_pre     0          0    .2698795   .0425986   415 |
// 204. |          pset_pre     1          0    .2717391   .0612719   184 |
// 205. |          pset_pre     2          0    .2368421   .0597829   190 |
//      |-----------------------------------------------------------------|
// 206. |       videos_mid1     0          0    13.29157   .6823616   415 |
// 207. |       videos_mid1     1          0    13.41848   .9092653   184 |
// 208. |       videos_mid1     2          0     13.6579   .9533648   190 |
// 209. |     videos_mid1_u     0          0    9.792771   .4318539   415 |
// 210. |     videos_mid1_u     1          0    9.782609   .5979519   184 |
//      |-----------------------------------------------------------------|
// 211. |     videos_mid1_u     2          0    10.11053   .6218136   190 |
// 212. |     duration_mid1     0          0    2.488219   .1273182   415 |
// 213. |     duration_mid1     1          0    2.534591   .1733982   184 |
// 214. |     duration_mid1     2          0    2.572491   .1800304   190 |
// 215. |   duration_mid1_u     0          0    1.737571   .0753303   415 |
//      |-----------------------------------------------------------------|
// 216. |   duration_mid1_u     1          0    1.769592   .1071003   184 |
// 217. |   duration_mid1_u     2          0    1.829539   .1098718   190 |
// 218. |             asian     0          0    .7012048   .0224962   415 |
// 219. |             asian     1          0    .6956522   .0340138   184 |
// 220. |             asian     2          0    .6526316   .0346337   190 |
//      |-----------------------------------------------------------------|
// 221. |              latx     0          0     .060241   .0116938   415 |
// 222. |              latx     1          0    .1413043   .0257497   184 |
// 223. |              latx     2          0    .1578947   .0265238   190 |
// 224. |             white     0          0    .1493976     .01752   415 |
// 225. |             white     1          0    .1086956   .0230088   184 |
//      |-----------------------------------------------------------------|
// 226. |             white     2          0     .131579   .0245882   190 |
// 227. |          othereth     0          0    .0891566   .0140055   415 |
// 228. |          othereth     1          0    .0543478   .0167584   184 |
// 229. |          othereth     2          0    .0578947   .0169878   190 |
// 230. |            female     0          0    .3927711   .0240019   415 |
//      |-----------------------------------------------------------------|
// 231. |            female     1          0    .3478261   .0352077   184 |
// 232. |            female     2          0    .4052632   .0357108   190 |
// 233. |              male     0          0    .5927711    .024147   415 |
// 234. |              male     1          0    .6467391   .0353335   184 |
// 235. |              male     2          0    .5842105   .0358501   190 |
//      |-----------------------------------------------------------------|
// 236. |          transfer     0          0    .2722892   .0218773   415 |
// 237. |          transfer     1          0    .4619565   .0368539   184 |
// 238. |          transfer     2          0    .4473684   .0361676   190 |
// 239. |      mid1scorestd     1          1   -1.031885   .0636158   166 |
// 240. |      mid1scorestd     2          1   -1.038894   .0645235   166 |
//      |-----------------------------------------------------------------|
// 241. |             y2019     1          1    .5180723   .0388995   166 |
// 242. |             y2019     2          1    .5180723   .0388995   166 |
// 243. |       prev_cumgpa     1          1    2.929238   .0473974   105 |
// 244. |       prev_cumgpa     2          1    3.000702   .0589801   114 |
// 245. | prev_cumgpa_unobs     1          1    .3674699   .0375327   166 |
//      |-----------------------------------------------------------------|
// 246. | prev_cumgpa_unobs     2          1     .313253   .0361081   166 |
// 247. |       mathquizstd     1          1    .0607922   .0713791   166 |
// 248. |       mathquizstd     2          1    .1570682   .0706351   166 |
// 249. |          pset_pre     1          1    .2831325   .0655509   166 |
// 250. |          pset_pre     2          1    .2530121   .0660173   166 |
//      |-----------------------------------------------------------------|
// 251. |       videos_mid1     1          1    13.72892   .9775277   166 |
// 252. |       videos_mid1     2          1    13.78916   1.023307   166 |
// 253. |     videos_mid1_u     1          1     9.79518   .6295926   166 |
// 254. |     videos_mid1_u     2          1    10.18072   .6645616   166 |
// 255. |     duration_mid1     1          1    2.604597   .1866719   166 |
//      |-----------------------------------------------------------------|
// 256. |     duration_mid1     2          1    2.599649   .1918695   166 |
// 257. |   duration_mid1_u     1          1    1.779538   .1128945   166 |
// 258. |   duration_mid1_u     2          1    1.852965   .1173922   166 |
// 259. |             asian     1          1    .7108434   .0352949   166 |
// 260. |             asian     2          1    .6325301   .0375327   166 |
//      |-----------------------------------------------------------------|
// 261. |              latx     1          1    .1385542   .0268956   166 |
// 262. |              latx     2          1    .1686747    .029152   166 |
// 263. |             white     1          1    .1024096    .023603   166 |
// 264. |             white     2          1    .1445783   .0273779   166 |
// 265. |          othereth     1          1    .0481928   .0166734   166 |
//      |-----------------------------------------------------------------|
// 266. |          othereth     2          1    .0542169   .0176287   166 |
// 267. |            female     1          1    .3373494   .0368078   166 |
// 268. |            female     2          1    .4036145   .0381949   166 |
// 269. |              male     1          1    .6566265   .0369658   166 |
// 270. |              male     2          1    .5843374   .0383672   166 |
//      |-----------------------------------------------------------------|
// 271. |          transfer     1          1    .4698795   .0388543   166 |
// 272. |          transfer     2          1    .4156626   .0383672   166 |
//      +-----------------------------------------------------------------+
//
// file ./data/generated/balance_table_data.csv saved

// %% [markdown]
// ## Instrument checks

// %% [markdown]
// ### Did students know their treatment statuses?

// %%
capture restore

qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

preserve

import delimited "./data/raw/DeID_fa19_attendance_checks.csv", clear
keep v15 v16
rename (v15 v16) (qTreat id)
gen year = 2019
drop in 1
tempfile tempf
save `tempf'

import delimited "./data/raw/DeID_fa18_attendance_checks.csv", clear
keep v9 v16
rename (v9 v16) (qTreat id)
gen year = 2018
drop in 1

append using `tempf'

* clean response
gen qtreat = .
replace qtreat = 1 if qTreat == "True" | qTreat == "1"
replace qtreat = 0 if qTreat == "False" | qTreat == "0"
drop qTreat

save `tempf', replace

restore
merge 1:1 id year using `tempf'

tab qtreat arm
// Out:
// (encoding automatically selected: ISO-8859-1)
// (16 vars, 418 obs)
//
//
//
//
// (1 observation deleted)
//
//
// file /var/folders/gy/wzctxswd5lz0q2mk9qksf81m0000gn/T//St09607.000005 saved as
//     .dta format
//
// (encoding automatically selected: UTF-8)
// (16 vars, 434 obs)
//
//
//
//
// (1 observation deleted)
//
// (variable qTreat was str57, now strL to accommodate using data's values)
//
// (850 missing values generated)
//
// (186 real changes made)
//
// (518 real changes made)
//
//
// file /var/folders/gy/wzctxswd5lz0q2mk9qksf81m0000gn/T//St09607.000005 saved as
//     .dta format
//
//
// (variable year was int, now float to accommodate using data's values)
//
//     Result                      Number of obs
//     -----------------------------------------
//     Not matched                             0
//     Matched                               850  (_merge==3)
//     -----------------------------------------
//
//
//            |               arm
//     qtreat | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       363        144         11 |       518
//          1 |        10         23        153 |       186
// -----------+---------------------------------+----------
//      Total |       373        167        164 |       704

// %%
frames dir
// Out:
// * default  850 x 138
// * results  272 x 7
//
// Note: Frames marked with * contain unsaved data.

// %%
set more off, perm
// Out:
// (set more preference recorded)

// %%
tab qtreat arm
di (10 + 23 + 11) / 704
// Out:
//            |               arm
//     qtreat | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       363        144         11 |       518
//          1 |        10         23        153 |       186
// -----------+---------------------------------+----------
//      Total |       373        167        164 |       704
//
// .0625

// %% [markdown]
// ### Relevancy

// %%
* get Montiel-Pflueger F-stats

ivreg2 mid2scorestd mid1scorestd y2019 (videos_mid2_u = treated) if arm > 0, robust
weakivtest

ivreg2 finalscorestd mid1scorestd y2019 (videos_final_u = treated) if arm > 0, robust
weakivtest
// Out:
// IV (2SLS) estimation
// --------------------
//
// Estimates efficient for homoskedasticity only
// Statistics robust to heteroskedasticity
//
//                                                       Number of obs =      395
//                                                       F(  3,   391) =    52.22
//                                                       Prob > F      =   0.0000
// Total (centered) SS     =   433.321407                Centered R2   =   0.1630
// Total (uncentered) SS   =   435.042424                Uncentered R2 =   0.1663
// Residual SS             =  362.6916087                Root MSE      =    .9582
//
// -------------------------------------------------------------------------------
//               |               Robust
//  mid2scorestd | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
// --------------+----------------------------------------------------------------
// videos_mid2_u |   .0265754   .0145527     1.83   0.068    -.0019474    .0550982
//  mid1scorestd |     .56305   .0481739    11.69   0.000     .4686309    .6574692
//         y2019 |   .3200665   .1618994     1.98   0.048     .0027496    .6373835
//         _cons |  -.1629726   .4730592    -0.34   0.730    -1.090152    .7642064
// -------------------------------------------------------------------------------
// Underidentification test (Kleibergen-Paap rk LM statistic):             17.944
//                                                    Chi-sq(1) P-val =    0.0000
// ------------------------------------------------------------------------------
// Weak identification test (Cragg-Donald Wald F statistic):               18.567
//                          (Kleibergen-Paap rk Wald F statistic):         18.613
// Stock-Yogo weak ID test critical values: 10% maximal IV size             16.38
//                                          15% maximal IV size              8.96
//                                          20% maximal IV size              6.66
//                                          25% maximal IV size              5.53
// Source: Stock-Yogo (2005).  Reproduced by permission.
// NB: Critical values are for Cragg-Donald F statistic and i.i.d. errors.
// ------------------------------------------------------------------------------
// Hansen J statistic (overidentification test of all instruments):         0.000
//                                                  (equation exactly identified)
// ------------------------------------------------------------------------------
// Instrumented:         videos_mid2_u
// Included instruments: mid1scorestd y2019
// Excluded instruments: treated
// ------------------------------------------------------------------------------
//
// (obs=395)
//
// Montiel-Pflueger robust weak instrument test
// --------------------------------------------
// Effective F statistic:       18.613
// Confidence level alpha:          5%
// --------------------------------------------
//
// --------------------------------------------
// Critical Values             TSLS      LIML
// --------------------------------------------
// % of Worst Case Bias
// tau=5%                    37.418    37.418
// tau=10%                   23.109    23.109
// tau=20%                   15.062    15.062
// tau=30%                   12.039    12.039
// --------------------------------------------
//
//
// IV (2SLS) estimation
// --------------------
//
// Estimates efficient for homoskedasticity only
// Statistics robust to heteroskedasticity
//
//                                                       Number of obs =      374
//                                                       F(  3,   370) =    64.19
//                                                       Prob > F      =   0.0000
// Total (centered) SS     =  395.7144969                Centered R2   =   0.3076
// Total (uncentered) SS   =  396.9372677                Uncentered R2 =   0.3097
// Residual SS             =  274.0045542                Root MSE      =    .8559
//
// -------------------------------------------------------------------------------
//               |               Robust
// finalscorestd | Coefficient  std. err.      z    P>|z|     [95% conf. interval]
// --------------+----------------------------------------------------------------
// videos_fina~u |   .0081109   .0040886     1.98   0.047     .0000973    .0161245
//  mid1scorestd |   .6541135   .0469237    13.94   0.000     .5621448    .7460823
//         y2019 |   .0548871   .0900208     0.61   0.542    -.1215504    .2313245
//         _cons |   .3869952   .2033575     1.90   0.057    -.0115781    .7855685
// -------------------------------------------------------------------------------
// Underidentification test (Kleibergen-Paap rk LM statistic):            128.411
//                                                    Chi-sq(1) P-val =    0.0000
// ------------------------------------------------------------------------------
// Weak identification test (Cragg-Donald Wald F statistic):              197.271
//                          (Kleibergen-Paap rk Wald F statistic):        194.575
// Stock-Yogo weak ID test critical values: 10% maximal IV size             16.38
//                                          15% maximal IV size              8.96
//                                          20% maximal IV size              6.66
//                                          25% maximal IV size              5.53
// Source: Stock-Yogo (2005).  Reproduced by permission.
// NB: Critical values are for Cragg-Donald F statistic and i.i.d. errors.
// ------------------------------------------------------------------------------
// Hansen J statistic (overidentification test of all instruments):         0.000
//                                                  (equation exactly identified)
// ------------------------------------------------------------------------------
// Instrumented:         videos_final_u
// Included instruments: mid1scorestd y2019
// Excluded instruments: treated
// ------------------------------------------------------------------------------
//
// (obs=374)
//
// Montiel-Pflueger robust weak instrument test
// --------------------------------------------
// Effective F statistic:      194.575
// Confidence level alpha:          5%
// --------------------------------------------
//
// --------------------------------------------
// Critical Values             TSLS      LIML
// --------------------------------------------
// % of Worst Case Bias
// tau=5%                    37.418    37.418
// tau=10%                   23.109    23.109
// tau=20%                   15.062    15.062
// tau=30%                   12.039    12.039
// --------------------------------------------

// %%
* Anderson-Rubin confidence intervals

capture restore
preserve

* change units to 10s of videos
replace videos_mid2_u = videos_mid2_u / 10
replace videos_final_u = videos_final_u / 10

weakiv ivreg2 mid2scorestd mid1scorestd y2019 (videos_mid2_u = treated) if arm > 0, robust gridpoints(2500)
weakiv ivreg2 mid2scorestd mid1scorestd y2019 (duration_mid2_u = treated) if arm > 0, robust gridpoints(2500)

weakiv ivreg2 finalscorestd mid1scorestd y2019 (videos_final_u = treated) if arm > 0, robust gridpoints(2500)
weakiv ivreg2 finalscorestd mid1scorestd y2019 (duration_final_u = treated) if arm > 0, robust gridpoints(2500)

restore
// Out:
// variable videos_mid2_u was byte now float
// (777 real changes made)
//
// variable videos_final_u was byte now float
// (807 real changes made)
//
// Estimating model for Wald tests using ivreg2...
// Estimating confidence sets over 2500 grid points
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// .................................................. 1,000
// .................................................. 1,050
// .................................................. 1,100
// .................................................. 1,150
// .................................................. 1,200
// .................................................. 1,250
// .................................................. 1,300
// .................................................. 1,350
// .................................................. 1,400
// .................................................. 1,450
// .................................................. 1,500
// .................................................. 1,550
// .................................................. 1,600
// .................................................. 1,650
// .................................................. 1,700
// .................................................. 1,750
// .................................................. 1,800
// .................................................. 1,850
// .................................................. 1,900
// .................................................. 1,950
// .................................................. 2,000
// .................................................. 2,050
// .................................................. 2,100
// .................................................. 2,150
// .................................................. 2,200
// .................................................. 2,250
// .................................................. 2,300
// .................................................. 2,350
// .................................................. 2,400
// .................................................. 2,450
// .................................................. 2,500
//
// Weak instrument robust tests and confidence sets for linear IV
// H0: beta[mid2scorestd:videos_mid2_u] = 0
// ------------------------------------------------------------------------------
//  Test |       Statistic         p-value |  Conf. level        Conf. Set
// ------+---------------------------------+-------------------------------------
//    AR | chi2(1)   =     3.80     0.0511 |      95%       [-.001098, .653135]
// ------+---------------------------------+-------------------------------------
//  Wald | chi2(1)   =     3.33     0.0678 |      95%       [-.019474, .550982]
// ------------------------------------------------------------------------------
// Confidence sets estimated for 2500 points in [-.304703, .83621].
// Number of obs N = 395.
// Method = lagrange multiplier (LM).
// Tests robust to heteroskedasticity.
// Wald statistic in last row is based on ivreg2 estimation and is not robust to
// weak instruments.
//
// Estimating model for Wald tests using ivreg2...
// Estimating confidence sets over 2500 grid points
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// .................................................. 1,000
// .................................................. 1,050
// .................................................. 1,100
// .................................................. 1,150
// .................................................. 1,200
// .................................................. 1,250
// .................................................. 1,300
// .................................................. 1,350
// .................................................. 1,400
// .................................................. 1,450
// .................................................. 1,500
// .................................................. 1,550
// .................................................. 1,600
// .................................................. 1,650
// .................................................. 1,700
// .................................................. 1,750
// .................................................. 1,800
// .................................................. 1,850
// .................................................. 1,900
// .................................................. 1,950
// .................................................. 2,000
// .................................................. 2,050
// .................................................. 2,100
// .................................................. 2,150
// .................................................. 2,200
// .................................................. 2,250
// .................................................. 2,300
// .................................................. 2,350
// .................................................. 2,400
// .................................................. 2,450
// .................................................. 2,500
//
// Weak instrument robust tests and confidence sets for linear IV
// H0: beta[mid2scorestd:duration_mid2_u] = 0
// ------------------------------------------------------------------------------
//  Test |       Statistic         p-value |  Conf. level        Conf. Set
// ------+---------------------------------+-------------------------------------
//    AR | chi2(1)   =     3.80     0.0511 |      95%       [-.000591, .391816]
// ------+---------------------------------+-------------------------------------
//  Wald | chi2(1)   =     3.36     0.0668 |      95%       [ -.01108, .331556]
// ------------------------------------------------------------------------------
// Confidence sets estimated for 2500 points in [-.182398, .502874].
// Number of obs N = 395.
// Method = lagrange multiplier (LM).
// Tests robust to heteroskedasticity.
// Wald statistic in last row is based on ivreg2 estimation and is not robust to
// weak instruments.
//
// Estimating model for Wald tests using ivreg2...
// Estimating confidence sets over 2500 grid points
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// .................................................. 1,000
// .................................................. 1,050
// .................................................. 1,100
// .................................................. 1,150
// .................................................. 1,200
// .................................................. 1,250
// .................................................. 1,300
// .................................................. 1,350
// .................................................. 1,400
// .................................................. 1,450
// .................................................. 1,500
// .................................................. 1,550
// .................................................. 1,600
// .................................................. 1,650
// .................................................. 1,700
// .................................................. 1,750
// .................................................. 1,800
// .................................................. 1,850
// .................................................. 1,900
// .................................................. 1,950
// .................................................. 2,000
// .................................................. 2,050
// .................................................. 2,100
// .................................................. 2,150
// .................................................. 2,200
// .................................................. 2,250
// .................................................. 2,300
// .................................................. 2,350
// .................................................. 2,400
// .................................................. 2,450
// .................................................. 2,500
//
// Weak instrument robust tests and confidence sets for linear IV
// H0: beta[finalscorestd:videos_final_u] = 0
// ------------------------------------------------------------------------------
//  Test |       Statistic         p-value |  Conf. level        Conf. Set
// ------+---------------------------------+-------------------------------------
//    AR | chi2(1)   =     3.89     0.0487 |      95%       [ .000492, .163137]
// ------+---------------------------------+-------------------------------------
//  Wald | chi2(1)   =     3.94     0.0473 |      95%       [ .000973, .161245]
// ------------------------------------------------------------------------------
// Confidence sets estimated for 2500 points in [-.079164, .241381].
// Number of obs N = 374.
// Method = lagrange multiplier (LM).
// Tests robust to heteroskedasticity.
// Wald statistic in last row is based on ivreg2 estimation and is not robust to
// weak instruments.
//
// Estimating model for Wald tests using ivreg2...
// Estimating confidence sets over 2500 grid points
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// .................................................. 1,000
// .................................................. 1,050
// .................................................. 1,100
// .................................................. 1,150
// .................................................. 1,200
// .................................................. 1,250
// .................................................. 1,300
// .................................................. 1,350
// .................................................. 1,400
// .................................................. 1,450
// .................................................. 1,500
// .................................................. 1,550
// .................................................. 1,600
// .................................................. 1,650
// .................................................. 1,700
// .................................................. 1,750
// .................................................. 1,800
// .................................................. 1,850
// .................................................. 1,900
// .................................................. 1,950
// .................................................. 2,000
// .................................................. 2,050
// .................................................. 2,100
// .................................................. 2,150
// .................................................. 2,200
// .................................................. 2,250
// .................................................. 2,300
// .................................................. 2,350
// .................................................. 2,400
// .................................................. 2,450
// .................................................. 2,500
//
// Weak instrument robust tests and confidence sets for linear IV
// H0: beta[finalscorestd:duration_final_u] = 0
// ------------------------------------------------------------------------------
//  Test |       Statistic         p-value |  Conf. level        Conf. Set
// ------+---------------------------------+-------------------------------------
//    AR | chi2(1)   =     3.89     0.0487 |      95%       [ .000366, .102476]
// ------+---------------------------------+-------------------------------------
//  Wald | chi2(1)   =     3.94     0.0470 |      95%       [ .000668, .101288]
// ------------------------------------------------------------------------------
// Confidence sets estimated for 2500 points in [-.049642, .151598].
// Number of obs N = 374.
// Method = lagrange multiplier (LM).
// Tests robust to heteroskedasticity.
// Wald statistic in last row is based on ivreg2 estimation and is not robust to
// weak instruments.

// %% [markdown]
// ## Base models
//
// Here we use the repeated sampling approach of Neyman to calculate confidence intervals, and fit a linear model that has no additional controls beyond those used to assign treatment.

// %%
/* Outcomes of interest:

- First stage
videos_b4_mid2_relu
duration_b4_mid2_relu
videos_rel_u
duration_rel_u

- Second stage
midterm2 score
final exam score

- Tests of exclusion restriction/spillovers to other studying
letter_option (did treatment affect decision to take 100A for letter grade?)
attendance
piazza questions
piazza answers
piazza views
pset visits (post)

- Spillover outcomes, concurrent quarter
gpa in all gpa-affecting courses
gpa, excluding 100A
gpa, non-econ courses
gpa, only econ courses excluding 100A
units taken for letter grade
units taken p/np
units withdrawn
n classes passed
n classes not passed
n class withdrawn
n classes taken p/np
n classes taken letter

- Spillovers, following quarter
took100b
videos_rel_u_100b
duration_rel_u_100b
midterm1 100B
midterm2 100B
final exam 100B
winter gpa all, excluding 100b, excluding all econ, econ excluding 100b
winter units taken letter, p/np, w
winter n classes pass, not passed, w
winter n classes taken letter, p/np
*/

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars
//sum

// %% [markdown]
// ### Checks

// %%
* heteroskedasticity? 

capture restore
preserve
keep if arm > 0

qui reg mid2scorestd treated mid1scorestd y2019
predict resid, resid
twoway (scatter resid mid1scorestd if arm == 1, mcolor(navy%75) msymbol(Oh)) ///
    (scatter resid mid1scorestd if arm == 2, mcolor(cranberry%75) msymbol(Dh)), ///
    legend(order(2 "Incentive" 1 "Control" ) pos(11) ring(0) col(1) region(lstyle(none))) /// 
    title("a) Midterm 2 model residuals") ///
    ylabel(-3(1)3) ///
    name(resid_mid2, replace)

drop resid

qui reg finalscorestd treated mid1scorestd y2019
predict resid, resid
twoway (scatter resid mid1scorestd if arm == 1, mcolor(navy%75) msymbol(Oh)) ///
    (scatter resid mid1scorestd if arm == 2, mcolor(cranberry%75) msymbol(Dh)), ///
    legend(order(2 "Incentive" 1 "Control" ) pos(11) ring(0) col(1) region(lstyle(none))) /// 
    title("b) Final exam model residuals") ///
    ylabel(-3(1)3) ///
    name(resid_final, replace)

graph combine resid_mid2 resid_final, name(combo_resid, replace) ysize(3) xsize(6)
export_img combo_resid

restore
// Out:
// (420 observations deleted)
//
//
// (35 missing values generated)
//
//
// file /Users/zack/.stata_kernel_cache/graph0.svg saved as SVG format
// file /Users/zack/.stata_kernel_cache/graph0.pdf saved as PDF format
//
//
//
// (56 missing values generated)
//
//
// file /Users/zack/.stata_kernel_cache/graph1.svg saved as SVG format
// file /Users/zack/.stata_kernel_cache/graph1.pdf saved as PDF format

// %%
* Demonstrating that imputing missings as the mean or as zeros doesn't affect 
*  estimates of the coefficients of interest.

capture restore
preserve

keep if arm > 0

qui sum prev_cumgpa if prev_cumgpa_unobs == 0
gen prev_cumgpa2 = prev_cumgpa
replace prev_cumgpa2 = r(mean) if prev_cumgpa_unobs

reg finalscorestd treated mid1scorestd y2019
reg finalscorestd treated mid1scorestd y2019 prev_cumgpa prev_cumgpa_unobs
reg finalscorestd treated mid1scorestd y2019 prev_cumgpa2

restore
// Out:
// (420 observations deleted)
//
//
//
// (155 real changes made)
//
//
//       Source |       SS           df       MS      Number of obs   =       374
// -------------+----------------------------------   F(3, 370)       =     54.32
//        Model |  120.994498         3  40.3314994   Prob > F        =    0.0000
//     Residual |  274.719999       370  .742486483   R-squared       =    0.3058
// -------------+----------------------------------   Adj R-squared   =    0.3001
//        Total |  395.714497       373  1.06089677   Root MSE        =    .86168
//
// ------------------------------------------------------------------------------
// finalscore~d |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1748242   .0892744     1.96   0.051    -.0007246    .3503731
// mid1scorestd |   .6402954   .0504566    12.69   0.000     .5410778    .7395131
//        y2019 |   .0165984   .0892946     0.19   0.853    -.1589902     .192187
//        _cons |   .6675452   .0933088     7.15   0.000     .4840631    .8510273
// ------------------------------------------------------------------------------
//
//
//       Source |       SS           df       MS      Number of obs   =       374
// -------------+----------------------------------   F(5, 368)       =     44.69
//        Model |  149.508888         5  29.9017776   Prob > F        =    0.0000
//     Residual |  246.205609       368  .669036981   R-squared       =    0.3778
// -------------+----------------------------------   Adj R-squared   =    0.3694
//        Total |  395.714497       373  1.06089677   Root MSE        =    .81795
//
// -------------------------------------------------------------------------------
// finalscorestd |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
//       treated |   .1575832   .0848274     1.86   0.064    -.0092241    .3243905
//  mid1scorestd |   .5451833   .0502148    10.86   0.000     .4464393    .6439273
//         y2019 |  -.0053294   .0848326    -0.06   0.950    -.1721469     .161488
//   prev_cumgpa |   .5990055   .0925701     6.47   0.000     .4169728    .7810383
// prev_cumgpa~s |   1.670722    .284671     5.87   0.000     1.110936    2.230508
//         _cons |  -1.152544    .299478    -3.85   0.000    -1.741447   -.5636415
// -------------------------------------------------------------------------------
//
//
//       Source |       SS           df       MS      Number of obs   =       374
// -------------+----------------------------------   F(4, 369)       =     55.67
//        Model |   148.92494         4   37.231235   Prob > F        =    0.0000
//     Residual |  246.789557       369  .668806387   R-squared       =    0.3763
// -------------+----------------------------------   Adj R-squared   =    0.3696
//        Total |  395.714497       373  1.06089677   Root MSE        =    .81781
//
// ------------------------------------------------------------------------------
// finalscore~d |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1604199   .0847585     1.89   0.059    -.0062503    .3270901
// mid1scorestd |   .5507426   .0498524    11.05   0.000     .4527121    .6487731
//        y2019 |  -.0042089   .0848095    -0.05   0.960    -.1709794    .1625617
// prev_cumgpa2 |   .5980805   .0925488     6.46   0.000     .4160912    .7800698
//        _cons |  -1.174583    .298496    -3.94   0.000     -1.76155   -.5876166
// ------------------------------------------------------------------------------

// %% [markdown]
// ### ITT

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str32 model

frames dir
// Out:
// * default  850 x 136
// * results  0 x 6
//
// Note: Frames marked with * contain unsaved data.

// %%
* define function to calculate difference in means and Neyman SEs

capture program drop neyman
program define neyman
    args y exam
    preserve

    * restrict sample
    keep if bothpairs_`exam' & arm > 0

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * reshape wide
    keep pairyear `y' treated
    reshape wide `y', i(pairyear) j(treated)

    * take difference in means
    gen diff = `y'1 - `y'0

    * get point estimate
    qui sum diff
    local meandiff = r(mean)
    
    * calc standard error estimate
    * SE_hat = [1/(J(J-1)) * sum(diff_j - diff_bar) ^ 2] ^ 0.5
    gen diff2 = (diff - `meandiff') ^ 2
    qui sum diff2
    local sumdiff2 = r(sum)
    local J = `N' / 2
    local se_hat = (1 / `J' / (`J' - 1) * `sumdiff2') ^ 0.5

    * post to frame
    frame post results ("`y'") (`meanctrl') (`meandiff') (`se_hat') (`N') ("Neyman")

    restore
    end

* test cases
// neyman mid2scorestd mid2
// neyman finalscorestd final
// frame results: li

// %%
* Write function to estimate linear model only controlling for treatment assignment method

capture program drop get_itt
program define get_itt
    args y exam
    preserve

    * restrict sample
    keep if !mi(`exam'scorestd)
    
    keep if !mi(`y') & arm > 0

    * mean control group
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * fit model
    reg `y' treated mid1scorestd y2019, robust
    
    * post to frame
    frame post results ("`y'") (`meanctrl') (_b[treated]) (_se[treated]) (e(N)) ("itt")

    restore
    end

* test cases
// get_itt mid2scorestd mid2
// get_itt finalscorestd final
// frame results: li

// %%
* Write function to estimate linear model only controlling for treatment assignment method
* and imputing zeros for missing outcomes

capture program drop get_itt_with_zeros
program define get_itt_with_zeros
    args y exam
    preserve

    * restrict sample to those seeing treatment status
    keep if !mi(assigned_grade) & arm > 0
    
    * replace `exam'scorestd with new one imputing zeros for missings,
    * then replace outcome with zero if missing. This is so stddev outcomes get correct
    * stddev units instead of zero, which would be a relatively high score.
    replace `exam'score = 0 if mi(`exam'score)
    get_std_units
    replace `y' = 0 if mi(`y')

    * mean control group
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * fit model
    reg `y' treated mid1scorestd y2019, robust
    
    * post to frame
    frame post results ("`y'") (`meanctrl') (_b[treated]) (_se[treated]) (e(N)) ("itt_zeros")

    restore
    end

* test cases
// get_itt_with_zeros mid2scorestd mid2
// get_itt_with_zeros finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars

local mid2vars videos_mid2_u ///
    videos_mid2 duration_mid2_u duration_mid2 mid2scorestd

local finalvars videos_final_u videos_final duration_final_u duration_final /// 
    finalscorestd ///
    letter_option attendance pset_post ///
    piazza_questions piazza_answers piazza_views piazza_daysonline ///
    gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a ///
    units_letter units_pnp units_w ///
    nclass_p nclass_np nclass_w nclass_letter nclass_pnp pclass_letter pclass_pnp ///
    took100b ///
    winter_gpa_letter winter_gpa_letter_sans100a winter_gpa_letter_sansecon winter_gpa_econ_sans100a ///
    winter_units_letter winter_units_pnp winter_units_w ///
    winter_nclass_p winter_nclass_np winter_nclass_w ///
    winter_nclass_letter winter_nclass_pnp winter_pclass_letter winter_pclass_pnp

local finalvarsb videos_b videos_b_u duration_b duration_b_u finalbscorestd pass100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui neyman `v' mid2
    qui get_itt `v' mid2
    qui get_itt_with_zeros `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui neyman `v' final
    qui get_itt `v' final
    qui get_itt_with_zeros `v' final
}


* Dependent vars observed at the end of 100B
capture drop bothpairs_finalb
rename final_100bstd finalbscorestd
gen bothpairs_finalb = !mi(finalbscorestd)
bys pair year: ereplace bothpairs_finalb = sum(bothpairs_finalb)
replace bothpairs_finalb = bothpairs_finalb >= 2
foreach v in `finalvarsb' {
    qui neyman `v' finalb
    qui get_itt `v' finalb
    qui get_itt_with_zeros `v' finalb
}
rename finalbscorestd final_100bstd


* Dependent vars observed in the middle of 100B
capture drop bothpairs_mid1b bothpairs_mid2b
forvalues i = 1/2 {
    di "`i'"
    rename mid`i'_100bstd mid`i'bscorestd
    gen bothpairs_mid`i'b = !mi(mid`i'bscorestd)
    bys pair year: ereplace bothpairs_mid`i'b = sum(bothpairs_mid`i'b)
    replace bothpairs_mid`i'b = bothpairs_mid`i'b >= 2
    qui neyman mid`i'bscorestd mid`i'b
    qui get_itt mid`i'bscorestd mid`i'b
    qui get_itt_with_zeros mid`i'bscorestd mid`i'b
    rename mid`i'bscorestd mid`i'_100bstd
}


* see results
frame results: li
// Out:
// (629 real changes made)
//
// (732 real changes made)
//
//
//
//
// 1
// (631 real changes made)
// (732 real changes made)
// 2
// (632 real changes made)
// (734 real changes made)
//
//
//      +---------------------------------------------------------------------+
//   1. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              videos_mid2_u |  23.27624 |  6.790055 | 1.699312 | 362 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   2. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              videos_mid2_u |  23.12953 |  6.625407 | 1.535681 | 395 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   3. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              videos_mid2_u |  22.92347 |  6.669462 | 1.526613 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   4. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                videos_mid2 |  34.38674 |  10.53591 | 3.117944 | 362 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   5. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                videos_mid2 |  33.91192 |  10.19244 | 2.848091 | 395 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   6. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                videos_mid2 |  33.59184 |  10.15065 | 2.821668 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   7. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |            duration_mid2_u |  3.886143 |  1.125516 | .2772946 | 362 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   8. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |            duration_mid2_u |  3.853877 |  1.098817 | .2543542 | 395 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   9. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |            duration_mid2_u |  3.826691 |  1.100912 | .2526906 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  10. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              duration_mid2 |  5.975752 |  1.722847 | .5474118 | 362 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  11. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              duration_mid2 |  5.878734 |  1.680279 | .5014099 | 395 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  12. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              duration_mid2 |  5.835404 |  1.664958 | .4963573 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  13. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               mid2scorestd |   .016723 |  .1833201 | .0940801 | 362 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  14. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               mid2scorestd | -6.88e-11 |  .1760727 | .0902943 | 395 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  15. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               mid2scorestd | -2.48e-09 |  .1383742 | .0897127 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  16. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             videos_final_u |  34.31928 |  21.08434 | 1.659218 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  17. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             videos_final_u |  33.95109 |  21.55435 | 1.545225 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  18. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             videos_final_u |  33.29082 |  21.36371 | 1.605532 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  19. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               videos_final |  54.40964 |  39.07229 |  4.37038 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  20. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               videos_final |  53.09239 |  39.25344 | 4.063951 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  21. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               videos_final |  52.44898 |  37.85894 | 3.994998 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  22. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           duration_final_u |  5.601814 |  3.357102 | .2704187 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  23. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           duration_final_u |  5.537307 |  3.429379 | .2511402 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  24. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           duration_final_u |  5.439365 |  3.390557 | .2602982 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  25. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             duration_final |  9.167701 |  6.256515 | .7495469 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  26. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             duration_final |  8.929994 |  6.300384 |  .691558 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  27. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             duration_final |  8.850473 |   6.06067 | .6797475 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  28. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              finalscorestd |  .0419063 |    .17384 | .1027427 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  29. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              finalscorestd | -1.34e-09 |  .1748243 | .0886893 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  30. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              finalscorestd |  3.15e-09 |  .0688695 | .0903134 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  31. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              letter_option |  .9578313 | -.0481928 | .0267604 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  32. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              letter_option |  .9510869 | -.0386101 | .0260221 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  33. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              letter_option |  .8928571 | -.0498716 | .0335585 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  34. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 attendance |  5.885542 | -.0903614 | .1738305 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  35. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 attendance |  5.907609 |  -.075822 | .1761695 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  36. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 attendance |  5.811224 | -.1870837 | .1802776 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  37. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  pset_post |  .4156626 | -.0060241 | .1394971 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  38. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  pset_post |  .4076087 |  .0516159 | .1314678 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  39. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  pset_post |  .3826531 |  .0368957 | .1236542 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  40. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           piazza_questions |  .5783132 |  .2951807 | .2971531 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  41. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           piazza_questions |  .5326087 |  .3152793 | .2549883 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  42. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |           piazza_questions |        .5 |  .2783919 | .2392668 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  43. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             piazza_answers |  .4939759 |  .0060241 | .2755057 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  44. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             piazza_answers |  .4673913 |  .0822503 | .2566592 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  45. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             piazza_answers |  .4387755 |   .060301 | .2388167 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  46. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               piazza_views |  52.33735 |  8.512048 | 8.252738 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  47. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               piazza_views |  49.80978 |  10.64254 | 7.643402 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  48. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               piazza_views |  47.55102 |  9.909402 | 7.321174 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  49. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          piazza_daysonline |  10.11446 |  1.885542 | 1.587244 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  50. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          piazza_daysonline |  10.39674 |  1.429269 | 1.548417 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  51. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          piazza_daysonline |  10.10204 |  1.034974 | 1.453188 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  52. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 gpa_letter |  2.589649 |  .1272058 | .0673855 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  53. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 gpa_letter |  2.591912 |  .1252629 | .0616506 | 373 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  54. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 gpa_letter |  2.511497 |  .0859683 | .0682757 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  55. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sans100a |  2.734828 |   .109314 | .0784565 | 329 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  56. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sans100a |  2.746626 |  .1033709 | .0723767 | 370 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  57. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sans100a |  2.666493 |  .0726822 | .0808993 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  58. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sansecon |  2.984595 |  .0911542 | .0898843 | 278 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  59. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sansecon |  2.989095 |   .063316 | .0952987 | 315 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  60. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |        gpa_letter_sansecon |  2.400527 |   .204502 | .1351667 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  61. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          gpa_econ_sans100a |  2.443732 |  .0152263 | .0760246 | 228 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  62. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          gpa_econ_sans100a |  2.439822 |  .0667777 | .0874412 | 258 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  63. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          gpa_econ_sans100a |  1.707738 | -.1364311 | .1280591 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  64. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               units_letter |  13.21687 |  .0481928 | .3807918 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  65. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               units_letter |  13.29891 |  .0494768 | .3217307 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  66. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               units_letter |  13.32143 | -.0477157 | .3095188 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  67. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  units_pnp |         1 |  .1807229 | .2126502 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  68. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  units_pnp |  .9891304 |   .210011 | .1962605 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  69. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  units_pnp |  1.005102 |  .1764478 | .1905526 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  70. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                    units_w |  .1686747 |  .0240964 | .0871234 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  71. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                    units_w |  .2173913 |  .0260175 | .1046019 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  72. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                    units_w |  .3061225 | -.0025181 | .1262853 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  73. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_p |   3.26506 |  .0903614 | .1045941 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  74. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_p |  3.282609 |  .0753706 | .0936251 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  75. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_p |  3.178571 |   .027659 | .0996416 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  76. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  nclass_np |  .3012048 | -.0060241 | .0636581 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  77. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  nclass_np |  .3097826 |  .0101565 | .0623283 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  78. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                  nclass_np |  .4234694 |  .0265034 | .0757365 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  79. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_w |  .0421687 |  .0060241 | .0217809 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  80. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_w |  .0543478 |  .0065044 | .0261505 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  81. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   nclass_w |  .0765306 | -.0006295 | .0315713 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  82. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              nclass_letter |  3.307229 |  .0301205 | .0990737 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  83. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              nclass_letter |  3.331522 |  .0304702 | .0829091 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  84. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              nclass_letter |  3.336735 |  .0094145 | .0797776 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  85. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 nclass_pnp |  .2590362 |  .0542169 | .0568467 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  86. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 nclass_pnp |  .2608696 |   .055057 |  .052113 | 374 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  87. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 nclass_pnp |  .2653061 |  .0447479 | .0503482 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  88. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              pclass_letter |  .9285141 | -.0128514 | .0153592 | 332 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  89. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              pclass_letter |  .9289855 |  -.013324 | .0139256 | 374 |
//      |---------------------------------------------------------------------|
// ...
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 134. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |       winter_pclass_letter |  .9538606 | -.0253943 | .0133942 | 360 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 135. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |       winter_pclass_letter |   .912415 | -.0275114 | .0231109 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 136. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          winter_pclass_pnp |  .0457292 |  .0178419 | .0138886 | 322 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 137. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          winter_pclass_pnp |  .0461394 |  .0253943 | .0133942 | 360 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 138. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |          winter_pclass_pnp |  .0416667 |  .0311932 | .0125176 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 139. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   videos_b |        30 |  12.77778 |  6.73558 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 140. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   videos_b |  25.46018 |  13.99861 | 4.450431 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 141. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   videos_b |  16.04592 |  4.298035 | 2.838483 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 142. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 videos_b_u |  22.09259 |  8.851851 | 4.035517 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 143. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 videos_b_u |  19.76991 |  9.872878 | 3.027476 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 144. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 videos_b_u |  12.43367 |  2.847823 | 2.016218 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 145. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 duration_b |  4.511271 |  1.881286 | 1.025364 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 146. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 duration_b |  3.817323 |  2.141301 |  .676448 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 147. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                 duration_b |  2.444674 |  .6289244 | .4319728 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 148. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               duration_b_u |    3.2384 |  1.330232 | .6041591 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 149. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               duration_b_u |  2.897707 |  1.510522 | .4505067 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 150. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               duration_b_u |  1.844114 |  .4292717 | .3001706 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 151. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             finalbscorestd |  .0004429 |  .0047253 | .1783199 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 152. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             finalbscorestd | -2.65e-09 |  .1185639 | .1371794 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 153. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             finalbscorestd | -1.53e-09 |  .0558573 | .0726836 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 154. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   pass100b |  .9814815 |  -.037037 |  .037037 | 108 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 155. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   pass100b |  .9734513 | -.0114243 | .0252237 | 211 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 156. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                   pass100b |  .5612245 |  -.092314 | .0476828 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 157. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid1bscorestd |  .1034037 | -.2432007 | .1753462 | 112 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 158. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid1bscorestd | -1.44e-09 | -.0414302 | .1266763 | 213 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 159. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid1bscorestd | -8.36e-10 | -.0277363 | .0709769 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 160. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid2bscorestd | -.0240863 | -.0369077 | .1953052 | 112 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                 Neyman                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 161. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid2bscorestd | -2.53e-10 |  .0030153 | .1294854 | 214 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                                    itt                              |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
// 162. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              mid2bscorestd | -1.47e-10 | -.0006584 | .0698187 | 402 |
//      |---------------------------------------------------------------------|
//      |                                  model                              |
//      |                              itt_zeros                              |
//      +---------------------------------------------------------------------+

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/itt_coeffs.csv", replace


* Export sample for Semenova (2025) generalized Lee Bounds (computed in R)
* and IPW estimation
* Sample: all randomized students who completed Micro A (saw treatment assignment)
* Selection indicator: took100b (enrolled in Micro B)
preserve
keep if !mi(assigned_grade) & arm > 0
export delimited treated took100b y2019 ///
    videos_b videos_b_u duration_b duration_b_u ///
    mid1_100bstd mid2_100bstd final_100bstd ///
    mid1scorestd mathquizstd mathquiz_unobs ///
    transfer prev_cumgpa prev_cumgpa_unobs ///
    female asian latx white ///
    using "./data/generated/semenova_sample.csv", replace
restore
// Out:
// file ./data/generated/itt_coeffs.csv saved
//
//
// (448 observations deleted)
//
// file ./data/generated/semenova_sample.csv saved

// %%
* IPW estimates for Micro B outcomes
* Reweight Micro B takers to look like the full experimental sample

capture frame drop ipw_results
frame create ipw_results str32 depvar meanctrl treatbeta stderr N str32 model

capture program drop est_ipw
program define est_ipw
    args y
    preserve

    * full sample: all randomized who completed Micro A
    keep if !mi(assigned_grade) & arm > 0

    * estimate propensity score: P(took100b=1 | X)
    logit took100b treated mid1scorestd mathquizstd mathquiz_unobs ///
        transfer prev_cumgpa prev_cumgpa_unobs ///
        female asian latx white y2019
    predict phat, pr

    * restrict to Micro B takers, generate IPW weights
    keep if took100b == 1
    gen ipw = 1 / phat

    * trim extreme weights at 1st/99th percentiles
    _pctile ipw, p(1 99)
    replace ipw = r(r1) if ipw < r(r1)
    replace ipw = r(r2) if ipw > r(r2)

    * control mean (unweighted, among Micro B takers)
    qui sum `y' if arm == 1
    local meanctrl = r(mean)

    * IPW-weighted regression
    reg `y' treated mid1scorestd y2019 [pweight=ipw], robust

    * post results
    frame post ipw_results ("`y'") (`meanctrl') (_b[treated]) (_se[treated]) (e(N)) ("ipw")

    restore
end

* Run IPW for each Micro B outcome
foreach v in videos_b videos_b_u duration_b duration_b_u mid1_100bstd mid2_100bstd final_100bstd {
    qui est_ipw `v'
}

frame ipw_results: li
frame ipw_results: export delimited "./data/generated/ipw_100b.csv", replace
// Out:
//      +---------------------------------------------------------------+
//      |        depvar    meanctrl   treatb~a     stderr     N   model |
//      |---------------------------------------------------------------|
//   1. |      videos_b    25.62281   16.05752   4.646589   214     ipw |
//   2. |    videos_b_u    19.94737   11.32539   3.186102   214     ipw |
//   3. |    duration_b    3.842856   2.478298   .7057157   214     ipw |
//   4. |  duration_b_u    2.926577   1.735196   .4701485   214     ipw |
//   5. |  mid1_100bstd   -1.44e-09    -.09663   .1526062   213     ipw |
//      |---------------------------------------------------------------|
//   6. |  mid2_100bstd   -2.53e-10   .0170041   .1462883   214     ipw |
//   7. | final_100bstd   -2.65e-09   .1329188   .1457244   211     ipw |
//      +---------------------------------------------------------------+
//
// file ./data/generated/ipw_100b.csv saved

// %% [markdown]
// ### LATE

// %%
* We'll use ivregress for the base model and a custom function for the Neyman model

* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str32 model

frames dir
// Out:
// * default  850 x 138
// * results  0 x 6
//
// Note: frames marked with * contain unsaved data

// %%
* define function for ivregress

capture program drop est_late
program define est_late
    args y exam

    capture restore
    preserve

    * restrict sample
    qui keep if !mi(`y') & arm > 0

    * adjust units of videos
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local ctrlmean = r(mean)

    * estimate iv, twice
    qui ivregress 2sls `y' mid1scorestd y2019 (videos_`exam'_u = treated), vce(robust)
    local late_v = _b[videos_`exam'_u]
    local se_v = _se[videos_`exam'_u]
    qui ivregress 2sls `y' mid1scorestd y2019 (duration_`exam'_u = treated), vce(robust)
    local late_d = _b[duration_`exam'_u]
    local se_d = _se[duration_`exam'_u]

    * post to frame, twice
    frame post results ("`y'") (`ctrlmean') (`late_v') (`se_v') (`N') ("late_v")
    frame post results ("`y'") (`ctrlmean') (`late_d') (`se_d') (`N') ("late_d")

    restore
    end

* test cases
// est_late mid2scorestd mid2
// est_late finalscorestd final
// frame results: li

// %%
* define function for ivregress

capture program drop est_late_with_zeros
program define est_late_with_zeros
    args y exam

    capture restore
    preserve

    * restrict sample to those seeing treatment assignment
    keep if !mi(assigned_grade) & arm > 0    
    
    * replace `exam'scorestd with new one imputing zeros for missings,
    * then replace outcome with zero if missing. This is so stddev outcomes get correct
    * stddev units instead of zero, which would be a relatively high score.
    replace `exam'score = 0 if mi(`exam'score)
    get_std_units
    replace `y' = 0 if mi(`y')

    * adjust units of videos
    replace videos_`exam'_u = 0 if mi(videos_`exam'_u)
    replace duration_`exam'_u = 0 if mi(duration_`exam'_u)
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local ctrlmean = r(mean)

    * estimate iv, twice
    qui ivregress 2sls `y' mid1scorestd y2019 (videos_`exam'_u = treated), vce(robust)
    local late_v = _b[videos_`exam'_u]
    local se_v = _se[videos_`exam'_u]
    qui ivregress 2sls `y' mid1scorestd y2019 (duration_`exam'_u = treated), vce(robust)
    local late_d = _b[duration_`exam'_u]
    local se_d = _se[duration_`exam'_u]

    * post to frame, twice
    frame post results ("`y'") (`ctrlmean') (`late_v') (`se_v') (`N') ("late_v_with_zeros")
    frame post results ("`y'") (`ctrlmean') (`late_d') (`se_d') (`N') ("late_d_with_zeros")

    restore
    end

* test cases
// est_late_with_zeros mid2scorestd mid2
// est_late_with_zeros finalscorestd final
// frame results: li

// %%
* define function to calculate difference in means and Neyman SEs


capture program drop neyman_late
program define neyman_late
    args y exam
    preserve

    * restrict sample
    qui keep if bothpairs_`exam' & arm > 0

    * adjust units of videos
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    qui sum `y' if arm == 1
    local ctrlmean = r(mean)

    * reshape wide
    qui keep pairyear `y' treated videos_`exam'_u duration_`exam'_u
    qui reshape wide `y' videos_`exam'_u duration_`exam'_u, i(pairyear) j(treated)

    * take difference in means for itt and first stages
    gen itt = `y'1 - `y'0
    gen fs_v = videos_`exam'_u1 - videos_`exam'_u0
    gen fs_d = duration_`exam'_u1 - duration_`exam'_u0

    * get point estimate
    foreach v in itt fs_v fs_d {
        qui sum `v'
        local meandiff_`v' = r(mean)
    }
    local late_v = `meandiff_itt' / `meandiff_fs_v'
    local late_d = `meandiff_itt' / `meandiff_fs_d'
    
    * calc standard error estimates
    * SE_hat = [1/(J(J-1)) * sum(diff_j - diff_bar) ^ 2] ^ 0.5
    local J = `N' / 2
    foreach v in itt fs_v fs_d {
        capture drop diff2
        gen diff2 = (`v' - `meandiff_`v'') ^ 2
        qui sum diff2
        local se_hat_`v' = (1 / `J' / (`J' - 1) * r(sum)) ^ 0.5
    }

    * SE for LATE approx b1/b2 sqrt( V(b1)/b1^2 + V(b2)/b2^2 - 2 * cov(b1, b2) / (b1 * b2) )
    * do this calc twice for each meandiff_fs

    foreach x in "v" "d" {
        * calculate covariance between itt estimate and first stage estimate
        capture drop diff2
        gen diff2 = (itt - `meandiff_itt') * (fs_`x' - `meandiff_fs_`x'')
        qui sum diff2
        local cov_`x' = 1 / `J' / (`J' - 1) * r(sum)
        * get variance terms
        local term0 = (`meandiff_itt' / `meandiff_fs_`x'')
        local term1 = (`se_hat_itt' ^ 2) / (`meandiff_itt' ^ 2)
        local term2 = (`se_hat_fs_`x'' ^ 2) / (`meandiff_fs_`x'' ^ 2)
        local term3 = 2 * `cov_`x'' / (`meandiff_itt' * `meandiff_fs_`x'')
        * check terms
//         forvalues i = 0/3 {
//             di `term`i''
//         }
        * calc standard error
        local se_`x' = `term0' * sqrt( `term1' + `term2' - `term3' )
//         di `se_`x''
    }

    * post to frame, twice
    frame post results ("`y'") (`ctrlmean') (`late_v') (`se_v') (`N') ("N_late_v")
    frame post results ("`y'") (`ctrlmean') (`late_d') (`se_d') (`N') ("N_late_d")

    restore
    end

* test cases
// neyman_late mid2scorestd mid2
// neyman_late finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars for which we estimate LATEs
// TODO: add 100b video vars

local mid2vars mid2scorestd

local finalvars finalscorestd 


* 100B outcomes
local finalvarsb final_100bstd


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui est_late `v' mid2
    qui est_late_with_zeros `v' mid2
    qui neyman_late `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui est_late `v' final
    qui est_late_with_zeros `v' final
    qui neyman_late `v' final
}

* see results
frame results: li
// Out:
//      +-------------------------------------------------------+
//   1. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd | -6.88e-11 | .2657538 | .1455273 | 395 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                              late_v                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   2. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd | -6.88e-11 | .1602384 | .0874088 | 395 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                              late_d                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   3. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd | -2.48e-09 | .2074743 |  .138052 | 402 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                   late_v_with_zeros                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   4. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd | -2.48e-09 | .1256905 |  .083498 | 402 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                   late_d_with_zeros                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   5. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd |   .016723 | .2699833 | .1498234 | 362 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                            N_late_v                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   6. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      |  mid2scorestd |   .016723 | .1628766 | .0896923 | 362 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                            N_late_d                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   7. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd | -1.34e-09 | .0811086 | .0408865 | 374 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                              late_v                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   8. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd | -1.34e-09 | .0509784 | .0256688 | 374 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                              late_d                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//   9. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd |  3.15e-09 | .0322367 | .0418386 | 402 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                   late_v_with_zeros                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//  10. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd |  3.15e-09 | .0203122 | .0263527 | 402 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                   late_d_with_zeros                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//  11. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd |  .0419063 | .0824498 | .0489504 | 332 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                            N_late_v                   |
//      +-------------------------------------------------------+
//
//      +-------------------------------------------------------+
//  12. |        depvar |  meanctrl | treatb~a |   stderr |   N |
//      | finalscorestd |  .0419063 | .0517828 | .0307475 | 332 |
//      |-------------------------------------------------------|
//      |                               model                   |
//      |                            N_late_d                   |
//      +-------------------------------------------------------+

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/lates_coeffs.csv", replace
// Out:
// file ./data/generated/lates_coeffs.csv saved

// %%
* Bootstrap standard errors

* Not using this becuase dist variance may not be finite
* TODO: look into altenative options, perhaps parametric bootstrap, using
* percentiles, etc.

capture program drop neyman_boot
program define neyman_boot 
    args y exam iters
    capture frame change default
    capture restore
    preserve

    * restrict sample
    keep if bothpairs_`exam' & arm > 0

    * get N and mean ctrl group
    qui sum `y'
    local N = r(N)
    local J = `N' / 2

    * reshape wide
    qui keep pairyear `y' treated videos_`exam'_u duration_`exam'_u
    qui reshape wide `y' videos_`exam'_u duration_`exam'_u, i(pairyear) j(treated)

    * take difference in means for itt and first stages
    gen itt = `y'1 - `y'0
    gen fs_v = videos_`exam'_u1 - videos_`exam'_u0
    gen fs_d = duration_`exam'_u1 - duration_`exam'_u0

    * get point estimate
    foreach v in itt fs_v fs_d {
        qui sum `v'
        local meandiff_`v' = r(mean)
    }
    local late_v = `meandiff_itt' / `meandiff_fs_v'
    local late_d = `meandiff_itt' / `meandiff_fs_d'

    * now resample `iters' times and store "LATE" estimates each round
    * store in frame `sim'. Each draw in draws
    capture frame drop sim
    frame create sim iter late_v late_d
    keep itt fs_v fs_d
    forvalue i = 1/`iters' {
        capture frame drop copyf
        frame copy default copyf
        frame change copyf
        bsample
        foreach v in itt fs_v fs_d {
            qui sum `v'
            local meandiff_`v' = r(mean)
        }
        local late_v_s = `meandiff_itt' / `meandiff_fs_v'
        local late_d_s = `meandiff_itt' / `meandiff_fs_d'
        frame post sim (`i') (`late_v_s') (`late_d_s')
        frame change default
    }
    frame sim: sum
    frame change sim
    histogram late_d, bin(50)
    frame change default
    
    frame sim: qui sum late_v
    local se_v = r(sd)
    frame sim: qui sum late_d
    local se_d = r(sd)

    * post to frame, twice
    frame post results ("`y'") (`late_v') (`se_v') (`N') ("N_boot_v")
    frame post results ("`y'") (`late_d') (`se_d') (`N') ("N_boot_d")

    frame change default
    restore
    end

* test cases
// neyman_boot mid2scorestd mid2 10000
// neyman_late finalscorestd final
// frame results: li

* Distribution (perhaps) does not have finite variance, std err does not converge

// ivregress 2sls mid2scorestd mid1scorestd y2019 (duration_mid2_u = treated) if arm > 0, vce(bootstrap, rep(10000)) nodots

// %% [markdown]
// ## Post-Double-Selection (control var selection)
//
// Here we use Belloni, Chernozhukov, and Hansen (2014)'s post-double-selection procedure to choose control variables in a principled manner. The method uses the lasso (least absolute shrinkage and selection operator) to predict, separately, outcomes of interest and treatment indicators. Then, one takes the union of the important covariates and includes them as controls in her specification of interest.
//
// Because `pdslasso` and `ivlasso`both produce coefficient estimates, we store these here as well.

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
* non linear controls?

/*
* add squares of nonbinary controls
capture drop mathquizstd2 pset_pre2 videos_b4_mid1_rel2
gen mathquizstd2 = mathquizstd * mathquizstd
gen pset_pre2 = pset_pre * pset_pre
gen videos_b4_mid1_rel2 = videos_b4_mid1_rel * videos_b4_mid1_rel
*/

// %% [markdown]
// ### ITT
//
// Here we use `pdslasso` to get control vars

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str99 ctrls str32 model

frames dir
// Out:
// * default  850 x 135
// * results  0 x 7
//
// Note: frames marked with * contain unsaved data

// %%
* Model without Fixed Effects

capture program drop pds_itt
program pds_itt, eclass
    args y
    // display 
    di "`=char(10)'`=char(13)'" ///
        "****************" "`=char(10)'`=char(13)'" "PDS for `y'..." ///
        "`=char(10)'`=char(13)'" "****************" "`=char(10)'`=char(13)'"
    // run PDS
    pdslasso `y' treated (y2019 mid1scorestd $ctrl_vars) if arm > 0, ///
        partial(y2019 mid1scorestd) robust noisily
    end


* Fixed Effect models

capture program drop pds_itt_fe
program pds_itt_fe, eclass
    args y bothpairs

    di "`=char(10)'`=char(13)'" ///
        "****************" "`=char(10)'`=char(13)'" "PDS for `y' with FEs..." ///
        "`=char(10)'`=char(13)'" "****************" "`=char(10)'`=char(13)'"

    
    pdslasso `y' treated (mid1scorestd $ctrl_vars) if arm > 0 & `bothpairs', ///
        partial(mid1scorestd) fe robust noisily
    end

// %%
* define function to get coefficient and ctrls for each outcome

capture program drop get_pds
program define get_pds
    args y exam

    * no fixed effects
    preserve
    keep if !mi(`exam'scorestd)
    qui sum `y' if arm == 1
    local meany = r(mean)
    qui pds_itt `y'
    restore
    frame post results ("`y'") (`meany') (_b[treated]) (_se[treated]) (e(N)) ("`e(xselected)'") ("noFEs")

    * fixed effects
    preserve
    xtset pairyear
    keep if bothpairs_`exam'
    qui sum `y' if arm == 1
    local meany = r(mean)
    qui pds_itt_fe `y' bothpairs_`exam'
    restore
    frame post results ("`y'") (`meany') (_b[treated]) (_se[treated]) (e(N)) ("`e(xselected)'") ("FEs")
    end

* test cases
// get_pds mid2scorestd mid2
// get_pds finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars
// TODO: add duration_rel_u for three times: before mid2, at final, and at 100b final

local mid2vars videos_mid2_u ///
    videos_mid2 duration_mid2_u duration_mid2 mid2scorestd

local finalvars videos_final_u videos_final duration_final_u duration_final /// 
    finalscorestd ///
    letter_option attendance pset_post ///
    piazza_questions piazza_answers piazza_views piazza_daysonline ///
    gpa_letter gpa_letter_sans100a gpa_letter_sansecon gpa_econ_sans100a ///
    units_letter units_pnp units_w ///
    nclass_p nclass_np nclass_w nclass_letter nclass_pnp pclass_letter pclass_pnp ///
    took100b ///
    winter_gpa_letter winter_gpa_letter_sans100a winter_gpa_letter_sansecon winter_gpa_econ_sans100a ///
    winter_units_letter winter_units_pnp winter_units_w ///
    winter_nclass_p winter_nclass_np winter_nclass_w ///
    winter_nclass_letter winter_nclass_pnp winter_pclass_letter winter_pclass_pnp

local finalvarsb videos_b videos_b_u duration_b duration_b_u finalbscorestd pass100b


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui get_pds `v' mid2
}


* Dependent vars observed after final
foreach v in `finalvars' {
    qui get_pds `v' final
}


* Dependent vars observed at the end of 100B
capture drop bothpairs_finalb
rename final_100bstd finalbscorestd
gen bothpairs_finalb = !mi(finalbscorestd)
bys pair year: ereplace bothpairs_finalb = sum(bothpairs_finalb)
replace bothpairs_finalb = bothpairs_finalb >= 2
foreach v in `finalvarsb' {
    qui get_pds `v' finalb
}
rename finalbscorestd final_100bstd


* Dependent vars observed in the middle of 100B
capture drop bothpairs_mid1b bothpairs_mid2b
forvalues i = 1/2 {
    di "`i'"
    rename mid`i'_100bstd mid`i'bscorestd
    gen bothpairs_mid`i'b = !mi(mid`i'bscorestd)
    bys pair year: ereplace bothpairs_mid`i'b = sum(bothpairs_mid`i'b)
    replace bothpairs_mid`i'b = bothpairs_mid`i'b >= 2
    qui get_pds mid`i'bscorestd mid`i'b
    rename mid`i'bscorestd mid`i'_100bstd
}


* see results
frame results: li
// Out:
// (629 real changes made)
//
// (732 real changes made)
//
//
//
//
// 1
// (631 real changes made)
// (732 real changes made)
// 2
// (632 real changes made)
// (734 real changes made)
//
//
//      +---------------------------------------------------------------------+
//   1. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              videos_mid2_u |  23.12953 |  5.966597 | .9824868 | 395 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                            videos_mid1_u duration_mid1_u  |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   2. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              videos_mid2_u |  23.27624 |  6.107009 | 1.111391 | 362 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                            videos_mid1_u  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   3. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                videos_mid2 |  33.91192 |  9.084972 | 2.033164 | 395 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                            videos_mid1_u duration_mid1_u  |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   4. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |                videos_mid2 |  34.38674 |  9.584745 | 2.185372 | 362 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                   videos_mid1_u duration_mid1_u pset_pre  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   5. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |            duration_mid2_u |  3.853877 |  .9886718 | .1595632 | 395 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                          duration_mid1_u  |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   6. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |            duration_mid2_u |  3.886143 |  1.017092 | .1797055 | 362 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                            videos_mid1_u duration_mid1_u  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   7. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              duration_mid2 |  5.878734 |  1.484301 | .3549374 | 395 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                          duration_mid1_u  |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   8. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |              duration_mid2 |  5.975752 |  1.554419 | .3805059 | 362 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                   videos_mid1_u duration_mid1_u pset_pre  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//   9. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               mid2scorestd | -6.88e-11 |  .1760727 | .0898359 | 395 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                                           |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  10. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               mid2scorestd |   .016723 |  .1743576 |  .095533 | 362 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                              mathquizstd  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  11. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             videos_final_u |  33.95109 |  21.27742 | 1.215254 | 374 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                            videos_mid1_u duration_mid1_u  |  noFEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  12. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |             videos_final_u |  34.31928 |  20.49299 | 1.274686 | 332 |
//      |---------------------------------------------------------------------|
//      |                                                    ctrls  |  model  |
//      |                                            videos_mid1_u  |    FEs  |
//      +---------------------------------------------------------------------+
//
//      +---------------------------------------------------------------------+
//  13. |                     depvar |  meanctrl | treatbeta |   stderr |   N |
//      |               videos_final |  53.09239 |  38.57132 | 3.397608 | 374 |
// --more--

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/pds_coeffs.csv", replace
// Out:
// file ./data/generated/pds_coeffs.csv saved

// %% [markdown]
// ### LATE
//
// Here we use `ivlasso` to get control vars

// %%
* create frame 'results' to store coefficients

capture frame drop results
frame create results str32 depvar meanctrl treatbeta stderr N str99 ctrls str32 model

frames dir
// Out:
// * default  850 x 138
// * results  0 x 7
//
// Note: frames marked with * contain unsaved data

// %%
* Model without Fixed Effects

capture program drop pds_iv
program pds_iv
    args y exam

    ** no Fixed Effects

    * restrict sample
    preserve
    keep if !mi(`y') & arm > 0

    * adjust units of videos_
    replace videos_`exam'_u = videos_`exam'_u / 10 // 10s of videos

    * control mean
    qui sum `y' if arm == 1
    local meany = r(mean)

    * estimate IV using PDS, video counts
    ivlasso `y' (y2019 mid1scorestd $ctrl_vars) (videos_`exam'_u=treated), ///
        partial(y2019 mid1scorestd treated) robust noisily
    frame post results ("`y'") (`meany') (_b[videos_`exam'_u]) (_se[videos_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IV_v")

    * estimate IV using PDS, video duration
    ivlasso `y' (y2019 mid1scorestd $ctrl_vars) (duration_`exam'_u=treated), ///
        partial(y2019 mid1scorestd treated) robust noisily
    frame post results ("`y'") (`meany') (_b[duration_`exam'_u]) (_se[duration_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IV_d")


    ** Fixed Effects

    * further restrict sample and xtset
    keep if bothpairs_`exam'
    xtset pairyear

    * get control mean
    qui sum `y' if arm == 1
    local meany = r(mean)

    * estimate IV using PDS with FEs, video counts
    ivlasso `y' (mid1scorestd $ctrl_vars) (videos_`exam'_u=treated), ///
        partial(mid1scorestd treated) fe robust noisily
    frame post results ("`y'") (`meany') (_b[videos_`exam'_u]) (_se[videos_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IVFE_v")

    * estimate IV using PDS with FEs, video duration
    ivlasso `y' (mid1scorestd $ctrl_vars) (duration_`exam'_u=treated), ///
        partial(mid1scorestd treated) fe robust noisily
    frame post results ("`y'") (`meany') (_b[duration_`exam'_u]) (_se[duration_`exam'_u]) ///
        (e(N)) ("`e(xselected)'") ("PDS_IVFE_d")

    restore
    end

* test cases
// qui pds_iv mid2scorestd mid2
// qui pds_iv finalscorestd final
// frame results: li

// %%
* Loop through all dependent vars for which we estimate LATEs
// TODO: add 100b video vars

local mid2vars mid2scorestd

local finalvars finalscorestd 

* 100B outcomes
local finalvarsb final_100bstd


* Dependent vars observed after second midterm
foreach v in `mid2vars' {
    qui pds_iv `v' mid2
}

* Dependent vars observed after final
foreach v in `finalvars' {
    qui pds_iv `v' final
}

* TODO: 100B LATEs

* see results
frame results: li
// Out:
//      +-----------------------------------------------------------------+
//   1. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |   mid2scorestd  |  -6.88e-11  |   .299515  |  .1505837  |  395  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                      videos_mid1_u duration_mid1_u |   PDS_IV_v |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   2. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |   mid2scorestd  |  -6.88e-11  |  .1808393  |  .0901626  |  395  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                                    duration_mid1_u |   PDS_IV_d |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   3. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |   mid2scorestd  |    .016723  |  .2929937  |  .1454094  |  362  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                      videos_mid1_u duration_mid1_u | PDS_IVFE_v |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   4. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |   mid2scorestd  |    .016723  |  .1699526  |  .0951755  |  362  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      | mathquizstd videos_mid1_u duration_mid1_u pset_pre | PDS_IVFE_d |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   5. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |  finalscorestd  |  -1.34e-09  |   .082312  |  .0412723  |  374  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                      videos_mid1_u duration_mid1_u |   PDS_IV_v |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   6. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |  finalscorestd  |  -1.34e-09  |  .0518015  |  .0259343  |  374  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                      videos_mid1_u duration_mid1_u |   PDS_IV_d |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   7. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |  finalscorestd  |   .0419063  |  .0867745  |  .0455351  |  332  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      |                      videos_mid1_u duration_mid1_u | PDS_IVFE_v |
//      +-----------------------------------------------------------------+
//
//      +-----------------------------------------------------------------+
//   8. |         depvar  |   meanctrl  |  treatb~a  |    stderr  |    N  |
//      |  finalscorestd  |   .0419063  |  .0429383  |  .0310935  |  332  |
//      |-----------------------------------------------------------------|
//      |                                              ctrls |      model |
//      | mathquizstd videos_mid1_u duration_mid1_u transfer | PDS_IVFE_d |
//      +-----------------------------------------------------------------+

// %%
* Export the results data for publication

frame results: export delimited "./data/generated/pds_iv_coeffs.csv", replace
// Out:
// >
// file ./data/generated/pds_iv_coeffs.csv saved

// %% [markdown]
// ## Heterogeneous treatment effects
//
// Here we add an interaction term to our specifications to estimate differences in treatment effects for key covariates.

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
* results frame for storing output

capture frame drop results
frame create results str32 depvar str32 interactvar meanctrl interactbeta stderr N

frames dir
// Out:
// * default  850 x 135
// * results  0 x 6
//
// Note: frames marked with * contain unsaved data

// %%
* Look at heterogeneity by:
* - blocking variables: mid1score and year
* - pre treatment videos, total and unique
* - demographics: transfer, ethnicity, gender

* why pretreatment videos?
* Hypothesis: those with high pretreatment videos are more likely to have watched
*  videos anyways, so potentially lower treatment effects.
* On the other hand, those who intended to watch videos may have done so for the 
*  very reason they knew they'd high have treatment effects.

capture restore
preserve

local interact_vars mid1scorestd y2019 ///
    videos_mid1 videos_mid1_u ///
    transfer female white asian latx othereth
    
* get het. ATE estimate for each covariate
foreach v in `interact_vars' {
    
    * two outcome vars
    foreach y in mid2scorestd finalscorestd {
        
        * get mean for control
        qui sum `y' if arm == 1
        local meanctrl = r(mean)
        
        * get interaction term
        capture drop interact
        gen interact = treated * `v'

        qui reg `y' treated interact mid1scorestd y2019 `v' if arm > 0, robust
        
        * store in frame
        frame post results ("`y'") ("`v'") (`meanctrl') (_b[interact]) ///
            (_se[interact]) (e(N))
        
        /*
        qui reg `y' treated interact mid1scorestd y2019 transfer female white asian latx `v' if arm > 0, robust
        
        * store in frame
        frame post results ("`y'") ("`v'") (`meanctrl') (_b[interact]) ///
            (_se[interact]) (e(N))
        */
    }
}

restore

frame results: li
// Out:
//      +------------------------------------------------------------------------+
//      |        depvar     interactvar    meanctrl   interac~a     stderr     N |
//      |------------------------------------------------------------------------|
//   1. |  mid2scorestd    mid1scorestd   -6.88e-11    .0091931    .086275   395 |
//   2. | finalscorestd    mid1scorestd   -1.34e-09    .0019628   .0954109   374 |
//   3. |  mid2scorestd           y2019   -6.88e-11    .0683024   .1814675   395 |
//   4. | finalscorestd           y2019   -1.34e-09    .0171747   .1791544   374 |
//   5. |  mid2scorestd     videos_mid1   -6.88e-11    .0114955   .0069895   395 |
//      |------------------------------------------------------------------------|
//   6. | finalscorestd     videos_mid1   -1.34e-09   -.0040357   .0072866   374 |
//   7. |  mid2scorestd   videos_mid1_u   -6.88e-11    .0198954   .0106596   395 |
//   8. | finalscorestd   videos_mid1_u   -1.34e-09    .0010049   .0106512   374 |
//   9. |  mid2scorestd        transfer   -6.88e-11    -.139185   .1826825   395 |
//  10. | finalscorestd        transfer   -1.34e-09    .1303846   .1780649   374 |
//      |------------------------------------------------------------------------|
//  11. |  mid2scorestd          female   -6.88e-11   -.2075472    .185177   395 |
//  12. | finalscorestd          female   -1.34e-09   -.3222725   .1877513   374 |
//  13. |  mid2scorestd           white   -6.88e-11    .6380493   .2601883   395 |
//  14. | finalscorestd           white   -1.34e-09    .2714211   .2501532   374 |
//  15. |  mid2scorestd           asian   -6.88e-11   -.4023684   .1890651   395 |
//      |------------------------------------------------------------------------|
//  16. | finalscorestd           asian   -1.34e-09   -.2154642   .1799567   374 |
//  17. |  mid2scorestd            latx   -6.88e-11    .2366881   .2535294   395 |
//  18. | finalscorestd            latx   -1.34e-09    .0218477   .2268566   374 |
//  19. |  mid2scorestd        othereth   -6.88e-11   -.1130778   .3072334   395 |
//  20. | finalscorestd        othereth   -1.34e-09    .2757307   .3465821   374 |
//      +------------------------------------------------------------------------+

// %%
* Export results as CSV

frame results: export delimited "./data/generated/het_coeffs.csv", replace
// Out:
// file ./data/generated/het_coeffs.csv saved

// %%
* adjust for multiple hypotheses

capture restore
preserve

keep if arm > 0

gen inter1 = treated * transfer
gen inter2 = treated * female
gen inter3 = treated * asian
gen inter4 = treated * latx
gen inter5 = treated * white
gen inter6 = treated * othereth
gen inter7 = treated * mid1scorestd 
gen inter8 = treated * y2019
gen inter9 = treated * videos_mid1_u

mhtreg (mid2scorestd inter1 transfer treated mid1scorestd y2019) ///
    (finalscorestd inter1 transfer treated mid1scorestd y2019) ///
 (mid2scorestd inter2 female treated mid1scorestd y2019) ///
    (finalscorestd inter2 female treated mid1scorestd y2019) ///
 (mid2scorestd inter3 asian treated mid1scorestd y2019) ///
    (finalscorestd inter3 asian treated mid1scorestd y2019) ///
(mid2scorestd inter4 latx treated mid1scorestd y2019) ///
    (finalscorestd inter4 latx treated mid1scorestd y2019) ///
 (mid2scorestd inter5 white treated mid1scorestd y2019) ///
    (finalscorestd inter5 white treated mid1scorestd y2019) ///
 (mid2scorestd inter6 othereth treated mid1scorestd y2019) ///
    (finalscorestd inter6 othereth treated mid1scorestd y2019) ///
(mid2scorestd inter7 treated mid1scorestd y2019) ///
    (finalscorestd inter7 treated mid1scorestd y2019) ///
 (mid2scorestd inter8 treated mid1scorestd y2019) ///
    (finalscorestd inter8 treated mid1scorestd y2019) ///
 (mid2scorestd inter9 videos_mid1_u treated mid1scorestd y2019) ///
    (finalscorestd inter9 videos_mid1_u treated mid1scorestd y2019)

restore
// Out:
// (420 observations deleted)
//
//
//
//
//
//
//
//
//
//
//
//              |       hyp       coef          p    pthm3_1      pbonf      pholm
// -------------+------------------------------------------------------------------
//           r1 |         1   -.139185       .458   .9956667          1          1
//           r2 |         2   .1303846   .4636667       .993          1          1
//           r3 |         3  -.2075472       .258   .9696667          1          1
//           r4 |         4  -.3222725   .0933333       .721          1          1
//           r5 |         5  -.4023684   .0353333   .4166667       .636   .6006667
//           r6 |         6  -.2154642   .2103333       .939          1          1
//           r7 |         7   .2366881       .343   .9803333          1          1
//           r8 |         8   .0218477   .9273333   .9936667          1          1
//           r9 |         9   .6380493       .012       .171       .216       .216
//          r10 |        10   .2714211   .2696667       .965          1          1
//          r11 |        11  -.1130778   .7323333          1          1          1
//          r12 |        12   .2757307   .4373333   .9956667          1          1
//          r13 |        13   .0091931   .9123333          1          1          1
//          r14 |        14   .0019628   .9833333   .9833333          1   .9833333
//          r15 |        15   .0683024   .7163333          1          1          1
//          r16 |        16   .0171747   .9183333   .9986667          1          1
//          r17 |        17   .0198954   .0563333       .555          1   .9013333
//          r18 |        18   .0010049   .9146667          1          1          1

// %% [markdown]
// ## Local linear trends by treatment arm
//
// Visual inspection of heterogeneity along mid1 score

// %%
* Plot local linear trends for mid2

capture restore
preserve

keep if !mi(finalscorestd)
replace arm = 1 if arm == 0

keep if mid1scorestd >= -3.0
keep if mid1scorestd <= 2

local videos videos_mid2_u
local outcome mid2scorestd
local n = 50
local bw = 0.9

twoway (lpolyci `videos' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `videos' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("") ///
    ytitle("Unique Videos") ///
    legend(order(4 "Incentive" 2 "Control") pos(1) ring(0) col(1) region(lstyle(none))) ///
    ylabel(0(10)60) ///
    name(lpolymid2v, replace)

twoway (lpolyci `outcome' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `outcome' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("Midterm 1 Score") ///
    ytitle("Midterm 2 Score") ///
    legend(order(4 "Incentive" 2 "Control") pos(11) ring(0) col(1) region(lstyle(none))) ///
    ylabel(-3(1)3) ///
    name(lpolymid2, replace)


* keep if matched pair or above median
keep if bothpairs_mid2 | (mid1scorestd > 0)

twoway (lpolyci `videos' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `videos' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("") ///
    ytitle("Unique videos") ///
    legend(order(4 "Incentive" 2 "Control") pos(1) ring(0) col(1) region(lstyle(none))) ///
    ylabel(0(10)60) ///
    name(lpolymid2vmatched, replace)

twoway (lpolyci `outcome' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `outcome' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("Midterm 1 Score") ///
    ytitle("Midterm 2 Score") ///
    legend(order(4 "Incentive" 2 "Control") pos(11) ring(0) col(1) region(lstyle(none))) ///
    ylabel(-3(1)3) ///
    name(lpolymid2matched, replace)

restore


* export combined plot

local filename lpolymid2

graph combine lpolymid2v lpolymid2vmatched lpolymid2 lpolymid2matched, ///
    name(`filename', replace) row(2) ///
    altshrink iscale(1.2) ysize(5) xsize(6)

export_img `filename'
// Out:
// (61 observations deleted)
//
// (415 real changes made)
//
// (11 observations deleted)
//
// (1 observation deleted)
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (25 observations deleted)
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (file ./tex/plots/lpolymid2.pdf written in PDF format)

// %%
* Plot local linear trends for final

capture restore
preserve

keep if !mi(finalscorestd)
replace arm = 1 if arm == 0

keep if mid1scorestd >= -3.0
keep if mid1scorestd <= 2

local videos videos_final_u
local outcome finalscorestd
local n = 100
local bw = 0.9

twoway (lpolyci `videos' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `videos' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("") ///
    ytitle("Unique Videos") ///
    legend(order(4 "Incentive" 2 "Control") pos(1) ring(0) col(1) region(lstyle(none))) ///
    ylabel(0(10)70) ///
    name(lpolyfinalv, replace)

twoway (lpolyci `outcome' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `outcome' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("Midterm 1 Score") ///
    ytitle("Final Exam Score") ///
    legend(order(4 "Incentive" 2 "Control") pos(11) ring(0) col(1) region(lstyle(none))) ///
    ylabel(-3(1)3) ///
    name(lpolyfinal, replace)


* keep if matched pair or above median
keep if bothpairs_final | (mid1scorestd > 0)

twoway (lpolyci `videos' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `videos' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("") ///
    ytitle("Unique videos") ///
    legend(order(4 "Incentive" 2 "Control") pos(1) ring(0) col(1) region(lstyle(none))) ///
    ylabel(0(10)70) ///
    name(lpolyfinalvmatched, replace)

twoway (lpolyci `outcome' mid1scorestd if arm == 1, kernel(tri) degree(1) bwidth(`bw') n(`n') ///
    ciplot(rarea) lcolor(navy) fcolor(gray*.5%60) alcolor(%0)) ///
    (lpolyci `outcome' mid1scorestd if arm == 2, degree(1) n(`n') ///
    ciplot(rarea) lcolor(cranberry) fcolor(gray*.5%60) alcolor(%0)), ///
    xtitle("Midterm 1 Score") ///
    ytitle("Final Exam Score") ///
    legend(order(4 "Incentive" 2 "Control") pos(11) ring(0) col(1) region(lstyle(none))) ///
    ylabel(-3(1)3) ///
    name(lpolyfinalmatched, replace)

restore


* export combined plot

local filename lpolyfinal

graph combine lpolyfinalv lpolyfinalvmatched lpolyfinal lpolyfinalmatched, ///
    name(`filename', replace) row(2) ///
    altshrink iscale(1.2) ysize(5) xsize(6)

export_img `filename'
// Out:
// (61 observations deleted)
//
// (415 real changes made)
//
// (11 observations deleted)
//
// (1 observation deleted)
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (35 observations deleted)
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (file ./tex/plots/lpolyfinal.pdf written in PDF format)

// %% [markdown]
// ## Student-level plots

// %%
* get data
qui get_idyearlevel
qui get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars

// %%
* histogram of unique videos watched

capture restore
preserve
keep if !mi(finalscore) // only include experiment completers

// how many students completed incentive?
gen meet_incent = videos_incent_counts_u >= 40
sum meet_incent if arm == 1
sum meet_incent if arm == 2

local w = 1
local filename = "hist_v_incent"
local histvar videos_incent_counts_u
twoway (hist `histvar' if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist `histvar' if arm == 2, ///
        width(`w') col(cranberry%50) freq xline(40, lpattern("dash") lcolor("black"))), ///
    legend(order(1 "Control" 2 "Incentive") ring(0) pos(11) col(1) region(lstyle(none))) ///
    xtitle("Videos") ///
    ytitle("Number of students") ///
    name(`filename', replace)

export_img `filename'

restore
// Out:
// (61 observations deleted)
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  meet_incent |        184    .1141304    .3188372          0          1
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//  meet_incent |        190    .9052632    .2936248          0          1
// This front-end cannot display the desired image type.
// (file ./tex/plots/hist_v_incent.pdf written in PDF format)

// %%
* regress treatment X indicator for watching at least N videos

* do this for mid2 and final


frame change default
capture frame drop results
frame create results N meanctrlm meanctrlf meantreatm meantreatf treatm lbm ubm treatf lbf ubf

capture restore
preserve

forvalues N = 0/74 {
    * number of people watching at least N vids
    capture drop vidsm vidsf
    local nvids = `N' * 1
    qui gen vidsm = videos_mid2_u >= `nvids'
    qui gen vidsf = videos_final_u >= `nvids'
    * mean in control arm
    qui sum vidsm if arm == 1
    local meanctrl_m = r(mean)
    qui sum vidsf if arm == 1
    local meanctrl_f = r(mean)
    * mean in treatment arm
    qui sum vidsm if arm == 2
    local meantreat_m = r(mean)
    qui sum vidsf if arm == 2
    local meantreat_f = r(mean)
    * regression for mid2
    qui reg vidsm ib1.arm if arm > 0, robust
    local treatm = _b[2.arm]
    local lbm = _b[2.arm] - 1.96*_se[2.arm]
    local ubm = _b[2.arm] + 1.96*_se[2.arm]
    * regression for final
    qui reg vidsf ib1.arm if arm > 0, robust
    local treatf = _b[2.arm]
    local lbf = _b[2.arm] - 1.96*_se[2.arm]
    local ubf = _b[2.arm] + 1.96*_se[2.arm]
    * post to frame
    frame post results (`nvids') (`meanctrl_m') (`meanctrl_f') (`meantreat_m') (`meantreat_f') ///
        (`treatm') (`lbm') (`ubm') (`treatf') (`lbf') (`ubf')
}

// frame results: li

frame change results

local c 71

twoway (line meanctrlm N if N <= `c', lcol("navy")) ///
    (line meantreatm N if N <= `c', lcol("cranberry")), ///
    ytitle("% watching {&ge}X unique videos") ///
    xtitle("") ///
    title("A: Midterm 2") ///
    xlabel(0(15)65) ///
    legend(order(2 "Incentive" 1 "Control" ) pos(2) ring(0) col(1) region(lstyle(none))) ///
    name(cdf_m, replace)

twoway (line meanctrlf N, lcol("navy")) ///
    (line meantreatf N, lcol("cranberry")), ///
    xtitle("") ///
    title("B: Final exam") ///
    xlabel(0(15)75) ///
    legend(order(2 "Incentive" 1 "Control" ) pos(2) ring(0) col(1) region(lstyle(none))) ///
    name(cdf_f, replace)

twoway (line treatm N if N <= `c', lcol("cranberry") yline(0, lcol("black") lpat("dash"))) ///
    (line lbm N if N <= `c', lcol("black") lpat("dash")) ///
    (line ubm N if N <= `c', lcol("black") lpat("dash")), ///
    ytitle("Effect of incentive on" "watching {&ge}X unique videos") ///
    xtitle("Unique videos") ///
    xlabel(0(15)65) ///
    ylabel(-0.15(.15)0.65) ///
    legend(off) ///
    name(treat_m, replace)

twoway (line treatf N, lcol("cranberry") yline(0, lcol("black") lpat("dash"))) ///
    (line lbf N, lcol("black") lpat("dash")) ///
    (line ubf N, lcol("black") lpat("dash")), ///
    xtitle("Unique videos") ///
    xlabel(0(15)75) ///
    ylabel(-0.15(.15)0.65) ///
    legend(off) ///
    name(treat_f, replace)

graph combine cdf_m cdf_f treat_m treat_f, name(combo_cdf, replace) row(2) ///
    altshrink iscale(1.2) ysize(5) xsize(6)
export_img combo_cdf


frame change default

restore
// Out:
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (file ./tex/plots/combo_cdf.pdf written in PDF format)

// %%
tab transfer arm
sum transfer if arm > 0
// Out:
//   Transfer |               arm
//    Student | Above med    Control    Treated |     Total
// -----------+---------------------------------+----------
//          0 |       306        109        118 |       533
//          1 |       114        106         97 |       317
// -----------+---------------------------------+----------
//      Total |       420        215        215 |       850
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//     transfer |        430     .472093    .4998021          0          1

// %%
* binscatter unique relevant videos watched vs mid1 score

capture restore
preserve
keep if !mi(finalscore) // only include experiment completers

local bins = 16

local filename = "binscatter_videosu"
binscatter2 videos_final_u mid1scorestd, by(arm) n(`bins') absorb(year) ///
    colors(green navy cranberry)
graph display


local filename = "binscatter_final"
binscatter2 finalscorestd mid1scorestd, by(arm) n(`bins') absorb(year) ///
    colors(green navy cranberry)
graph display

//     legend(order(3 "Incentive" 2 "Control"  1 "Above Median") pos(2) ring(0) col(1) region(lstyle(none))) ///
//     legend(order(3 "Incentive" 2 "Control"  1 "Above Median") pos(11) ring(0) col(1) region(lstyle(none))) ///


restore
// Out:
// (61 observations deleted)
//
//
//
// Num fes: 1
// y_vars_r:
// residvar: __00001O
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// Num fes: 1
// y_vars_r:
// residvar: __00001O
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %%
* binscatter, mid2 & final, videos and scores

capture restore
preserve
keep if !mi(mid2score)

local bins = 20
local options "by(arm) n(`bins') absorb(year) colors(navy cranberry) msymbols(Oh Dh)"
replace arm = 1 if arm == 0

local filename "binscatter_vmid2"
binscatter2 videos_mid2_u mid1scorestd, `options'
// ytitle("Unique videos by Midterm 2") name(`filename', replace) xtitle("")
// legend(order(2 "Incentive" 1 "Control") pos(2) ring(0) col(1) region(lstyle(none)))
graph display

local filename "binscatter_mid2"
binscatter2 mid2scorestd mid1scorestd, `options'
// ytitle("Midterm 2 score") name(`filename', replace) xtitle("Midterm 1 Score")
// legend(order(2 "Incentive" 1 "Control") pos(11) ring(0) col(1) region(lstyle(none)))
graph display


capture restore
preserve
keep if !mi(finalscore)

replace arm = 1 if arm == 0

local filename "binscatter_vfinal"
binscatter2 videos_final_u mid1scorestd, `options'
graph display
// ytitle("Unique videos by Final") name(`filename', replace) xtitle("") ///
// legend(order(2 "Incentive" 1 "Control") pos(2) ring(0) col(1) region(lstyle(none)))

local filename "binscatter_final"
binscatter2 finalscorestd mid1scorestd, `options'
graph display
// ytitle("Final exam score") name(`filename', replace) xtitle("Midterm 1 Score") ///
// legend(order(2 "Incentive" 1 "Control") pos(11) ring(0) col(1) region(lstyle(none)))

restore

// graph combine binscatter_vmid2 binscatter_mid2 binscatter_vfinal binscatter_final, ///
//    name(combo_binscatter, replace) row(2) ///
//    altshrink iscale(1.2) ysize(4) xsize(6) colfirst xcommon
// export_img combo_binscatter
// Out:
// (38 observations deleted)
//
//
//
// (417 real changes made)
//
//
// Num fes: 1
// y_vars_r:
// residvar: __00001P
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// Num fes: 1
// y_vars_r:
// residvar: __00001P
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// (61 observations deleted)
//
// (415 real changes made)
//
//
// Num fes: 1
// y_vars_r:
// residvar: __00001P
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.
// Num fes: 1
// y_vars_r:
// residvar: __00001P
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Quantile Regression

// %%
* final 

local filename = "finalquantreg"
tempfile temp
sqreg finalscorestd treated mid1scorestd if arm > 0, ///
    quantile(.05 .25 .5 .75 .95) reps(100) 
grqreg treated, ci ols olsci seed(1887) save(`temp') 
preserve
use `temp', clear
tw (rarea treated_cihi treated_cilo qtile, col(gs13)) ///
    (line treated qtile) (line ols_treated qtile if qtile <= 0.06 | qtile >= 0.94, ///
        lpattern("dash")), ///
    title("Quantile effects of being assigned" "treatment on final exam scores") ///
    legend(col(1) ring(0) order(2 "QITE estimates" 3 "OLS estimate")) ///
    ytitle("Final exam std. deviations") ///
    xtitle("Quantile") ///
    name(`filename', replace)
export_img `filename'
restore

* midterm 2

local filename = "mid2quantreg"
tempfile temp2
sqreg mid2scorestd treated mid1scorestd if arm > 0, ///
    quantile(.05 .25 .5 .75 .95) reps(100) 
grqreg treated, ci ols olsci seed(1887) save(`temp2') 
preserve
use `temp2', clear
tw (rarea treated_cihi treated_cilo qtile, col(gs13)) ///
    (line treated qtile) (line ols_treated qtile if qtile <= 0.06 | qtile >= 0.94, ///
        lpattern("dash")), ///
    title("Quantile effects of being assigned" "treatment on midterm 2 scores") ///
    legend(col(1) ring(0) order(2 "QTE estimates" 3 "OLS estimate")) ///
    ytitle("Midterm 2 std. deviations") ///
    xtitle("Quantile") ///
    name(`filename', replace)
export_img `filename'
restore
// Out:
// (fitting base model)
//
// Bootstrap replications (100)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
//
// Simultaneous quantile regression                    Number of obs =        374
//   bootstrap(100) SEs                                .05 Pseudo R2 =     0.1828
//                                                     .25 Pseudo R2 =     0.1986
//                                                     .50 Pseudo R2 =     0.1625
//                                                     .75 Pseudo R2 =     0.1552
//                                                     .95 Pseudo R2 =     0.1071
//
// ------------------------------------------------------------------------------
//              |              Bootstrap
// finalscore~d |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
// q05          |
//      treated |  -.0706883   .2049603    -0.34   0.730     -.473718    .3323413
// mid1scorestd |   .6286272   .1123434     5.60   0.000     .4077175    .8495369
//        _cons |  -.6105043   .1889898    -3.23   0.001    -.9821298   -.2388788
// -------------+----------------------------------------------------------------
// q25          |
//      treated |   .1619626   .1057362     1.53   0.126    -.0459548      .36988
// mid1scorestd |   .5971653    .038708    15.43   0.000     .5210507    .6732799
//        _cons |   .0145151   .0862011     0.17   0.866    -.1549889    .1840191
// -------------+----------------------------------------------------------------
// q50          |
//      treated |   .2861107    .123347     2.32   0.021     .0435637    .5286576
// mid1scorestd |   .7103903   .0615668    11.54   0.000     .5893266     .831454
//        _cons |   .6835508   .1084904     6.30   0.000     .4702176     .896884
// -------------+----------------------------------------------------------------
// q75          |
//      treated |   .1341069   .1300002     1.03   0.303    -.1215227    .3897364
// mid1scorestd |   .7041162   .0731848     9.62   0.000     .5602071    .8480253
//        _cons |   1.356993   .1300234    10.44   0.000     1.101318    1.612668
// -------------+----------------------------------------------------------------
// q95          |
//      treated |   .3353974   .2245464     1.49   0.136    -.1061459    .7769407
// mid1scorestd |   .5790122   .1437182     4.03   0.000     .2964078    .8616166
//        _cons |   2.007854   .1398563    14.36   0.000     1.732844    2.282864
// ------------------------------------------------------------------------------
//
// Only coefficients .05.25.5.75.95 will be plotted.
// (note: file /var/folders/tn/7qj50s3n0mbfh39gwd1dyz180000gn/T//St86162.00000h not
// >  found)
// file /var/folders/tn/7qj50s3n0mbfh39gwd1dyz180000gn/T//St86162.00000h saved
// This front-end cannot display the desired image type.
// (file ./tex/plots/finalquantreg.pdf written in PDF format)
//
//
//
//
// (fitting base model)
//
// Bootstrap replications (100)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
//
// Simultaneous quantile regression                    Number of obs =        395
//   bootstrap(100) SEs                                .05 Pseudo R2 =     0.1248
//                                                     .25 Pseudo R2 =     0.1614
//                                                     .50 Pseudo R2 =     0.1668
//                                                     .75 Pseudo R2 =     0.1479
//                                                     .95 Pseudo R2 =     0.0979
//
// ------------------------------------------------------------------------------
//              |              Bootstrap
// mid2scorestd |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
// q05          |
//      treated |   .0410676   .1823027     0.23   0.822    -.3173457    .3994809
// mid1scorestd |   .3894487   .0704626     5.53   0.000     .2509169    .5279805
//        _cons |  -.9220972   .1376257    -6.70   0.000    -1.192674   -.6515203
// -------------+----------------------------------------------------------------
// q25          |
//      treated |   .0238111   .1373165     0.17   0.862    -.2461578    .2937801
// mid1scorestd |   .5056841   .0568754     8.89   0.000     .3938651    .6175031
//        _cons |   .0018169   .1665626     0.01   0.991    -.3256508    .3292846
// -------------+----------------------------------------------------------------
// q50          |
//      treated |    .219027   .0882825     2.48   0.014     .0454606    .3925934
// mid1scorestd |   .6231179   .0530062    11.76   0.000     .5189059    .7273299
//        _cons |   .6357308   .0814072     7.81   0.000     .4756814    .7957802
// -------------+----------------------------------------------------------------
// q75          |
//      treated |   .2775314    .117677     2.36   0.019     .0461744    .5088884
// mid1scorestd |   .6145791   .0761577     8.07   0.000     .4648505    .7643077
//        _cons |   1.248706   .1308816     9.54   0.000     .9913881    1.506024
// -------------+----------------------------------------------------------------
// q95          |
//      treated |   .3050258    .264086     1.16   0.249    -.2141762    .8242278
// mid1scorestd |   .6116524   .1380367     4.43   0.000     .3402674    .8830373
//        _cons |   2.042408   .1511772    13.51   0.000     1.745189    2.339628
// ------------------------------------------------------------------------------
//
// Only coefficients .05.25.5.75.95 will be plotted.
// (note: file /var/folders/tn/7qj50s3n0mbfh39gwd1dyz180000gn/T//St86162.00000j not
// >  found)
// file /var/folders/tn/7qj50s3n0mbfh39gwd1dyz180000gn/T//St86162.00000j saved
// This front-end cannot display the desired image type.
// (file ./tex/plots/mid2quantreg.pdf written in PDF format)

// %% [markdown]
// ## Time series plots
//
// Here we plot the first stage as a function of time to see when students are watching videos.

// %%
import delimited "./data/generated/id-year-weekoy-arm_level.csv", clear varnames(1)

* keep only those who finish final
keep if !mi(finalscore)

* Hours units
replace duration = duration / 3600
replace durationu = durationu / 3600

unique year
unique id
unique id year
describe
// sum
// Out:
// (15 vars, 10,200 obs)
//
// (732 observations deleted)
//
// variable duration was long now double
// (4,322 real changes made)
//
// variable durationu was long now double
// (4,100 real changes made)
//
// Number of unique values of year is  2
// Number of records is  9468
//
// Number of unique values of id is  788
// Number of records is  9468
//
// Number of unique values of id year is  789
// Number of records is  9468
//
//
// Contains data
//   obs:         9,468
//  vars:            15
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// id              str9    %9s
// year            int     %8.0g
// weekoy          byte    %8.0g
// arm             byte    %8.0g
// finalscore      float   %9.0g
// videos          int     %8.0g
// duration        double  %12.0g
// videos_pre_mid1 byte    %8.0g
// videos_mid1_t~2 byte    %8.0g
// videos_post_m~2 byte    %8.0g
// videosu         byte    %8.0g
// durationu       double  %8.0g
// videos_pre_m~1u byte    %8.0g
// videos_mid1_~2u byte    %8.0g
// videos_post_~2u byte    %8.0g
// --------------------------------------------------------------------------------
// Sorted by:
//      Note: Dataset has changed since last saved.

// %%
* collapse to arm-weekoy level taking means

drop id year finalscore
collapse videos-videos_post_mid2u, by(weekoy arm)

sum
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       weekoy |         36         1.5     3.50102         -4          7
//          arm |         36           1    .8280787          0          2
//       videos |         36    5.388658    5.556613          0   30.92105
//     duration |         36    .8969776    .8805252          0   4.911211
// videos_pre~1 |         36    1.351174    1.435997          0   4.532609
// -------------+---------------------------------------------------------
// videos_mid~2 |         36     2.93457    3.751825          0   16.10526
// videos_pos~2 |         36    1.102914     2.47719          0   12.18421
//      videosu |         36    3.366022    2.827042          0   15.35263
//    durationu |         36    .5453793    .4398708          0   2.392538
// videos_pr~1u |         36    .8543317     1.03314          0   3.216867
// -------------+---------------------------------------------------------
// videos_mi~2u |         36    1.738379    2.065908          0   6.805263
// videos_po~2u |         36     .773311    1.609544          0   7.457895

// %%
* define plot function

capture program drop plot_ts
program plot_ts
    args filename y title xtitle ytitle
    twoway (line `y' weekoy if arm == 0, lcol(green)) ///
        (line `y' weekoy if arm == 1, lcol(navy)) ///
        (line `y' weekoy if arm == 2, lcol(cranberry) ///
            xline(-1, lpattern(dash) lcolor(black)) ///
            xline(3, lpattern(dash) lcolor(black)) ///
            xline(6, lpattern(dash) lcolor(black))), ///
        legend(off) ///
        title(`title') ///
        xtitle("") ///
        ytitle(`ytitle') ///
        xscale(range(-4 7)) ///
        xlabel(-4(1)7) ///
        xsize(2.5) ///
        ysize(1.7) ///
        name(`filename', replace)
    // export_img `filename'
    end


capture program drop plot_ts_legend
program plot_ts_legend
    args filename y title xtitle ytitle
    twoway (line `y' weekoy if arm == 0, lcol(green)) ///
        (line `y' weekoy if arm == 1, lcol(navy)) ///
        (line `y' weekoy if arm == 2, lcol(cranberry) ///
            xline(-1, lpattern(dash) lcolor(black)) ///
            xline(3, lpattern(dash) lcolor(black)) ///
            xline(6, lpattern(dash) lcolor(black))), ///
        legend(order(3 "Treated" 2 "Control" 1 "Above cutoff" ) ///
            pos(11) ring(0) col(1) region(lstyle(none))) ///
        title(`title') ///
        xtitle(`xtitle') ///
        ytitle(`ytitle') ///
        xscale(range(-4 7)) ///
        xlabel(-4(1)7) ///
        xsize(2.5) ///
        ysize(2) ///
        name(`filename', replace)
    // export_img `filename'
    end

// %%
* Mean videos, all
plot_ts tsall videos ///
    "Videos watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Mean videos, unique
plot_ts tsunique videosu ///
    "Unique videos watched per week" ///
    "Weeks since experiment began" ///
    "Unique videos"

* Mean duration
plot_ts_legend tsduration duration ///
    "Time spent watching per week" ///
    "Weeks since experiment began" ///
    "Hours"

* Videos before midterm 1
plot_ts tspremid1 videos_pre_mid1 ///
    "Videos relevant to first midterm watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Videos between mid1 and mid2
plot_ts tsmid1mid2 videos_mid1_to_mid2 ///
    "Videos relevant to second midterm watched per week" ///
    "Weeks since experiment began" ///
    "Videos"

* Videos post midterm 2
plot_ts_legend tspostmid2 videos_post_mid2 ///
    "Videos relevant to final exam watched per week" ///
    "Weeks since experiment began" ///
    "Videos"
// Out:
// This front-end cannot display the desired image type.
// . plot_ts tsunique videosu     "Unique videos watched per week"     "Weeks since
// >  experiment began"     "Unique videos"
// This front-end cannot display the desired image type.
// . plot_ts_legend tsduration duration     "Time spent watching per week"     "Wee
// > ks since experiment began"     "Hours"
// This front-end cannot display the desired image type.
// . plot_ts tspremid1 videos_pre_mid1     "Videos relevant to first midterm watche
// > d per week"     "Weeks since experiment began"     "Videos"
// This front-end cannot display the desired image type.
// . plot_ts tsmid1mid2 videos_mid1_to_mid2     "Videos relevant to second midterm
// > watched per week"     "Weeks since experiment began"     "Videos"
// This front-end cannot display the desired image type.
// . plot_ts_legend tspostmid2 videos_post_mid2     "Videos relevant to final exam
// > watched per week"     "Weeks since experiment began"     "Videos"
// This front-end cannot display the desired image type.

// %%
graph combine tsall tsunique tsduration, name(tscombo, replace) rows(3) ysize(6) xsize(5) ///
    altshrink iscale(1.5)

export_img tscombo

graph combine tspremid1 tsmid1mid2 tspostmid2, name(tscombo_exam, replace) rows(3) ysize(6) xsize(5) ///
    altshrink iscale(1.5)

export_img tscombo_exam
// Out:
// This front-end cannot display the desired image type.
// (file ./tex/plots/tscombo.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (file ./tex/plots/tscombo_exam.pdf written in PDF format)

// %% [markdown]
// ## Binge watching

// %%
* Histogram of most videos watched in any week

capture restore
import delimited "./data/generated/id-year-weekoy-arm_level.csv", clear varnames(1)

* keep only those who finish final
keep if !mi(finalscore)

preserve
local filename = "histweek"
local w = 2
bys id year: egen max_videos_week = max(videos)
keep if weekoy == 1
twoway (hist max_videos_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_videos_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week by each student") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Videos") ///
    name(`filename', replace)

restore

preserve
local filename = "histweek_u"
local w = 2
bys id year: egen unique_videos_week = max(videosu) 
keep if weekoy == 1
twoway (hist unique_videos_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist unique_videos_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most unique videos watched in one week by each student") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Videos") ///
    name(`filename', replace)

restore

* Histogram of most videos watched in any week before mid2
preserve
local filename = "histweekmid2"
keep if inrange(weekoy, 0, 3)
capture drop max_relevant_u_week
bys id year: egen max_relevant_u_week = max(videos)
keep if weekoy == 3
local w = 2
twoway (hist max_relevant_u_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_relevant_u_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week" "before Midterm 2") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Videos") ///
    name(`filename', replace)
restore

preserve
local filename = "histweekfinal"
keep if weekoy >= 4
capture drop max_relevant_u_week
bys id year: egen max_relevant_u_week = max(videos)
keep if weekoy == 4
local w = 2
twoway (hist max_relevant_u_week if arm == 1, ///
        width(`w') color(navy%50) freq) ///
    (hist max_relevant_u_week if arm == 2, ///
        width(`w') col(cranberry%50) freq), ///
    title("Most videos watched in one week" "between Midterm 2 and Final") ///
    legend(order(1 "Control" 2 "Treated") ring(0) pos(1) col(1)) ///
    xtitle("Videos") ///
    name(`filename', replace)
restore
// Out:
// (15 vars, 10,200 obs)
//
// (732 observations deleted)
//
//
//
//
//
// (8,679 observations deleted)
// This front-end cannot display the desired image type.
// (8,679 observations deleted)
// This front-end cannot display the desired image type.
// (6,312 observations deleted)
//
//
//
// (2,367 observations deleted)
// This front-end cannot display the desired image type.
// (6,312 observations deleted)
//
//
//
// (2,367 observations deleted)
// This front-end cannot display the desired image type.

// %% [markdown]
// ### Regression discontinuity

// %%
preserve
keep if bothpairs_final

* final
local filename = "rdplotfinal"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot finalscorestd mid1scorestd i.year if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(10) ///
    graph_options(name(`filename', replace) ///
    title("Effect of Treatement (ITT) at the cutoff on Final exam scores") ///
    legend(off) xtitle("Normalized Midterm 1 score") ///
    ytitle("Normalized Final exam score"))
export_img `filename'
graph display

restore

preserve
keep if bothpairs_mid2

* midterm 2
local filename = "rdplotmid2"
qui sum mid1scorestd if arm == 2
local cutoff = r(max)
rdplot mid2scorestd mid1scorestd i.year if arm != 1, ///
    c(`cutoff') p(2) kernel(tri) ci(95) shade nbins(10) ///
    graph_options(name(`filename', replace) ///
    title("Effect of Treatement (ITT) at the cutoff on Midterm 2 scores") ///
    legend(off) xtitle("Normalized Midterm 1 score") ///
    ytitle("Normalized Midterm 2 score"))
export_img `filename'
graph display

restore
// Out:
// (98 observations deleted)
//
//
//
//
// Mass points detected in the running variable.
//
// RD Plot with RD plot with manually set number of bins.
//
//          Cutoff c = 0 | Left of c  Right of c        Number of obs  =        581
// ----------------------+----------------------        Kernel         = Triangular
//         Number of obs |       162         419
//    Eff. Number of obs |       162         419
//   Order poly. fit (p) |         2           2
//      BW poly. fit (h) |     4.007       2.096
//  Number of bins scale |     1.000       1.000
//
// Outcome: finalscorestd. Running variable: mid1scorestd.
// ---------------------------------------------
//                       | Left of c  Right of c
// ----------------------+----------------------
//         Bins selected |        10          10
//    Average bin length |     0.401       0.210
//     Median bin length |     0.401       0.210
// ----------------------+----------------------
//     IMSE-optimal bins |         7           8
//   Mimicking Var. bins |        14          17
// ----------------------+----------------------
// Rel. to IMSE-optimal: |
//         Implied scale |     1.429       1.250
//     WIMSE var. weight |     0.255       0.339
//     WIMSE bias weight |     0.745       0.661
// ---------------------------------------------
//
//
// (file ./tex/plots/rdplotfinal.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (68 observations deleted)
//
//
//
//
// Mass points detected in the running variable.
//
// RD Plot with RD plot with manually set number of bins.
//
//          Cutoff c = 0 | Left of c  Right of c        Number of obs  =        598
// ----------------------+----------------------        Kernel         = Triangular
//         Number of obs |       176         422
//    Eff. Number of obs |       176         422
//   Order poly. fit (p) |         2           2
//      BW poly. fit (h) |     4.007       2.096
//  Number of bins scale |     1.000       1.000
//
// Outcome: mid2scorestd. Running variable: mid1scorestd.
// ---------------------------------------------
//                       | Left of c  Right of c
// ----------------------+----------------------
//         Bins selected |        10          10
//    Average bin length |     0.401       0.210
//     Median bin length |     0.401       0.210
// ----------------------+----------------------
//     IMSE-optimal bins |         5           7
//   Mimicking Var. bins |        19          18
// ----------------------+----------------------
// Rel. to IMSE-optimal: |
//         Implied scale |     2.000       1.429
//     WIMSE var. weight |     0.111       0.255
//     WIMSE bias weight |     0.889       0.745
// ---------------------------------------------
//
//
// (file ./tex/plots/rdplotmid2.pdf written in PDF format)
// This front-end cannot display the desired image type.

// %%
* Combine histograms

graph combine histweek histweek_u histweekmid2 histweekfinal, ///
    col(2) altshrink name(hist_maxweek)

export_img hist_maxweek
// Out:
// This front-end cannot display the desired image type.
// (file ./tex/plots/hist_maxweek.pdf written in PDF format)

// %% [markdown]
// ## Video-level plots

// %%
* Start with raw video data, collapse to arm-video level

* import and clean
import delimited ./data/raw/DeID_video-level_data.csv, clear varnames(1)
rename deid id
drop if length_mins == "NA"
drop if mi(id)
drop if syllabus_week == "NA"
destring visitid length_mins-syllabus_week, replace
gen video_duration_secs = 60 * minutes + seconds
keep id year videocode video_duration_secs incentivized-syllabus_week
gen views = 1

* collapse to student-video level
collapse (sum) views, by(id year videocode video_duration_secs incentivized-syllabus_week)

* merge arm
preserve
get_idyearlevel
// keep if complete experiment
keep if !mi(finalscore)
keep id year arm
tempfile temp
save `temp'
restore
// merge and drop videos watched by those not in sample
merge n:1 id year using `temp', nogen keep(2 3) 

* balance panel
bysort id year: gen idyear = 1 if _n == 1
replace idyear = sum(idyear)
drop id year
encode videocode, generate(vcode)
replace vcode = 1 if mi(vcode)
tsset idyear vcode
unique idyear vcode
unique idyear
unique vcode
local x = 789 * 73
di "Should have `x' observations after balancing."
tsfill, full
count
//tab vcode

* replace missings
drop videocode
bys idyear: ereplace arm = min(arm)
replace views = 0 if mi(views)
foreach v of varlist incentivized-video_duration_secs {
    bys vcode: ereplace `v' = min(`v')
}

sum

* collapse to arm-video level
drop idyear
gen conditional_views = views if views > 0
gen unique_views = views > 0
collapse (mean) unique_views views conditional_views, ///
    by(arm vcode incentivized-video_duration_secs)

label var unique_views "Perc. arm that saw video at least once"
label var views "Avg. views for that video by that arm"
label var conditional_views "Avg. views conditional on seeing the video at least once"

sum
// Out:
// (17 vars, 50,302 obs)
//
//
// (43 observations deleted)
//
// (0 observations deleted)
//
// (605 observations deleted)
//
// visitid: all characters numeric; replaced as long
// length_mins: all characters numeric; replaced as byte
// minutes: all characters numeric; replaced as byte
// seconds: all characters numeric; replaced as byte
// incentivized: all characters numeric; replaced as byte
// pre_mid1: all characters numeric; replaced as byte
// mid1_to_mid2: all characters numeric; replaced as byte
// post_mid2: all characters numeric; replaced as byte
// relevant_100a: all characters numeric; replaced as byte
// syllabus_week: all characters numeric; replaced as byte
//
//
//
//
//
//
// (72 vars, 850 obs)
// (0 observations deleted)
// (817 real changes made)
// (847 real changes made)
// (810 real changes made)
// (843 real changes made)
// (789 real changes made)
// (831 real changes made)
// (15 real changes made)
//
// (61 observations deleted)
//
//
//
// file /var/folders/tn/7qj50s3n0mbfh39gwd1dyz180000gn/T//St86162.00000q saved
//
//
//
//     Result                           # of obs.
//     -----------------------------------------
//     not matched                            36
//         from master                         0
//         from using                         36
//
//     matched                            29,900
//     -----------------------------------------
//
// (29,147 missing values generated)
//
// (29,935 real changes made)
//
//
//
// (36 real changes made)
//
//        panel variable:  idyear (unbalanced)
//         time variable:  vcode, 1 to 73, but with gaps
//                 delta:  1 unit
//
// Number of unique values of idyear vcode is  29936
// Number of records is  29936
//
// Number of unique values of idyear is  789
// Number of records is  29936
//
// Number of unique values of vcode is  73
// Number of records is  29936
//
//
// Should have 57597 observations after balancing.
//
//
//   57,597
//
//
// (27,661 real changes made)
//
// (27,697 real changes made)
//
// (27,697 real changes made)
// (27,697 real changes made)
// (27,697 real changes made)
// (27,697 real changes made)
// (27,697 real changes made)
// (27,697 real changes made)
// (27,697 real changes made)
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// incentivized |     57,597    16.10959    16.16671          0         48
//     pre_mid1 |     57,597    .3150685    .4645472          0          1
// mid1_to_mid2 |     57,597    .4794521    .4995819          0          1
//    post_mid2 |     57,597    .2054795     .404055          0          1
// relevan~100a |     57,597           1           0          1          1
// -------------+---------------------------------------------------------
// syllabus_w~k |     57,597    3.986301    2.463414          0          9
// video_dura~s |     57,597    571.1644    285.9159        108       1667
//        views |     57,597    .8221956     1.05007          0         11
//          arm |     57,597    .7148289    .8279389          0          2
//       idyear |     57,597         395    227.7665          1        789
// -------------+---------------------------------------------------------
//        vcode |     57,597          37    21.07149          1         73
//
//
// (27,697 missing values generated)
//
//
//
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// incentivized |        219    16.10959     16.2036          0         48
//     pre_mid1 |        219    .3150685    .4656074          0          1
// mid1_to_mid2 |        219    .4794521    .5007221          0          1
//    post_mid2 |        219    .2054795    .4049772          0          1
// relevan~100a |        219           1           0          1          1
// -------------+---------------------------------------------------------
// syllabus_w~k |        219    3.986301    2.469037          0          9
// video_dura~s |        219    571.1644    286.5684        108       1667
//          arm |        219           1    .8183671          0          2
//        vcode |        219          37    21.11958          1         73
// unique_views |        219    .5533187    .2654834   .0120482   .9947369
// -------------+---------------------------------------------------------
//        views |        219    .8858068    .5005991   .0120482   2.263158
// conditiona~s |        219    1.513241     .257191          1   2.324324

// %%
help scheme files
// Out:
// Description of scheme file format
// ---------------------------------
//
//    A scheme specifies the overall look of a graph and is defined by a scheme
//    file.  Each entry in a scheme file specifies the look for a specific
//    attribute of a specific graph element, such as the color of a symbol or the
//    size of text.
//
//    This information is provided primarily for those creating their own
//    graphics schemes.  We describe the format of scheme files and the effect
//    entries in the scheme file have on graphs.  For an overview of graphics
//    schemes, see [G-4] Schemes intro.
//
//
// Remarks
// -------
//
//    Remarks are presented under the following headings:
//
//         Creating your own schemes
//         What is a scheme-file entry?
//         Plot entries
//         Composite entries
//         Example scheme file
//         Suggestions
//
//    See scheme entries for the full list of scheme file entry definitions, but
//    first read the rest of this help file.
//
//
// Creating your own schemes
// -------------------------
//
//    Scheme schemename is stored in file scheme-schemename.scheme.  For example,
//    scheme s2color is stored in file scheme-s2color.scheme.  You can find where
//    a scheme file is located by typing
//
//         . which scheme-schemename.scheme
//
//    To create a new scheme, say mine, you need only create a file with the name
//    scheme-mine.scheme in your PERSONAL directory (see [P] sysdir).  You should
//    always base your scheme on a scheme shipped with Stata or on another scheme
//    based on an official scheme shipped with Stata.  You do that by putting the
//    line
//
//         #include schemename
//
//    before any scheme-file entries in your scheme.  If you want to base your
//    scheme on the scheme Stata uses by default when shipped, the line should
//    read
//
//         #include s2color
//
//    Graphs drawn with your scheme will start out looking just like those drawn
//    with s2color, and the entries that you make in your scheme file will serve
//    as edits to the s2color scheme.
//
//    For the adventurous, that may be sufficient information.  Look at the file
//    containing the s2color scheme - type which scheme-s2color.scheme to locate
//    that file.  You will find the lines in the file very readable, and you can
//    often guess what effect a line has.  When you want to change something,
//    simply create a similar line in your own file and change the style (the
//    last word on the line) to whatever you prefer; for example, for a color
//    entry change green to red.  For the less adventurous, read on.
//
//
// What is a scheme-file entry?
// ----------------------------
//
//    Each entry in a scheme file specifies how a particular attribute of a graph
//    element looks.  For example,
//
//         symbolsize matrix medium
//
//    specifies that the size of symbols used in scatterplot matrices is to be
//    medium.  We know this because the first word of the entry specifies the
//    styletype, or attribute affected; the second word is the graph element, or
//    the part affected (here matrix is short for scatterplot matrix); and the
//    third word is the style to be applied to the specific attribute of the
//    element.
//
//    We could change medium to small or large or any of the predefined styles
//    for markersizestyle, or we could specify a number for the size.  This
//    number is scaled so that 100 represents the full height of the graph (or
//    width if the width is smaller than the height); see [G-4] size.  The
//    available options for each style that may be specified, the 3rd word, are
//    documented in the tables of entries in scheme entries.
//
//    As a second example, we could change the text color for axis titles from
//    black to red by changing the line,
//
//         color axis_title black
//    to
//         color axis_title red
//
//    The available styles for color entries are the colorstyles, which include
//    explicit RGB values, rather than just named colors; see [G-4] colorstyle
//    for more information and a discussion of RGB values.  This means that we
//    could have changed the entry to
//
//         color axis_title "255 0 0"
//
//    a bright red.  Note that the RGB values and any style using more than one
//    token or word must be enclosed in quotes.
//
//
// Plot entries
// ------------
//
//    In addition to standard entries, scheme files have many entries for plots.
//
//    What is a plot?  When you type
//
//         . scatter y1 y2 x
//
//    the set of plotted markers for y1 versus x is the first plot and y2 versus
//    x is the second plot.  The markers for the first plot look different from
//    those for the second plot -, with perhaps different colors, or sizes, or
//    both.  With different graph commands, we might have two lines that differ,
//    or two sets of bars, or two pie slices, but in all cases we refer to these
//    as plot1 and plot2, and their looks are controlled by pstyles (short for
//    plot styles); see [G-4] pstyle.  The official scheme files have entries for
//    15 plots.
//
//    An entry to set the marker size for the second plot might be
//
//         symbolsize p2 medium
//
//    where p2 specifies plot2.
//
//    As it turns out, most of Stata's official schemes use the same size markers
//    for all plots.  Rather than having 15 entries to set the same marker size,
//    we simply omit the plot number and use the following single entry that
//    applies to all plots:
//
//         symbolsize p medium
//
//    We saw earlier how to base your own scheme on another scheme, such as the
//    official s2color scheme, and in that case we must take some care using just
//    p.  Because s2color defines only one symbolsize for all plots, we could
//    change the size of all symbols to large by adding the line
//
//         symbolsize p large
//
//    If s2color had been more specific and included entries to separately define
//    marker sizes for plot1 - plot15, then those more specific entries would
//    take precedence over our entry that did not specify a plot number.  We
//    would need to make individual entries for p1, p2, etc., for each plot.
//
//    Note that there are many attributes for plot elements, so there are many
//    plot entries.  In addition to marker size, there are entries for marker
//    color,
//
//         color p1 navy
//
//    marker symbol (shape),
//
//         symbol p circle
//
//    and sets of entries for lines, boxes, and other plot elements.
//
//    We pulled these two examples from the s2color scheme, and you can see that
//    the marker colors are different for each plot, whereas the marker symbols
//    are all circles.
//
//    Plot entries can be even more specific than plot number.  Some entries can
//    be directed at a particular kind of plot.  For example, the entry
//
//         color p3line yellow
//
//    will make the third line plot yellow but will not affect the color of
//    scatters, bars, or other plottypes.  While the s2color scheme does not take
//    advantage of this, you can create schemes with different colors and
//    intensities for each plottype -- scatter, line, bar, pie slice, etc.
//
//
// Composite entries
// -----------------
//
//    When we said that each entry specifies a particular attribute, that was an
//    oversimplification.  Some entries designate how the specific attributes
//    will be assigned for a collection of attributes for a graph element.  We
//    will call the entries for these collections composite entries.
//
//    Textboxes, for example, are used for titles, captions, and many other graph
//    text elements.  There are 11 attributes associated with a textbox, for
//    example, the size of the text, the color of the text, the color of the
//    background, and more; see [G-4] textboxstyle for the full list.  Changing a
//    textboxstyle entry, which is a composite entry, can potentially change all
//    11 of these attributes.
//
//    Let's look at two composite entries for textboxstyles:
//
//         textboxstyle axis_title axis_title
//         textboxstyle title      heading
//
//    The first entry specifies that the textboxstyle for axis titles is to be
//    the axis_title style, which seems like a good default.  Similarly, the
//    second line specifies that the textboxstyle for graph titles is to be the
//    heading style.
//
//    We could make axis titles look just like graph titles by changing the
//    specified textboxstyle of the first entry from axis_title to heading:
//
//         textboxstyle axis_title heading
//
//    Now, all axis titles will look like graph titles - they will have the same
//    text size, the same text color, etc.
//
//    Note that changes to composite entries can interact with the effects of
//    other entries.  In section 2, we changed the color of axis title text by
//    changing the color axis_title black entry to color axis_title red.  Now
//    that the composite textboxstyle entry for axis titles no longer specifies
//    the axis_title style, but rather the heading style, our color change will
//    have no effect.  We would need to change the color heading black entry to
//    color heading red to change the color of axis titles.  This would also
//    change the color of graph titles because the two now share the heading
//    textboxstyle.
//
//
// Example scheme file
// -------------------
//
//    As discussed in section 1, you can create your own schemes by creating a
//    file in your PERSONAL director called scheme-schemename.scheme.  Let's look
//    at a very simple example of such a scheme and name the scheme simple.
//
//
//         --- Begin scheme-simple.scheme ------------------------
//         #include s2color
//         color background  white
//         --- End scheme-simple.scheme --------------------------
//
//    This scheme is based on the s2color scheme; and we can tell that because of
//    the #include s2color line (see section 1). It changes only one thing -- the
//    background color is set to white.  If we use simple by including
//    scheme(simple) option on our graph command (see [G-4] Schemes intro for
//    more ways to set the scheme), then the graph region will no longer be
//    bluish gray, but will be white.  Any other graph element that references
//    the background color will also be white.
//
//    Now, let's look at a slightly more complicated example, which we will call
//    mine.
//
//         --- Begin scheme-mine.scheme --------------------------
//         * This is our better demonstration scheme.
//         * We should probably go on to describe it further here.
//
//         *! version 1.0.0   12nov2004
//
//         #include s2color
//
//         color background  white
//         color major_grid  "200 200 200"
//
//         color p1          "  0 255   0"
//         color p2          magenta
//
//         anglestyle vertical_tick    horizontal
//
//         clockdir   legend_position  4
//         numstyle   legend_cols      1
//         linestyle  legend           none
//         margin     legend           "5 0 0 0"
//         --- End scheme-mine.scheme ----------------------------
//
//    The first two lines are simply comments to help us identify our scheme
//    later.  Note that in scheme files, comments can only be entered as entire
//    lines and the lines must begin with a "*".  The third line is just a fancy
//    comment that identifies the version number of our scheme and the date it
//    was last updated.
//
//    The line #include s2color includes the entire contents of the official
//    s2color scheme in our scheme.  Again, this is just the starting point for
//    our changes.
//
//    As in simple, the line color background white sets the background color to
//    white.  Similarly, the line color major_grid "200 200 200" specifies that
//    grid lines be drawn in a light shade of gray.  Here we are using an RGB
//    value rather than a named colorstyle; see section 2.  For more entries
//    relating to grid lines, see scheme grids.
//
//    The next two entries,
//
//         color p1          "  0 255   0"
//         color p2          magenta
//
//    change how the first two plots look.  The first entry changes the color of
//    the first plot to a bright green using the RGB value "0 255 0".  Note that
//    the extra spacing is not required in the RGB value; it is only there to
//    make the entries align nicely in the file.  The second entry changes the
//    color of the second plot to magenta using the named colorstyle magenta.
//
//    The anglestyle vertical_tick horizontal entry changes the angle of text
//    used to label the ticks on the y axis (designated by vertical_tick) to be
//    horizontal so that they are not turned "sideways" as they are in the
//    s2color scheme.  See scheme axes for more entries relating to axes.
//
//    The last four entries change where and how legends are displayed.  The
//    clockdir legend_position 4 entry moves the legend from its default position
//    at the bottom of the graph to 4 o'clock - the right of the graph and
//    aligned with the bottom of the graph.  numstyle legend_cols 1 changes the
//    default number of columns in the legend from 2 to 1, while
//    linestyle legend none turns off the outlining around the legend.  Finally,
//    margin legend "5 0 0 0", designates a small margin, 5% of the graph size,
//    to the left of the legend with no margin (0) to the right, top, or bottom.
//    Find out more about these entries and other legend settings at scheme
//    legends.
//
//    In 10 lines, we have changed quite a bit about how graphs drawn with our
//    scheme will look.  You can click here to create a copy of
//    scheme-mine.scheme in your current working directory, and then you can draw
//    some graphs using the new scheme.  For starters try
//
//         . sysuse auto
//         . scatter trunk turn weight, scheme(s2color)
//         . scatter trunk turn weight, scheme(mine)
//
//    and compare the difference.  Try drawing some other bar graphs or others
//    with the new scheme.
//
//
// Suggestions
// -----------
//
//    The first and best suggestion is to try it.  The base scheme file for
//    graphics, scheme-s2color.scheme has over 1,700 entries.  Because composite
//    entries often change the effect of other entries (see section 4), the entry
//    descriptions in scheme entries at best indicate what will happen if you
//    base your new scheme on s2color; if you base it on another scheme, you may
//    need to experiment to get the desired effects.
//
//    It is also a good idea to build your new scheme in small steps while
//    checking the results on a graph.  Draw a graph that has all the elements
//    you want to control: perhaps axes, legends, or even the third scatter plot.
//    Then create your scheme file and place a #include statement to base your
//    scheme on an existing scheme.  Now redraw your graph using your new, but
//    empty, scheme using the scheme(your_scheme) option.  Now add one entry to
//    your scheme, issue the discard command, redraw the graph by reissuing the
//    graph command, and observe the result.  Then, make changes to the entry, if
//    desired; or, move on to the next element you want to change.  This is how
//    scheme-mine.scheme was created.  In particular, we did not know exactly how
//    all the changes to the legends would look, and we altered several entries
//    after seeing the initial results.
//
//    It is critical that you issue the discard command each time before you
//    reissue your graph command.  discard reinitializes the graphics system, and
//    that includes clearing the graphics scheme.  If you do not type discard,
//    graph will note that you are using the same scheme each time and will use
//    the already loaded scheme - ignoring the changes you made in the scheme
//    file.

// %%
*** Plot % of each arm viewing each video

* trim and reshape data for plotting
capture restore
preserve
keep if arm > 0
gen incent = incentivized > 0
label define incent 0 "Not incentivized" 1 "Incentivized"
label values incent incent
replace syllabus_week = syllabus_week + 1
reshape wide views unique_views conditional_views, i(vcode incentivized - video_duration_secs) j(arm)
order vcode video_duration_secs incent incentivized - syllabus_week unique_views* views* conditional_views*


* regression watch_rate = b0 + b1 * length + b2 * control_watch_rate
gen video_duration_mins = video_duration_secs / 60
sum video_duration_mins if incentivized
reg unique_views2 video_duration_mins unique_views1 if incentivized, robust
di -.0036438 * (19.93333 - 9.682639)

* ordered by incentives

capture drop ordering
sort unique_views1
bys incent: gen ordering = _n
local filename = "bar_uviews"
graph bar unique_views1 unique_views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) ///
        col(1) pos(10) region(lstyle(none))) ///
    title("Fraction of arm viewing each video") ///
    ytitle("Fraction of arm") ///
    name(`filename', replace)
export_img `filename'


* ordered by syllabus_week

capture drop ordering
sort syllabus_week unique_views1
bys incent: gen ordering = _n
local filename = "bar_uviews_week"
graph bar unique_views1 unique_views2, ///
    over(ordering, sort(1) lab(nolab)) over(syllabus_week) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) ///
        col(1) pos(10) region(lstyle(none))) ///
    title("Fraction of arm viewing each video") ///
    ytitle("Fraction of arm") ///
    b1title("Week of quarter") ///
    name(`filename', replace)
export_img `filename'


* ordered by video_duration

capture drop ordering
sort incent video_duration_secs
by incent: gen ordering = _n
local filename = "bar_uviews_duration"
graph bar unique_views1 unique_views2, ///
    over(ordering, lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) ///
        col(1) pos(10) region(lstyle(none))) ///
    title("Fraction of arm viewing each video") ///
    ytitle("Fraction of arm") ///
    b1title("Week of quarter") ///
    name(`filename', replace)
export_img `filename'


* Total views per person

capture drop ordering
sort incent unique_views1
by incent: gen ordering = _n
local filename = "bar_views"
graph bar views1 views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) ///
    col(1) pos(10) region(lstyle(none))) ///
    title("Views per person per video") ///
    ytitle("Views") ///
    name(`filename', replace)
export_img `filename'


* Conditional views per person

capture drop ordering
sort conditional_views1
bys incent: gen ordering = _n
local filename = "bar_cviews"
graph bar conditional_views1 conditional_views2, ///
    over(ordering, sort(1) lab(nolab)) over(incent) nofill ///
    bar(1, color(navy)) bar(2, color(cranberry)) ///
    legend(order(1 "Control" 2 "Treated") ring(0) ///
        col(1) pos(10) region(lstyle(none))) ///
    title("Views per person who watched at least once") ///
    ytitle("Views") ///
    name(`filename', replace)
export_img `filename'



restore
// Out:
// (73 observations deleted)
//
//
//
//
// (146 real changes made)
//
// (note: j = 1 2)
//
// Data                               long   ->   wide
// -----------------------------------------------------------------------------
// Number of obs.                      146   ->      73
// Number of variables                  13   ->      15
// j variable (2 values)               arm   ->   (dropped)
// xij variables:
//                                   views   ->   views1 views2
//                            unique_views   ->   unique_views1 unique_views2
//                       conditional_views   ->   conditional_views1 conditional_vi
// > ews2
// -----------------------------------------------------------------------------
//
//
//
//
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
// video_dur~ns |         48    9.682639    4.120275   3.516667   19.93333
//
//
// Linear regression                               Number of obs     =         48
//                                                 F(2, 45)          =      75.22
//                                                 Prob > F          =     0.0000
//                                                 R-squared         =     0.8008
//                                                 Root MSE          =     .03739
//
// -------------------------------------------------------------------------------
//               |               Robust
// unique_views2 |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// --------------+----------------------------------------------------------------
// video_dura~ns |  -.0036438   .0011081    -3.29   0.002    -.0058756   -.0014119
// unique_views1 |   .3689512   .0333567    11.06   0.000     .3017673    .4361351
//         _cons |   .7737015   .0243099    31.83   0.000     .7247389    .8226641
// -------------------------------------------------------------------------------
//
// -.03735147
// This front-end cannot display the desired image type.
// (file ./tex/plots/bar_uviews.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (file ./tex/plots/bar_uviews_week.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (file ./tex/plots/bar_uviews_duration.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (file ./tex/plots/bar_views.pdf written in PDF format)
// This front-end cannot display the desired image type.
// (file ./tex/plots/bar_cviews.pdf written in PDF format)

// %% [markdown]
// ## Robustness Checks

// %%
sum
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       weekoy |         36         1.5     3.50102         -4          7
//          arm |         36           1    .8280787          0          2
//       videos |         36    5.388658    5.556613          0   30.92105
//     duration |         36    .8969776    .8805252          0   4.911211
// videos_pre~1 |         36    1.351174    1.435997          0   4.532609
// -------------+---------------------------------------------------------
// videos_mid~2 |         36     2.93457    3.751825          0   16.10526
// videos_pos~2 |         36    1.102914     2.47719          0   12.18421
//      videosu |         36    3.366022    2.827042          0   15.35263
//    durationu |         36    .5453793    .4398708          0   2.392538
// videos_pr~1u |         36    .8543317     1.03314          0   3.216867
// -------------+---------------------------------------------------------
// videos_mi~2u |         36    1.738379    2.065908          0   6.805263
// videos_po~2u |         36     .773311    1.609544          0   7.457895

// %% [markdown]
// ### Randomization inference
//
// Randomly assign placebo treatment and estimate placebo treatment effects. Where the true treatment effect falls into the distribution of placebo treatments provides a nonparametric p-value.

// %%
* get data

get_idyearlevel
get_std_units
qui merge_winter_gpa
qui merge_dem
qui clean_dem
qui label_vars
// Out:
// (72 vars, 850 obs)
// (0 observations deleted)
// (817 real changes made)
// (847 real changes made)
// (810 real changes made)
// (843 real changes made)
// (789 real changes made)
// (831 real changes made)
// (15 real changes made)
//
// (850 missing values generated)
// (433 real changes made)
// (417 real changes made)
// (850 missing values generated)
// (433 real changes made)
// (417 real changes made)
// (850 missing values generated)
// (407 real changes made)
// (405 real changes made)
// (850 missing values generated)
// (396 real changes made)
// (393 real changes made)
// (850 missing values generated)
// (228 real changes made)
// (270 real changes made)
// (850 missing values generated)
// (225 real changes made)
// (270 real changes made)
// (850 missing values generated)
// (225 real changes made)
// (267 real changes made)

// %%
* random number generated from random.org

ritest treated _b[treated], reps(5000) seed(84784) strata(year mid1scorestd): ///
    reg finalscorestd treated mid1scorestd i.year if arm > 0, robust
// Out:
// (running regress on estimation sample)
//
// Linear regression                               Number of obs     =        374
//                                                 F(3, 370)         =      64.01
//                                                 Prob > F          =     0.0000
//                                                 R-squared         =     0.3058
//                                                 Root MSE          =     .86168
//
// ------------------------------------------------------------------------------
//              |               Robust
// finalscore~d |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1748242   .0886893     1.97   0.049     .0004259    .3492226
// mid1scorestd |   .6402954   .0471575    13.58   0.000     .5475651    .7330258
//              |
//         year |
//        2019  |   .0165984    .089277     0.19   0.853    -.1589556    .1921524
//              |
//        _cons |   .6675452   .0953325     7.00   0.000     .4800838    .8550067
// ------------------------------------------------------------------------------
// (420 missing values generated)
// (420 missing values generated)
//
// Resampling replications (5000)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// ..................................................  1000
// ..................................................  1050
// ..................................................  1100
// ..................................................  1150
// ..................................................  1200
// ..................................................  1250
// ..................................................  1300
// ..................................................  1350
// ..................................................  1400
// ..................................................  1450
// ..................................................  1500
// ..................................................  1550
// ..................................................  1600
// ..................................................  1650
// ..................................................  1700
// ..................................................  1750
// ..................................................  1800
// ..................................................  1850
// ..................................................  1900
// ..................................................  1950
// ..................................................  2000
// ..................................................  2050
// ..................................................  2100
// ..................................................  2150
// ..................................................  2200
// ..................................................  2250
// ..................................................  2300
// ..................................................  2350
// ..................................................  2400
// ..................................................  2450
// ..................................................  2500
// ..................................................  2550
// ..................................................  2600
// ..................................................  2650
// ..................................................  2700
// ..................................................  2750
// ..................................................  2800
// ..................................................  2850
// ..................................................  2900
// ..................................................  2950
// ..................................................  3000
// ..................................................  3050
// ..................................................  3100
// ..................................................  3150
// ..................................................  3200
// ..................................................  3250
// ..................................................  3300
// ..................................................  3350
// ..................................................  3400
// ..................................................  3450
// ..................................................  3500
// ..................................................  3550
// ..................................................  3600
// ..................................................  3650
// ..................................................  3700
// ..................................................  3750
// ..................................................  3800
// ..................................................  3850
// ..................................................  3900
// ..................................................  3950
// ..................................................  4000
// ..................................................  4050
// ..................................................  4100
// ..................................................  4150
// ..................................................  4200
// ..................................................  4250
// ..................................................  4300
// ..................................................  4350
// ..................................................  4400
// ..................................................  4450
// ..................................................  4500
// ..................................................  4550
// ..................................................  4600
// ..................................................  4650
// ..................................................  4700
// ..................................................  4750
// ..................................................  4800
// ..................................................  4850
// ..................................................  4900
// ..................................................  4950
// ..................................................  5000
//
//       command:  regress finalscorestd treated mid1scorestd i.year if arm > 0,
//                     robust
//         _pm_1:  _b[treated]
//   res. var(s):  treated
//    Resampling:  Permuting treated
// Clust. var(s):  __000020
//      Clusters:  430
// Strata var(s):  year mid1scorestd
//        Strata:  237
//
// ------------------------------------------------------------------------------
// T            |     T(obs)       c       n   p=c/n   SE(p) [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        _pm_1 |   .1748243     516    5000  0.1032  0.0043  .0949011   .1119654
// ------------------------------------------------------------------------------
// Note: Confidence interval is with respect to p=c/n.
// Note: c = #{|T| >= |T(obs)|}

// %%
sum
// Out:
//     Variable |        Obs        Mean    Std. Dev.       Min        Max
// -------------+---------------------------------------------------------
//       weekoy |         36         1.5     3.50102         -4          7
//          arm |         36           1    .8280787          0          2
//       videos |         36    5.388658    5.556613          0   30.92105
//     duration |         36    .8969776    .8805252          0   4.911211
// videos_pre~1 |         36    1.351174    1.435997          0   4.532609
// -------------+---------------------------------------------------------
// videos_mid~2 |         36     2.93457    3.751825          0   16.10526
// videos_pos~2 |         36    1.102914     2.47719          0   12.18421
//      videosu |         36    3.366022    2.827042          0   15.35263
//    durationu |         36    .5453793    .4398708          0   2.392538
// videos_pr~1u |         36    .8543317     1.03314          0   3.216867
// -------------+---------------------------------------------------------
// videos_mi~2u |         36    1.738379    2.065908          0   6.805263
// videos_po~2u |         36     .773311    1.609544          0   7.457895

// %%
* repeat fixing pair assignments as strata

ritest treated _b[treated], reps(5000) seed(84784) strata(pairyear): ///
    reg finalscorestd treated mid1scorestd i.year if arm > 0, robust
// Out:
// (running regress on estimation sample)
//
// Linear regression                               Number of obs     =        374
//                                                 F(3, 370)         =      64.01
//                                                 Prob > F          =     0.0000
//                                                 R-squared         =     0.3058
//                                                 Root MSE          =     .86168
//
// ------------------------------------------------------------------------------
//              |               Robust
// finalscore~d |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1748242   .0886893     1.97   0.049     .0004259    .3492226
// mid1scorestd |   .6402954   .0471575    13.58   0.000     .5475651    .7330258
//              |
//         year |
//        2019  |   .0165984    .089277     0.19   0.853    -.1589556    .1921524
//              |
//        _cons |   .6675452   .0953325     7.00   0.000     .4800838    .8550067
// ------------------------------------------------------------------------------
// (420 missing values generated)
// (420 missing values generated)
//
// Resampling replications (5000)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// ..................................................  1000
// ..................................................  1050
// ..................................................  1100
// ..................................................  1150
// ..................................................  1200
// ..................................................  1250
// ..................................................  1300
// ..................................................  1350
// ..................................................  1400
// ..................................................  1450
// ..................................................  1500
// ..................................................  1550
// ..................................................  1600
// ..................................................  1650
// ..................................................  1700
// ..................................................  1750
// ..................................................  1800
// ..................................................  1850
// ..................................................  1900
// ..................................................  1950
// ..................................................  2000
// ..................................................  2050
// ..................................................  2100
// ..................................................  2150
// ..................................................  2200
// ..................................................  2250
// ..................................................  2300
// ..................................................  2350
// ..................................................  2400
// ..................................................  2450
// ..................................................  2500
// ..................................................  2550
// ..................................................  2600
// ..................................................  2650
// ..................................................  2700
// ..................................................  2750
// ..................................................  2800
// ..................................................  2850
// ..................................................  2900
// ..................................................  2950
// ..................................................  3000
// ..................................................  3050
// ..................................................  3100
// ..................................................  3150
// ..................................................  3200
// ..................................................  3250
// ..................................................  3300
// ..................................................  3350
// ..................................................  3400
// ..................................................  3450
// ..................................................  3500
// ..................................................  3550
// ..................................................  3600
// ..................................................  3650
// ..................................................  3700
// ..................................................  3750
// ..................................................  3800
// ..................................................  3850
// ..................................................  3900
// ..................................................  3950
// ..................................................  4000
// ..................................................  4050
// ..................................................  4100
// ..................................................  4150
// ..................................................  4200
// ..................................................  4250
// ..................................................  4300
// ..................................................  4350
// ..................................................  4400
// ..................................................  4450
// ..................................................  4500
// ..................................................  4550
// ..................................................  4600
// ..................................................  4650
// ..................................................  4700
// ..................................................  4750
// ..................................................  4800
// ..................................................  4850
// ..................................................  4900
// ..................................................  4950
// ..................................................  5000
//
//       command:  regress finalscorestd treated mid1scorestd i.year if arm > 0,
//                     robust
//         _pm_1:  _b[treated]
//   res. var(s):  treated
//    Resampling:  Permuting treated
// Clust. var(s):  __000021
//      Clusters:  430
// Strata var(s):  pairyear
//        Strata:  218
//
// ------------------------------------------------------------------------------
// T            |     T(obs)       c       n   p=c/n   SE(p) [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        _pm_1 |   .1748243     359    5000  0.0718  0.0037   .064796   .0793087
// ------------------------------------------------------------------------------
// Note: Confidence interval is with respect to p=c/n.
// Note: c = #{|T| >= |T(obs)|}

// %%
* Randomization inference for midterm 2 as outcome

ritest treated _b[treated], reps(1000) seed(84784) strata(year mid1scorestd): ///
    reg mid2scorestd treated mid1scorestd i.year if arm > 0, robust

ritest treated _b[treated], reps(1000) seed(84784) strata(pairyear): ///
    reg mid2scorestd treated mid1scorestd i.year if arm > 0, robust
// Out:
// (running regress on estimation sample)
//
// Linear regression                               Number of obs     =        395
//                                                 F(3, 391)         =      64.21
//                                                 Prob > F          =     0.0000
//                                                 R-squared         =     0.2677
//                                                 Root MSE          =     .90085
//
// ------------------------------------------------------------------------------
//              |               Robust
// mid2scorestd |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1760727   .0902943     1.95   0.052    -.0014503    .3535957
// mid1scorestd |   .5842426   .0431204    13.55   0.000     .4994658    .6690194
//              |
//         year |
//        2019  |   .0848701   .0905292     0.94   0.349    -.0931149     .262855
//              |
//        _cons |   .5955296   .0985996     6.04   0.000     .4016778    .7893813
// ------------------------------------------------------------------------------
// (420 missing values generated)
// (420 missing values generated)
//
// Resampling replications (1000)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// ..................................................  1000
//
//       command:  regress mid2scorestd treated mid1scorestd i.year if arm > 0,
//                     robust
//         _pm_1:  _b[treated]
//   res. var(s):  treated
//    Resampling:  Permuting treated
// Clust. var(s):  __000022
//      Clusters:  430
// Strata var(s):  year mid1scorestd
//        Strata:  237
//
// ------------------------------------------------------------------------------
// T            |     T(obs)       c       n   p=c/n   SE(p) [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        _pm_1 |   .1760727      68    1000  0.0680  0.0080  .0531881   .0854131
// ------------------------------------------------------------------------------
// Note: Confidence interval is with respect to p=c/n.
// Note: c = #{|T| >= |T(obs)|}
//
// (running regress on estimation sample)
//
// Linear regression                               Number of obs     =        395
//                                                 F(3, 391)         =      64.21
//                                                 Prob > F          =     0.0000
//                                                 R-squared         =     0.2677
//                                                 Root MSE          =     .90085
//
// ------------------------------------------------------------------------------
//              |               Robust
// mid2scorestd |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//      treated |   .1760727   .0902943     1.95   0.052    -.0014503    .3535957
// mid1scorestd |   .5842426   .0431204    13.55   0.000     .4994658    .6690194
//              |
//         year |
//        2019  |   .0848701   .0905292     0.94   0.349    -.0931149     .262855
//              |
//        _cons |   .5955296   .0985996     6.04   0.000     .4016778    .7893813
// ------------------------------------------------------------------------------
// (420 missing values generated)
// (420 missing values generated)
//
// Resampling replications (1000)
// ----+--- 1 ---+--- 2 ---+--- 3 ---+--- 4 ---+--- 5
// ..................................................    50
// ..................................................   100
// ..................................................   150
// ..................................................   200
// ..................................................   250
// ..................................................   300
// ..................................................   350
// ..................................................   400
// ..................................................   450
// ..................................................   500
// ..................................................   550
// ..................................................   600
// ..................................................   650
// ..................................................   700
// ..................................................   750
// ..................................................   800
// ..................................................   850
// ..................................................   900
// ..................................................   950
// ..................................................  1000
//
//       command:  regress mid2scorestd treated mid1scorestd i.year if arm > 0,
//                     robust
//         _pm_1:  _b[treated]
//   res. var(s):  treated
//    Resampling:  Permuting treated
// Clust. var(s):  __000022
//      Clusters:  430
// Strata var(s):  pairyear
//        Strata:  218
//
// ------------------------------------------------------------------------------
// T            |     T(obs)       c       n   p=c/n   SE(p) [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        _pm_1 |   .1760727      65    1000  0.0650  0.0078  .0505203   .0821011
// ------------------------------------------------------------------------------
// Note: Confidence interval is with respect to p=c/n.
// Note: c = #{|T| >= |T(obs)|}
